# %% [markdown]
# # Результат ревью:
#
# Я отмечаю адекватный уровень твоей программистской подготовки. Ты используешь продвинутые концепции языка Python, библиотеки pandas и одной из основных библиотек машинного обучения sckit-learn. Это показывает твой уровень владения инструментами анализа данных и machine learning.
#
# С комментированием никаких проблем нет. Твоих объяснений достаточно для понимания твоими коллегами хода мыслей. Ссылки из брифа проекта в нужных местах также помогают следовать за развитием событий и дают полную информацию касаемо того, что будет происходить в том или ином разделе проекта.
#
# Мне было просто проверять твой проект, потому что он чётко структурирован, с использованием оглавления.
#
# Зелёным цветом я отметил и прокомментировал удачные и элегантные решения, на которые ты можешь опираться в будущих проектах.
#
# Жёлтым цветом я выделил то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас.
#
# Красных комментариев, которые бы не позволяли мне принять твой проект в его нынешнем состоянии - нет.
#
# ПРОЕКТ ПРИНЯТ!
#
# Подводя итог: отличная работа, молодец! Желаю тебе успехов в учёбе, желаю, чтобы проекты сдавались или сразу, или после первой итерации! Удачи!
#
# Если же после факта принятия проекта у тебя возникнут дополнительные вопросы – я никуда не пропал. Мой адрес эл/почты: anepomnjashiy@gmail.com, имя в Пачке: anepomnjashiy, имя в Телеграмме: https://t.me/aleks_nep
#
# p.s. я тебе на твой адрес эл/почты сейчас вышлю некоторые материалы из своей электронной библиотеки - надеюсь они будут тебе полезными в учёбе.</div>

# %% [markdown]
# Приветствую Дмитрий!
#
# Меня зовут Александр Непомнящий и я буду проверять твой проект. Предлагаю общаться на «ты», но, если это не удобно - мы вполне можем перейти на вы".
#
# Вкратце обо мне: я работаю в сфере информационных технологий, аналитика (анализ) данных - это и мой рабочий функционал и личная, интересная мне область для саморазвития. Используемый стек: python, pandas, графические библиотеки matplotlib/seaborn/plotly. Сфера применения: маркетинговая аналитика в медицинской клинике. Если вдруг есть вопрос – что делает аналитик в коммерческой медицине – то вот короткий ответ. Самый главный вопрос, на который мы хотим получить ответ (и который в дальнейшем приведёт к перераспределению рекламного бюджета, плюс напрямую повлияет на разработку и предложению рынку новых лечебных программ) - это КТО ОН, НАШ КЛИЕНТ? Фактически это задача (на нашем внутреннем языке формулируется как построение и анализ «ПОРТРЕТА КЛИЕНТА»). Визуализируем и пытаемся придать смысл половозрастным данным наших клиентов, кто из какого региона и в какие времена года к нам приезжает. Учитываем количество приездов. Учитываем на какую программу этот конкретный клиент приехал в первый раз и как в дальнейшем меняются его предпочтения. Пытаемся построить модель оттока и спрогнозировать, когда клиент уйдёт в отток. Смотрим цифры (суммы трат клиентов на отдельных группах медицинских программ). Анализируем медицинские услуги, которые входят в путёвку, а также что, в каких количествах и на какую сумму клиент покупает дополнительно. Очень вкратце как-то так.
#
# Теперь к сути: основная цель моей проверки - пройти по шагам, по логике твоего решения и обсудить те моменты, которые можно изменить, улучшить, довести до идеала. Такой формат работы двух программистов (аналитиков) ты или уже встречал(а), или встретишь на своей новой работе. Кто-то такой процесс называет "код-ревью", ну а как по мне, так это обмен опытом двух коллег, когда каждый из нас становиться лучше в процессе дискуссии.
#
# Свои мысли, советы, комментарии и вопросы я буду оставлять в текстовых ячейках (markdown) ПОД твоим кодом.
# Для твоего удобства все эти заметки будут "цветными", как на примерах ниже:
#
# "Зелеными" комментариями я буду отмечать твой элегантный ("красивый") код и/или удачные решения, на которые ты можешь смело опираться в будущих проектах.
# <div class="alert alert-success">
# <b>Отлично! 👍</b>
#
# Отличная находка, элегантный код ...</div>
#
# "Жёлтые" комментарии - это мои размышления, предложения, что-то, что на следующей итерации можно сделать по-другому. Твоя реакция на "жёлтые" комментарий необходима и подразумевает или правки, или реакцию или аргументированное согласие/не согласие. Я искренне верю, что наш двусторонний диалог под "желтым" комментарием - это то, от чего твой проект только выиграет. <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Здесь я бы предложил использовать .... Мои аргументы в пользу этого ...</div>
#
# "Красные" комментарий будут появляться, когда что-то пойдёт не так: например, код будет выдавать ошибку. Или, когда в проекте не будет ответов на основные вопросы, ради которых весь анализ и выполнялся. "Красные" комментарии необходимо будет исправить, прежде чем я смогу принять проект.
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# В этой ячейке код работает не так как задумано ...</div>
#
# Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Это поможет мне оперативно выполнить повторную проверку твоего проекта.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом, лучше всего в новой ячейке, сразу под моим комментарием. Если для своих комментариев ты будешь использовать какой-то заметный цвет, то мне будет легче отследить твои изменения, например так:
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Текст твоего комментария ...</font>
# </div>
#
# **Распространенные типичные недочёты в проектах студентов:**
#
# <div class="alert alert-danger" ❌>
# Неработоспособный код. Проверь проект на работоспособность перед отправкой на проверку. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании.</div>
# <div class="alert alert-danger" ❌>
# Проект не структурирован. В проекте должна быть структура, т.е. названия разделов и подразделов должны быть записаны в ячейках Markdown.</div>
# <div class="alert alert-warning" 👉 >
# Отсутствие описания, целей проекта, его задач, выводов. В описании должны быть озвучены поставленные задачи, содержание датасета, промежуточные и финальные выводы. Как правило, заказчик читает только финальный вывод, поэтому важно добавить информацию о проведенном исследовании, применить форматирование текста, в общем, сделать красиво, чтобы было понятно, что проведено настоящее исследование и выводу можно верить.</div>
# <div class="alert alert-warning" 👉 >
# "Длинный код". Код и и комментарии, которые прячутся за правым концом ячейки нужно переносить на новую строку. Твои будущие коллеги не оценят необходимость постоянного скроллинга. Согласно PEP8: https://www.python.org/dev/peps/pep-0008/ длина строки не должна превышать 79 символов.</div>
# <div class="alert alert-warning" 👉 >
# Твои коллеги ценят и твое и своё время, поэтому "подсвечивай" свои комментарии в ячейках Markdown. Подробнее про синтаксис Markdown, с примерами, можно почитать здесь: https://paulradzkov.com/2014/markdown_cheatsheet/?
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Привет, Александр! Рад знакомству и спасибо за подробное интро. Я проектный менеджер в ИТ компании (ML & BigData). Мне очень нравится область  ML, это то что меня по-настоящему увлекает. Поэтому хочу в ML дальше работать и развиваться, именно поэтому решил получить перспективные знания в этой области. Яндекс Практикум - сила! Я хочу научиться всесторонне работать с данными), применять потом свои навыки для решения бизнесовых задач. Подтянуть харды), незабывая про софт скилы конечно же) Спасибо за твое время и профессиональный подход. Готов учиться, перенимать знания и опыт. </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Дмитрий - приветствую! Я тоже изначально был в нашей компании руководителем отдела ИТ, но с 2018 начал увлекаться аналитикой, стал учиться, потом пробовать решать рабочие маркетингово-аналитические задачи и в итоге с конца 2024 чтобы разрешить двусмысленность рабочей позиции отказался от руководства отделом и стал обычным аналитиком данных в нем.
#
# Дмитрий, я приступаю ко 2ой итерации проверки и если всё исправлено, то сразу приму твой проект!
# </div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# IT-компания получила заказ от фермера, который хочет расширить стадо, закупив новых коров, но при этом:
#
# - хочет получить высокий удой (не менее 6000 кг/год)
# - вкусное молоко по собственным критериям.
#
# Для принятия решения фермер просит разработать модели машинного обучения, которые помогут ему объективно выбрать коров по данным от продавца.

# %% [markdown]
# ### Цель проекта

# %% [markdown]
# Создать две модели:
#
# - Модель 1 (регрессия) — прогнозирует удой коровы (в кг/год).
#
# - Модель 2 (классификация) — прогнозирует, будет ли молоко вкусным (да/нет).
#
# На основе этих моделей фермер сможет:
#
# - отбирать коров с удоем ≥6000 кг/год;
#
# - исключать коров с невкусным молоком;
#
# - сократить риск неудачных покупок.

# %% [markdown]
# ### План работы над проектом

# %% [markdown]
# Шаг 1. Загрузить и изучить данные
#
# Шаг 2. Предобработка: пропуски, типы данных, переименование столбцов
#
# Шаг 3. Исследовательский анализ: графики, выбросы, статистика
#
# Шаг 4. Корреляционный анализ признаков
#
# Шаг 5. Обучение и сравнение трёх моделей линейной регрессии (для удоя)
#
# Шаг 6. Обучение модели логистической регрессии (для вкуса молока)
#
# Шаг 7. Финальные прогнозы, отбор лучших коров, выводы и рекомендации фермеру

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Ты делаешь хорошую работу уже в начале нашего проекта по Data Science. Твой подход к описанию всего проекта уже с самого начала – это плюс. Ты ясно и четко формулируешь цель и план нашего исследования, что дает нам основу для выполнения дальнейших этапов (... слона надо есть по кусочкам ... - такой мудрый совет есть на предмет того как подступиться к решению большой и сложной на первый взгляд задаче).
#
# Твое описание того, как ты будешь двигаться дальше, также впечатляет. Твои действия по обработке и структурированию данных в начальных этапах – это правильный шаг. Также отмечу, что твое умение систематизировать данные с самого начала проекта позволяет нам лучше понимать характер данных и уже сейчас делать некоторые предварительные наметки. Такой подход в начале аналитического/Дата Сайенс проекта говорит о твоей компетентности и ставит нас на "правильную дорогу" для успешного исследования.
# </div>

# %% [markdown]
# ## Шаг 1. Загрузка и изучение данных

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from scipy.stats import ttest_ind
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import r2_score, accuracy_score, recall_score, precision_score, confusion_matrix
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score, precision_score, confusion_matrix
from IPython.display import display

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично, все импорты собраны в начале "тетрадки"!
#
# ---
# В Python есть своя философия. Именно отсюда берутся определенные правила и стандарты. В пайтон такое соглашение назвали PEP8.
#
# Соответствие PEP8 позволяет видеть основную структуру вашего кода другим разработчикам. Не нужно привыкать к другому оформлению кода. Если вы привыкли как-то оформлять код, а увидели что-то совершенно другое, то вы поймете.
#
# Официальная документация: https://peps.python.org/pep-0008/
#
# Основные моменты и рекомендации:
#
# - Используй пробелы, разрешается использование табов, но смешивание запрещено. Отступ соответствует 4 пробелам. Хорошие редакторы кода автоматически заменяют табы на пробелы.
#
# - Вокруг операторов +, -, =, *, /, ** должны быть пробелы.
#
# - Строка не должна превышать 79 символов
#
# - Ну и наконец про импорты: импорты можно делать только по одному на строку! При этом из одного модуля можно доставать несколько нужных объектов. Порядок тоже важен:
#
# - импорты из стандартной библиотеки
# - импорты из сторонних библиотек
# - импорты пользовательских модулей текущего проекта (например если выносишь функции в отдельный модуль)
#
# И нежелательно их перемешивать с константами и переменными.
#
# p.s. состав стандартных библиотек Python здесь: [The Python Standard Library](https://docs.python.org/3/library/)
# </div>

# %% [markdown]
# ### 1.1 Откроем файлы с данными и изучим общую информацию**

# %%
# Загрузка данных
main_df = pd.read_csv('/datasets/ferma_main.csv')
dad_df = pd.read_csv('/datasets/ferma_dad.csv')
buy_df = pd.read_csv('/datasets/cow_buy.csv')

# %% [markdown]
# ### 1.2 Изучите данные. Определите, соответствуют ли они описанию задачи и изученным в прошлых спринтах стандартам оформления данных. При необходимости переименуйте столбцы.

# %% [markdown]
# ###  Изучим датафрейм main_df:

# %%
# Посмотрим на общую информацию датафрейма main_df
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634 entries, 0 to 633
# Data columns (total 5 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   id;Удой                                                                                634 non-null    object
#  1    кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин                                634 non-null    object
#  2    г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  634 non-null    object
#  3   %;Белок                                                                                634 non-null    object
#  4   %;Вкус молока;Возраст                                                                  616 non-null    object
# dtypes: object(5)
# memory usage: 24.9+ KB

# %% [markdown]
# Вся таблица «склеена» в 5 колонок, хотя по описанию должно быть около 12 отдельных признаков (id, удой, жирность, СПО и т.д.). Данные, скорее всего, разделены ";" (точкой с запятой), а pandas.read_csv( ) по умолчанию разделяет по запятой ",". При загрузке данных нужно будет указать разделитель ";".

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Да Дмитрий, отлично! Здесь была небольшая хитрость от авторов проекта.
# </div>

# %%
# Посмотрим на общую информацию датафрейма main_df с указателем разделителя ";"
main_df = pd.read_csv('/datasets/ferma_main.csv', sep=';')
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634 entries, 0 to 633
# Data columns (total 12 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     634 non-null    int64
#  1   Удой, кг                               634 non-null    int64
#  2   ЭКЕ (Энергетическая кормовая единица)  634 non-null    object
#  3   Сырой протеин, г                       634 non-null    int64
#  4   СПО (Сахаро-протеиновое соотношение)   634 non-null    object
#  5   Порода                                 634 non-null    object
#  6   Тип пастбища                           634 non-null    object
#  7   порода папы_быка                       634 non-null    object
#  8   Жирность,%                             634 non-null    object
#  9   Белок,%                                634 non-null    object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично. Импортировали требуемые для анализа библиотеки и загрузили данные. Сейчас посмотрим на их состояние и если всё ОК, сможем приступать к построению моделей....
#
# p.s. при установке дополнительных библиотек (через ! pip install ...) можно использовать полезный ключ **-q** (он "подавит" служебные сообщения об установке, которых может быть достаточно много - вплоть до нескольких экранов прокрутки)
#
# p.p.s. При считывании данных из файла здорово перестраховывать себя от ошибок, связанных, например, с неверным указанием пути к файлу. А иногда бывает, что работаешь с файлом локально, выгружаешь его на сервер, ожидая, что он будет принимать данные, которые лежат на том же сервере, а код падает с ошибкой, потому что путь к файлу не поменялся с локального на серверный.
#
# Для этого, например, можно использовать конструкцию `try-except`: сначала пробуешь локальный путь, при возникновении ошибки используется серверный путь (подробнее можешь почитать тут: https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html).
#
# Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# Ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
# Также на этапе считывания данных задать индекс-столбец- за это действие отвечает параметр `index_col`.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# ![image.png](attachment:image.png)
#
# В наших данных пропусков НЕТ, НО ЕСЛИ БЫ БЫЛИ .... я стараюсь дать подробный коммент-видение на тему обработки пропусков данных (так как понимаю, что несмотря на кажущуюся простоту - не очень просто понять чем ("заглушкой"? / медианой? / средним? / по комбинации столбцов?) заполнять? а может удалять?
#
# ---
# По результатам проверки примерно 4+ тысяч проектов за крайние 2 года у меня родилось небольшое эссе на тему "удаления vs. спасения" данных, как раз на основе тех ситуаций и вопросов, которые мне коллеги задавали, которые мы обсуждали, уточняли и исправляли ...
#
# <br>
# <br>
# <details>
# <summary style="color: blue; font-size: 18px; font-weight: bold;">▶ <u>Подробнее ...</u></summary>
#
# Желание уменьшить количество пропусков в данных (если такое желание конечно возникает ... но в рабочих проектах, "в жизни" оно как правило возникает) - можно только приветствовать. Приветствовать по 3-м минимум причинам:
#
# 1. это тренировка
#
# 2. это попытка сохранить данные ("данных много не бывает")
#
# 3. самое главное на мой взгляд - развитие аналитического мышления, желания "проникать" в секреты, которые скрывают данные. Когда вначале рождается гипотеза, потом эта гипотеза проверяется на данных (может ли такое быть? подтверждается?) и в финале уже гипотеза облекается в код.
#
# Однако заполнение пропусков в данных не такая простая задача, как кажется ... простого ответа на вопросы: заполнять? удалить? чем заполнять? подходящего под все сценарии, нет ни в одной умной книжке ...
#
# Самый идеальный случай - когда у тебя под рукой есть эксперт в предметной области. Если такой есть - советуйся с ним. Как правило это человек из бизнеса, который знает суть бизнес-процесса и вот именно он даст тебе точный и аргументированный совет - что в данной, конкретной задаче делать с "битыми" полями в строках датафрейма. Ты скажешь ему какой процент пропусков в данных, а он тебе ответит что делать: можно/нельзя удалить и/или даст рекомендации по заполнению. Вообще, как правило такой человек "на любой работе" есть. Для примера, финансовый директор думаю всегда даст рекомендации по финансовым данным, прочие профильные спецы - по своей сфере компетенций. Наверное только в зарождающемся стартапе может не быть каких-то компетенций, но тут уже можно и через фриланс (и т.п.) попробовать найти спеца и просить совета.
#
# Теперь, что делать, если такого человека нет. Я бы ответил так: **ПОПЫТАТЬСЯ** вникнуть в бизнес-проблему самому. Наверное это сложно, если предметная область ну совсем незнакома. Но в общем случае, если бизнес совсем незнаком, то заполнение пропусков в данных наверное, не получиться. В таком случае попробуй ориентироваться на такое правило: если записи с пропусками в ключевых для твоего анализа столбцах составляют 1-3-5-ну может до 10% строк, то попробуй эти записи из оригинального датафрейма вырезать (но сохрани бы в некий df, к которому ты при необходимости можешь всегда обратиться).
#
# В жизни, МНЕ КАЖЕТСЯ, как правило по всему датафрейму заполнять медианой/средним - ну вообще не вариант. Почему? Я бы ответил так - потому, что реальные датафреймы имеют миллионы строк и горизонт в несколько (десятков) лет, и если в 90-2000-е года всё было как-то более -менее стабильно/прогнозируемо, то в нынешней реальности события раскручиваются гораздо быстрее и не прогнозируемо. Пример: ты аналитик в автобизнесе. У тебя есть данные с пропусками в цене для машин в 2005-2007 года. Можно заполнить их средними основываясь на данных 2020-2021?
#
# Может быть и такой вариант, что без заполнения некоторых столбцов некоторые записи по сути **НЕ** имеют смысла, но если их (записи с пропусками удалить), то и данных-то не останется. Ну тогда я бы такой совет дал - всё же заполнять медианой (она к скачкам выбросов более устойчива), но не по всему глобальному датафрейму, а выбрать простые группы (например, группы по интервалу лет - чтобы сгладить турбулентность нынешних лет) или выбрать более сложные группы (например, группы по интервалу лет и одновременно марке автопроизводителя (это я про вымышленный пример с автобизнесом)).
#
# Теперь предположим, что мы выбрали какую-то стратегию заполнения "пропусков", не суть какую (оставить NaN или заполнить "заглушкой"). И в том и в другом случае придётся помнить этот выбор. Ты спросишь почему? Отвечу - потому, что инструменты, применяемые тобой в Питон/Пандас в каких-то случаях могут спокойно пропускать твой выбор, а в каких-то случаях тебе придется этот твой выбор обрабатывать.
#
# Пример 1: мы заполнили пропуски "заглушкой". В этом случае: 1. расчет корреляций значение "заглушку" будет "ловить" (надо отфильтровать!), 2. расчет гипотез также будет "сбивать" правильный вывод (надо отфильтровать!) 3. графики, которые ты будешь строить - будут "заглушку" отображать на осях (нужно фильтровать), 4. в группировках также по-видимому "заглушку" надо будет убирать.
#
# Пример 2: мы оставили пропуски как NaN. В этом случае: 1. метод .corr NaN'ы пропускает (отфильтровать не надо), 2. в расчет гипотез всё равно пропуски отфильтровать 3. графики, которые ты будешь строить могут отображать, а могут не отображать, 4. в группировках NaN'ы по sum() видны не будут, а по count() будут.
#
# Ну и напоследок совсем уже жёсткий пример: додумывать "от себя", бездумно проставлять в пропуски медианные/средние значения - это НЕ верно. Давай же опять "про жизнь". Я писал выше, что в медицине работаю, да? **Предположим** мне принесли данные из онкологического диспансера. Задача: построить модель, которая по некоторым маркерным анализам будет прогнозировать наличие онкологии. **По-простому, ответить, что стоит за строчкой в данных: жизнь или смерть.** Уууууух … аж мороз по коже продирает, правда?
#
# Итак, 1.000.000 записей и 70 столбцов. Данные за 25 лет. 70 столбцов - это поля, с результатами конкретных и очень специфичных анализов. В "начале" данных, 15-20 лет назад, есть пропуски (много), но и в принципе, в данных есть пропуски. Как думаешь - имею я моральное право перед людьми, которые фактически доверяют мне в виде данных свою жизнь огульно подойти к заполнению пропусков?
#
# </details>
# <br>
# <br>
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Спасибо за инф! Изучил твое эссе и буду применять на практике! </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Отлично! Всегда рад помочь!
# </div>

# %%
# Посмотрим на первые строки датафейма main_df
main_df.head()
# Out:
#    id  Удой, кг ЭКЕ (Энергетическая кормовая единица)  Сырой протеин, г  \
# 0   1      5863                                  14,2              1743
# 1   2      5529                                  12,8              2138
# 2   3      5810                                    14              1854
# 3   4      5895                                  12,4              2012
# 4   5      5302                                  12,8              1675
#
#   СПО (Сахаро-протеиновое соотношение)           Порода Тип пастбища  \
# 0                                 0,89   Вис Бик Айдиал    Равнинное
# 1                                 0,89   Вис Бик Айдиал    Равнинные
# 2                                0,885  РефлешнСоверинг    Холмистое
# 3                                0,885  РефлешнСоверинг    Холмистое
# 4                                0,885   Вис Бик Айдиал    Равнинные
#
#   порода папы_быка Жирность,% Белок,% Вкус молока      Возраст
# ...

# %% [markdown]
# Теперь данные из ferma_main.csv загружены корректно.
#
# Всего строк: 634
#
# Всего столбцов: 12
#
# Целевые признаки:
#
# Удой, кг — количество молока в кг (int64)
#
# Вкус молока — вкус (объект, то есть категориальный признак: «вкусно» / «не вкусно»)
#
# Однако есть проблема с типами данных: cтолбцы ЭКЕ (Энергетическая кормовая единица), СПО, Жирность,%, Белок,% — имеют тип object, хотя должны быть числовыми. Это значит, что внутри них, вероятно, запятая используется как десятичный разделитель.
#
# Необходима предварительная обработка датафейма main_df: замена запятых на точки в числовых столбцах, приведение к float нужных столбцов.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Спасибо за точный и конкретный вывод по предварительному анализу загруженных данных. Зачастую коллеги ограничиваются исключительно кодом, без слов. Ввиду чего непонятно к каким выводам они пришли и что собираются делать дальше.
#
# Ты важные моменты озвучиваешь в этом выводе, молодец. Я прокомментирую их по месту возникновения кода (или в финальном выводе по подразделу подготовки (предобработки) данных.</div>

# %% [markdown]
# В датафрейме main_df приведем названия колонок к нижнему регистру, заменяем пробелы и символы

# %%
# Приводим названия колонок к нижнему регистру, заменяем пробелы и символы
main_df.columns = (
    main_df.columns
    .str.strip()                            # удаляем пробелы по краям
    .str.lower()                            # приводим к нижнему регистру
    .str.replace(' ', '_', regex=True)      # заменяем пробелы на подчёркивания
    .str.replace(',%', 'проц', regex=True)   # заменяем символ % на 'проц'
    .str.replace(',', '', regex=True)       # удаляем запятые
    .str.replace('(', '', regex=True)       # удаляем открывающую скобку
    .str.replace(')', '', regex=True)       # удаляем закрывающую скобку
    .str.replace('__+', '_', regex=True)    # заменяем двойные подчёркивания на одинарные
)

# Заменим "жирностьпроц" на "жирность_проц"
main_df.rename(columns={
    'жирностьпроц': 'жирность_проц',
    'белокпроц': 'белок_проц'
}, inplace=True)

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Молодец, что названия столбцов выше приведены к "змеинному регистру"!
#
# p.s и приведение названий столбцов к нижнему регистру и изменение типов данных столбцов - это отдельные шаги в общем пайплайне исследовательского анализа данных (EDA). Ниже ссылки, описывающие взгляд на процесс EDA "сверху":
#
# 1. https://waksoft.susu.ru/2021/07/23/issledovatelskij-analiz-dannyh-v-python-rukovodstvo-dlya-novichkov-na-2021-god/
#
# 2. https://www.kaggle.com/code/ekami66/detailed-exploratory-data-analysis-with-python
#
# 3. https://www.datacareer.de/blog/exploratory-data-analysis-in-python/
# </div>

# %%
main_df.columns
# Out:
# Index(['id', 'удой_кг', 'эке_энергетическая_кормовая_единица',
#        'сырой_протеин_г', 'спо_сахаро-протеиновое_соотношение', 'порода',
#        'тип_пастбища', 'порода_папы_быка', 'жирность_проц', 'белок_проц',
#        'вкус_молока', 'возраст'],
#       dtype='object')

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634 entries, 0 to 633
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   634 non-null    int64
#  1   удой_кг                              634 non-null    int64
#  2   эке_энергетическая_кормовая_единица  634 non-null    object
#  3   сырой_протеин_г                      634 non-null    int64
#  4   спо_сахаро-протеиновое_соотношение   634 non-null    object
#  5   порода                               634 non-null    object
#  6   тип_пастбища                         634 non-null    object
#  7   порода_папы_быка                     634 non-null    object
#  8   жирность_проц                        634 non-null    object
#  9   белок_проц                           634 non-null    object
#  10  вкус_молока                          634 non-null    object
# ...

# %%
# Посмотрим на первые строки датафейма main_df
main_df.head()
# Out:
#    id  удой_кг эке_энергетическая_кормовая_единица  сырой_протеин_г  \
# 0   1     5863                                14,2             1743
# 1   2     5529                                12,8             2138
# 2   3     5810                                  14             1854
# 3   4     5895                                12,4             2012
# 4   5     5302                                12,8             1675
#
#   спо_сахаро-протеиновое_соотношение           порода тип_пастбища  \
# 0                               0,89   Вис Бик Айдиал    Равнинное
# 1                               0,89   Вис Бик Айдиал    Равнинные
# 2                              0,885  РефлешнСоверинг    Холмистое
# 3                              0,885  РефлешнСоверинг    Холмистое
# 4                              0,885   Вис Бик Айдиал    Равнинные
#
#   порода_папы_быка жирность_проц белок_проц вкус_молока      возраст
# 0           Айдиал          3,58      3,076      вкусно  более_2_лет
# ...

# %% [markdown]
# Названия колонок приведены к нижнему регистру, заменены пробелы на подчёркивания, заменены символ % на 'проц'.

# %% [markdown]
# ### Изучим датафрейм dad_df:

# %%
# Посмотрим на общую информацию датафрейма dad_df
dad_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id;Имя Папы  629 non-null    object
# dtypes: object(1)
# memory usage: 5.0+ KB

# %%
# Посмотрим на первые строки датафейма dad_df
dad_df.head()
# Out:
#   id;Имя Папы
# 0    1;Буйный
# 1  2;Соловчик
# 2     3;Барин
# 3    4;Буйный
# 4     5;Барин

# %% [markdown]
# Датафрейм dad_df «склеена» в 1 одну колонку с названием id;Имя Папы, где значения идут в формате id;имя. Эта колонка должна быть разделена на две: id — идентификатор (число), а вторая колонка Имя Папы — имя быка (строка). Нужно будет сплитануть датафейм dad_df по ";".

# %%
# Разделим колонку на два отдельных столбца
# dad_df[['id', 'Имя Папы']] = dad_df['id;Имя Папы'].str.split(';', expand=True)

# Удалим исходную колонку
# dad_df.drop(columns='id;Имя Папы', inplace=True)

# Преобразуем id в целое число
# dad_df['id'] = dad_df['id'].astype(int)

# Посмотрим результат
# dad_df.info()

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Дмитрий - это сложно, да и не нужно. Почему также не указать сразу при загрузке данных "разделитель"?
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Согласен! Незачем усложнять. Загружаем dad_df сразу с правильным разделителем. </font>
# </div>

# %%
# Загружаем dad_df сразу с правильным разделителем
dad_df = pd.read_csv('/datasets/ferma_dad.csv', sep=';')

# Проверим результат
dad_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        629 non-null    int64
#  1   Имя Папы  629 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 10.0+ KB

# %%
# Посмотрим первые 5 строк
dad_df.head()
# Out:
#    id  Имя Папы
# 0   1    Буйный
# 1   2  Соловчик
# 2   3     Барин
# 3   4    Буйный
# 4   5     Барин

# %%
# Приводим названия столбцов в датафрейме dad_df к нижнему регистру и нормализуем
dad_df.columns = (
    dad_df.columns
    .str.strip()              # удаляем пробелы по краям
    .str.lower()              # приводим к нижнему регистру
    .str.replace(' ', '_')    # заменяем пробелы на подчёркивания
)

# %%
dad_df.columns
# Out:
# Index(['id', 'имя_папы'], dtype='object')

# %%
dad_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        629 non-null    int64
#  1   имя_папы  629 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 10.0+ KB

# %% [markdown]
# В датафрейме dad_df разделили "склееную" колонку на два отдельных столбца, преобразовали данные id в целое число, привели названия столбца "Имя Папы" к нижнему регистру на "имя_папы".

# %% [markdown]
# ### Изучим датафрейм buy_df:

# %%
# Посмотрим на общую информацию датафрейма buy_df
buy_df.info()

# Посмотрим на первые строки датафрейма buy_df
buy_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Порода;Тип пастбища;порода папы_быка;Имя_папы;Текущая_жирность  20 non-null     object
#  1   %;Текущий_уровень_белок                                         20 non-null     object
#  2   %;Возраст                                                       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes
#   Порода;Тип пастбища;порода папы_быка;Имя_папы;Текущая_жирность  \
# 0         Вис Бик Айдиал;холмистое;Айдиал;Геркулес;3
# 1          Вис Бик Айдиал;равнинное;Соверин;Буйный;3
# 2          РефлешнСоверинг;равнинное;Соверин;Барин;3
# 3          РефлешнСоверинг;холмистое;Айдиал;Буйный;3
# 4          РефлешнСоверинг;равнинное;Айдиал;Буйный;3
#
# ...

# %% [markdown]
# Всего 3 столбца, все типа object — это указывает на проблему: данные не были корректно разделены на столбцы при чтении. Нужно считать файл buy_df с правильным разделителем (sep=';').

# %%
# Перечитаем датафрейма buy_df правильно
buy_df = pd.read_csv('/datasets/cow_buy.csv', sep=';')

# Проверим информацию о колонках
buy_df.info()

# Посмотрим на первые строки
buy_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Порода                   20 non-null     object
#  1   Тип пастбища             20 non-null     object
#  2   порода папы_быка         20 non-null     object
#  3   Имя_папы                 20 non-null     object
#  4   Текущая_жирность,%       20 non-null     object
#  5   Текущий_уровень_белок,%  20 non-null     object
#  6   Возраст                  20 non-null     object
# dtypes: object(7)
# memory usage: 1.2+ KB
#             Порода Тип пастбища порода папы_быка  Имя_папы Текущая_жирность,%  \
# 0   Вис Бик Айдиал    холмистое           Айдиал  Геркулес               3,58
# 1   Вис Бик Айдиал    равнинное          Соверин    Буйный               3,54
# 2  РефлешнСоверинг    равнинное          Соверин     Барин               3,59
# ...

# %%
# Приводим названия столбцов в датафрейме buy_df к нижнему регистру и нормализуем
buy_df.columns = (
    buy_df.columns
    .str.strip()                            # удаляем пробелы по краям
    .str.lower()                            # приводим к нижнему регистру
    .str.replace(' ', '_', regex=True)      # заменяем пробелы на подчёркивания
    .str.replace('%', 'проц', regex=True)   # заменяем символ % на 'проц'
    .str.replace(',', '', regex=True)       # удаляем запятые
    .str.replace('__+', '_', regex=True)    # заменяем двойные подчёркивания на одинарные
)

# Заменим "жирностьпроц" на "жирность_проц"
buy_df.rename(columns={
    'текущая_жирностьпроц': 'текущая_жирность_проц',
    'текущий_уровень_белокпроц': 'текущий_уровень_белок_проц'
}, inplace=True)

# %%
buy_df.columns
# Out:
# Index(['порода', 'тип_пастбища', 'порода_папы_быка', 'имя_папы',
#        'текущая_жирность_проц', 'текущий_уровень_белок_проц', 'возраст'],
#       dtype='object')

# %%
buy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   порода                      20 non-null     object
#  1   тип_пастбища                20 non-null     object
#  2   порода_папы_быка            20 non-null     object
#  3   имя_папы                    20 non-null     object
#  4   текущая_жирность_проц       20 non-null     object
#  5   текущий_уровень_белок_проц  20 non-null     object
#  6   возраст                     20 non-null     object
# dtypes: object(7)
# memory usage: 1.2+ KB

# %% [markdown]
# Tеперь датафрейм buy_df читается корректно и содержит 7 столбцов. Есть проблема с типом данных: все пока object — жирность и белок записаны как строки с запятой вместо точки (пример: '3,58'), поэтому их нужно привести к float.

# %% [markdown]
# Данные всех трех датафреймов изучены, определили что в каждом из них нужно корректирорвать, переходим к обработке.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Хорошо, данные загрузили, первичные проверки сделали.
# </div>

# %% [markdown]
# ##  Шаг 2. Предобработка данных

# %% [markdown]
# Проверьте данные на наличие пропусков и дубликатов. Узнайте, корректны ли типы данных у каждого признака. При необходимости устраните все проблемы с данными.

# %% [markdown]
# ### Выполним предварительную обработку датафейма main_df:

# %%
# Список столбцов, где нужно заменить запятую на точку и привести к float
columns_to_fix = [
    'эке_энергетическая_кормовая_единица',
    'спо_сахаро-протеиновое_соотношение',
    'жирность_проц', 
    'белок_проц'
]

# Заменим запятые на точки и преобразуем к типу float
for col in columns_to_fix:
    main_df[col] = main_df[col].astype(str).str.replace(',', '.').astype(float)

# Проверим типы данных после преобразования
print("Типы данных после преобразования:\n")
print(main_df.dtypes)

# Проверим пропуски
print("\nКоличество пропущенных значений:\n")
print(main_df.isna().sum())

# Проверим дубликаты
print("\nКоличество дубликатов:", main_df.duplicated().sum())
# Out:
# Типы данных после преобразования:
#
# id                                       int64
# удой_кг                                  int64
# эке_энергетическая_кормовая_единица    float64
# сырой_протеин_г                          int64
# спо_сахаро-протеиновое_соотношение     float64
# порода                                  object
# тип_пастбища                            object
# порода_папы_быка                        object
# жирность_проц                          float64
# белок_проц                             float64
# вкус_молока                             object
# возраст                                 object
# dtype: object
#
# Количество пропущенных значений:
#
# id                                     0
# удой_кг                                0
# эке_энергетическая_кормовая_единица    0
# сырой_протеин_г                        0
# спо_сахаро-протеиновое_соотношение     0
# порода                                 0
# тип_пастбища                           0
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично, привели типы ... явно числовые типы, но при этом имеющие тип "строка" приведены к числовому типу.
#
# ---
# Кроме того, что теперь признаки в нашем датафрейме имеют корректные типы данных - это действие ещё и вот по какой прчине полезно: оптимизация объёма больших датасетов может помочь значительно сократить объём памяти (занимаемый датасетом). Это особенно важно, если у вас ограничены вычислительные ресурсы или если требуется работать с огромными объёмами данных.
#
# Функция pd.to_numeric() с параметром downcast='integer' позволяет снизить тип числовых данных до наименьшего возможного размера без потери информации. Например, преобразование целочисленных значений из типа int64 до int32, int16 или int8 может существенно сократить использование памяти, особенно если значения в датасете могут быть представлены более короткими типами данных.
#
# Однако при использовании этой оптимизации следует быть осторожным. Преобразование типов данных может привести к потере точности или диапазона значений, особенно если числа в датасете имеют большой разброс или могут выходить за пределы нового типа данных. Поэтому перед использованием функции pd.to_numeric() с параметром downcast='integer', рекомендуется проверить, что сокращение размера типа не приведет к потере важной информации для конкретной задачи.
# </div>

# %% [markdown]
# Найдено 5 дубликатов — удалим их, чтобы не было искажений в обучении моделей.

# %%
main_df = main_df.drop_duplicates()

# Проверим дубликаты
print("\nКоличество дубликатов:", main_df.duplicated().sum())
# Out:
# Количество дубликатов: 0

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Хочу отметить, что в общем случае даже если **df.duplicated().sum() == 0** - это может совсем не означать, что в данных нет дубликатов.
#
# ---
# В реальных рабочих датасетах скорее всего не будет полных дубликатов, но вот неявные наверняка будут встречаться, соответственно с ними надо будет уметь работать. Для поиска неявных дублей обычно используют параметр **subset** у функции duplicated(). Правда здесь, в нашем проекте, надо поразмыслить над тем какие комбинации столбцов могут говорить о реальных дублях в данных.</div>

# %% [markdown]
# Дубликаты удалены, пропуски в датафейме main_df не найдены, типы данных преобразованы.

# %% [markdown]
# Прроведем проверку неявных дубликатов в категориальных признаках в датафрейме main_df. Проверим возможные проблемы в данных, которые не видны сразу — особенно в больших датафреймах.

# %%
# Выберем категориальные признаки
cat_cols = main_df.select_dtypes(include='object').columns

# Посмотрим на уникальные значения до очистки
for col in cat_cols:
    print(f"\nПризнак: {col}")
    print("Уникальные значения (до очистки):")
    print(main_df[col].sort_values().unique())
# Out:
# Признак: порода
# Уникальные значения (до очистки):
# ['Вис Бик Айдиал' 'РефлешнСоверинг']
#
# Признак: тип_пастбища
# Уникальные значения (до очистки):
# ['Равнинное' 'Равнинные' 'Холмистое']
#
# Признак: порода_папы_быка
# Уникальные значения (до очистки):
# ['Айдиал' 'Айдиалл' 'Соверин']
#
# Признак: вкус_молока
# Уникальные значения (до очистки):
# ['вкусно' 'не вкусно']
#
# Признак: возраст
# Уникальные значения (до очистки):
# ['более_2_лет' 'менее_2_лет']

# %% [markdown]
# В наших признаках есть неявные дубликаты, которые обязательно нужно очистить, иначе они могут исказить обучение моделей.
#
# тип_пастбища:
# 'Равнинное' и 'Равнинные' — это, скорее всего, одно и тоже - ошибка ввода.
#
# Нужно привести к одному: например, 'равнинное'.
#
# порода_папы_быка:
# 'Айдиал' и 'Айдиалл' — опечатка (двойная «л»).
#
# Нужно привести обе к 'айдиал'.
#
# порода:
# 'Вис Бик Айдиал', 'РефлешнСоверинг' — норм, но стоит привести к нижнему регистру.
#
# вкус_молока, возраст:
# Значения уже в норме (на русском, нижний регистр, без дубликатов).

# %%
# Унификация текстовых значений в категориальных признаках

# Приводим все к нижнему регистру и удаляем лишние пробелы
cat_cols = ['порода', 'тип_пастбища', 'порода_папы_быка', 'вкус_молока', 'возраст']
for col in cat_cols:
    main_df[col] = (
        main_df[col]
        .astype(str)
        .str.strip()
        .str.lower()
        .str.replace(r'\s+', ' ', regex=True)
    )

# Исправим явные ошибки и опечатки
main_df['тип_пастбища'] = main_df['тип_пастбища'].replace({
    'равнинные': 'равнинное'
})
main_df['порода_папы_быка'] = main_df['порода_папы_быка'].replace({
    'айдиалл': 'айдиал'
})

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# **Приводим все к нижнему регистру** - небольшой комментарий, на будущее … в общем случае, **в жизни** я бы не стал приводить к нижнему регистру данные, хранящиеся в датафрейме. Что если некоторые значения предполагаются что зависят от регистра (ну, например, навскидку: какие-нибудь "хитрые" цифро-буквенные маркировки у лекарств или внутренние коды (в разном регистре), под которыми по складу проходят десятки миллионов запчастей для какой-нибудь подводной лодки или пароли, которые могут зависеть от регистра)? Прежде чем это делать в реальном проекте, для реального бизнеса я бы пообщался с экспертом в предметной области. </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Логично, я сразу об этом не подумал! Спасибо! На будущее запомню.</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично, молодец, обнаружено 2 "разночтения" (породы + типы пастбищ) по факту одних и тех же категорий в признаках.</div>

# %%
# Посмотрим на уникальные значения после очистки
for col in cat_cols:
    print(f"\n{col}:")
    print(main_df[col].value_counts())
# Out:
# порода:
# вис бик айдиал     373
# рефлешнсоверинг    256
# Name: порода, dtype: int64
#
# тип_пастбища:
# холмистое    351
# равнинное    278
# Name: тип_пастбища, dtype: int64
#
# порода_папы_быка:
# айдиал     318
# соверин    311
# Name: порода_папы_быка, dtype: int64
#
# вкус_молока:
# вкусно       371
# не вкусно    258
# Name: вкус_молока, dtype: int64
#
# возраст:
# более_2_лет    519
# менее_2_лет    110
# Name: возраст, dtype: int64

# %%
# Посмотрим общую инф о дата фрейма
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 629 entries, 0 to 628
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   629 non-null    int64
#  1   удой_кг                              629 non-null    int64
#  2   эке_энергетическая_кормовая_единица  629 non-null    float64
#  3   сырой_протеин_г                      629 non-null    int64
#  4   спо_сахаро-протеиновое_соотношение   629 non-null    float64
#  5   порода                               629 non-null    object
#  6   тип_пастбища                         629 non-null    object
#  7   порода_папы_быка                     629 non-null    object
#  8   жирность_проц                        629 non-null    float64
#  9   белок_проц                           629 non-null    float64
#  10  вкус_молока                          629 non-null    object
# ...

# %%
# Посмотрим первые строки датафрейма 
main_df.head()
# Out:
#    id  удой_кг  эке_энергетическая_кормовая_единица  сырой_протеин_г  \
# 0   1     5863                                 14.2             1743
# 1   2     5529                                 12.8             2138
# 2   3     5810                                 14.0             1854
# 3   4     5895                                 12.4             2012
# 4   5     5302                                 12.8             1675
#
#    спо_сахаро-протеиновое_соотношение           порода тип_пастбища  \
# 0                               0.890   вис бик айдиал    равнинное
# 1                               0.890   вис бик айдиал    равнинное
# 2                               0.885  рефлешнсоверинг    холмистое
# 3                               0.885  рефлешнсоверинг    холмистое
# 4                               0.885   вис бик айдиал    равнинное
#
#   порода_папы_быка  жирность_проц  белок_проц вкус_молока      возраст
# ...

# %% [markdown]
# **Даннные датафейма main_df готовы для EDA. Всё чисто.**

# %% [markdown]
# ### Выполним предварительную обработку датафейма dad_df:

# %%
# Проверим типы данных
print("Типы данных:\n")
print(dad_df.dtypes)

# Проверим пропуски
print("\nКоличество пропущенных значений:\n")
print(dad_df.isna().sum())

# Проверим количество дубликатов
print("\nКоличество дубликатов:", dad_df.duplicated().sum())
# Out:
# Типы данных:
#
# id           int64
# имя_папы    object
# dtype: object
#
# Количество пропущенных значений:
#
# id          0
# имя_папы    0
# dtype: int64
#
# Количество дубликатов: 0

# %% [markdown]
# Явных дубликатов и пропусков - нет! Теперь проверим какие имена встречаются в столбце имя_папы.

# %%
# Посмотрим, какие имена встречаются:
print(dad_df['имя_папы'].value_counts())
# Out:
# Барин       240
# Буйный      215
# Соловчик    110
# Геркулес     64
# Name: имя_папы, dtype: int64

# %% [markdown]
# В результате проверки выявлено, что все имена в dad_df написаны одинаково и консистентно. Их всего 4, и все уникальные значения имеют ожидаемый вид: Барин, Буйный, Соловчик, Геркулес.

# %%
# Посмотрим общую инф о датафрейме 
dad_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        629 non-null    int64
#  1   имя_папы  629 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 10.0+ KB

# %%
# Посмотрим первые строки датафрейма 
dad_df.head()
# Out:
#    id  имя_папы
# 0   1    Буйный
# 1   2  Соловчик
# 2   3     Барин
# 3   4    Буйный
# 4   5     Барин

# %% [markdown]
# **Даннные датафейма dad_df готовы для EDA. Всё чисто.**

# %% [markdown]
# ### Выполним предварительную обработку датафейма buy_df:

# %%
# Проверим пропуски
print("Пропуски в данных:\n" + buy_df.isna().sum().to_string(), "\n")


# Проверим дубликаты
print("Количество дубликатов:", buy_df.duplicated().sum(), "\n")

# Преобразуем строки с запятыми в float
columns_to_convert = ['текущая_жирность_проц', 'текущий_уровень_белок_проц']
for col in columns_to_convert:
    buy_df[col] = buy_df[col].str.replace(',', '.').astype(float)

# Проверим типы данных после преобразования
print("Типы данных после преобразования:\n", buy_df.dtypes)
# Out:
# Пропуски в данных:
# порода                        0
# тип_пастбища                  0
# порода_папы_быка              0
# имя_папы                      0
# текущая_жирность_проц         0
# текущий_уровень_белок_проц    0
# возраст                       0
#
# Количество дубликатов: 4
#
# Типы данных после преобразования:
#  порода                         object
# тип_пастбища                   object
# порода_папы_быка               object
# имя_папы                       object
# текущая_жирность_проц         float64
# текущий_уровень_белок_проц    float64
# возраст                        object
# dtype: object

# %% [markdown]
# Пропусков нет. Типы данных приведены — числовые признаки (жирность, белок) теперь в формате float64.
# Однако обнаружены дубликаты — 4 строки. Удалим их.

# %%
# Удалим дубликаты и перезапишем нумерацию
# buy_df = buy_df.drop_duplicates().reset_index(drop=True)

# Проверим дубликаты
print("Количество дубликатов:", buy_df.duplicated().sum(), "\n")

# Проверим размер датафрейма:
print("Текущий размер датафрейма:", buy_df.shape)
# Out:
# Количество дубликатов: 4
#
# Текущий размер датафрейма: (20, 7)

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Датафрейм "с коровами для предсказаний" - это ведь по сути тестовая выборка, данные для предсказаний (для наших моделей). А в тестовой выборке мы не правомочны что либо удалять - эти данные поступают на вход обученной модели и по ним должны быть сделаны "предсказания".
#
# Нет никакой разницы есть ли дубли в тестовой выборке или нет: **это данные по которым ДОЛЖНЫ БЫТЬ сделаны "предсказания"**.
#
# Один раз мне студент задал такой вопрос:
# </div>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Принято! Исправил - отменил удаление дубликатов в тестовой выборке. Запомню, это важный момент про тестовую выборку. Спасибо!
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, это важный момент именно для понимания. Но что касается потенциальных ошибок в "реальной жизни", то мне кажется их не должно быть. В реальности вряд ли будет ситуация, когда ты получишь сразу и тренировочную и тестовую выборки. Обычно всё происходит наоборот, так: ты получаешь полный набор данных, проводишь на нем предобработку и EDA и только потом дельишь на трейн и тест.
# </div>

# %% [markdown]
# Данные уже в нижнем регистре, без лишних пробелов. Проверка показывает, все текстовые столбцы — типа object, нет пропусков, числовые значения жирность и белок — в формате float64. В датафрейме 20 строк, 7 столбцов - всё корректно.

# %%
# Посмотрим общую инф о датафрейме
buy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   порода                      20 non-null     object
#  1   тип_пастбища                20 non-null     object
#  2   порода_папы_быка            20 non-null     object
#  3   имя_папы                    20 non-null     object
#  4   текущая_жирность_проц       20 non-null     float64
#  5   текущий_уровень_белок_проц  20 non-null     float64
#  6   возраст                     20 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 1.2+ KB

# %%
# Посмотрим первые строки датафрейма
buy_df.head()
# Out:
#             порода тип_пастбища порода_папы_быка  имя_папы  \
# 0   Вис Бик Айдиал    холмистое           Айдиал  Геркулес
# 1   Вис Бик Айдиал    равнинное          Соверин    Буйный
# 2  РефлешнСоверинг    равнинное          Соверин     Барин
# 3  РефлешнСоверинг    холмистое           Айдиал    Буйный
# 4  РефлешнСоверинг    равнинное           Айдиал    Буйный
#
#    текущая_жирность_проц  текущий_уровень_белок_проц      возраст
# 0                   3.58                       3.076  более_2_лет
# 1                   3.54                       3.081  менее_2_лет
# 2                   3.59                       3.074  более_2_лет
# 3                   3.40                       3.061  более_2_лет
# 4                   3.64                       3.074  более_2_лет

# %% [markdown]
# **Даннные датафейма buy_df готовы для EDA. Всё чисто.**

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# В этом разделе всё ОК: необходимые после загрузки данных действия (1. загрузка данных, 2. требования PEP8, 3. дубликаты, 4. анализ уникальных значений в признаках 5. пропуски) выполнены.
# </div>

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# ### 3.1 Проведите статистический анализ всех признаков.

# %%
# Разделим признаки на числовые и категориальные
num_features = main_df.select_dtypes(include=['int64', 'float64']).columns
cat_features = main_df.select_dtypes(include='object').columns

print("Числовые признаки:", list(num_features), "\n")
print("Категориальные признаки:", list(cat_features))
# Out:
# Числовые признаки: ['id', 'удой_кг', 'эке_энергетическая_кормовая_единица', 'сырой_протеин_г', 'спо_сахаро-протеиновое_соотношение', 'жирность_проц', 'белок_проц']
#
# Категориальные признаки: ['порода', 'тип_пастбища', 'порода_папы_быка', 'вкус_молока', 'возраст']

# %%
# Описательная статистика для числовых признаков
main_df[num_features].describe().T
# Out:
#                                      count         mean          std  \
# id                                   629.0   315.000000   181.720940
# удой_кг                              629.0  6188.750397  1644.795489
# эке_энергетическая_кормовая_единица  629.0    14.543879     1.306408
# сырой_протеин_г                      629.0  1923.364070   182.956251
# спо_сахаро-протеиновое_соотношение   629.0     0.913116     0.032203
# жирность_проц                        629.0     3.603657     0.168656
# белок_проц                           629.0     3.075671     0.002549
#
#                                           min       25%       50%       75%  \
# id                                      1.000   158.000   315.000   472.000
# удой_кг                              5204.000  5751.000  6133.000  6501.000
# эке_энергетическая_кормовая_единица    10.900    13.500    14.700    15.600
# сырой_протеин_г                      1660.000  1771.000  1888.000  2062.000
# ...

# %% [markdown]
# Разбор описательной статистики (EDA) по всем числовым признакам.
#
# 1. удой_кг — целевой признак для линейной регрессии
#
# mean: 6188.75
#
# std: 1644.80
#
# min / max: от 5204 до 45616 — выброс!
#
# Наблюдение: максимум сильно отличается от 75% квартиля (6501), это явный выброс. Надо будет построить boxplot или распределение, чтобы принять решение об удалении.
#
# 2. эке_энергетическая_кормовая_единица
#
# Среднее: 14.54
#
# min: 10.9, max: 16.8
#
# Распределение похоже на нормальное, разброс умеренный
#
# Наблюдение: признак скорее всего полезен, но проверим на корреляцию с удоем.
#
# 3. сырой_протеин_г
#
# Среднее: 1923 г, std: 182.96
#
# Диапазон от 1660 до 2349 г
#
# Наблюдение: тоже выглядит как хороший числовой признак без явных выбросов. Проверим линейную зависимость с удоем.
#
# 4. спо_сахаро-протеиновое_соотношение
#
# Маленькое стандартное отклонение (0.03) при среднем 0.91
#
# Значения от 0.84 до 0.96
#
# Наблюдение: почти константа — слабая информативность. Проверим его значение при обучении, возможно, модель его проигнорирует.
#
# 5. жирность_проц
#
# Среднее 3.6%, min = 2.99, max = 3.75
#
# Наблюдение: небольшой разброс, но не совсем константа. Можно оставить, особенно если влияет на вкус.
#
# 6. белок_проц
#
# Среднее: 3.075, std: 0.0025 — очень малая дисперсия
#
# min/max: от 3.069 до 3.085
#
# Наблюдение: почти одинаковые значения — признак может быть бесполезен. Проверим позже с помощью model.feature_importances_ или coef_.
#
# 7. id — идентификатор
#
# Просто порядковый номер — в модели не используется. Нужно будет удалить перед обучением.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Молодец! Не часто вижу чтобы результат describe() вообще, в принципе, комментировали. Обычно почему-то просто "выводят эту табличку" и ни словом в выводах её не упоминают.
#
# describe() играет важную роль в понимание распределения статистик признаков в данных. Отсюда можно увидеть аномалии, выбросы. Просто "посмотреть" на эти таблички недостаточно, обязательно нужен вывод по анализу результата describe().
#
# ---
# describe() в pandas - это мощный метод, который предоставляет статистическое описание данных. Вот несколько причин, почему describe() важен:
#
# 1. Общее понимание данных: describe() предоставляет общий обзор статистических характеристик, таких как среднее значение, стандартное отклонение, минимум, максимум и квартили. Это позволяет быстро понять основные характеристики данных.
#
# 2. Выявление выбросов: Анализ статистических показателей может помочь выявить аномалии или выбросы в данных. Например, если среднее значение сильно отличается от медианы, это может указывать на наличие выбросов.
#
# 3. Понимание распределения данных: describe() также предоставляет информацию о распределении данных через квартили, что может быть полезным для понимания формы распределения.
#
# 4. Быстрый анализ пропущенных значений: Метод также выводит количество непустых значений для каждого столбца, что может помочь в определении пропущенных данных.
# </div>

# %%
# Частота появления значений категориальных признаков
for col in cat_features:
    print(f"\n{col} — уникальные значения и частота:")
    print(main_df[col].value_counts())
# Out:
# порода — уникальные значения и частота:
# вис бик айдиал     373
# рефлешнсоверинг    256
# Name: порода, dtype: int64
#
# тип_пастбища — уникальные значения и частота:
# холмистое    351
# равнинное    278
# Name: тип_пастбища, dtype: int64
#
# порода_папы_быка — уникальные значения и частота:
# айдиал     318
# соверин    311
# Name: порода_папы_быка, dtype: int64
#
# вкус_молока — уникальные значения и частота:
# вкусно       371
# не вкусно    258
# Name: вкус_молока, dtype: int64
#
# возраст — уникальные значения и частота:
# более_2_лет    519
# менее_2_лет    110
# Name: возраст, dtype: int64

# %% [markdown]
# Вывод по частоте появления значений категориальных признаков:
#
# Порода: порода «вис бик айдиал» встречается чаще (373), чем «рефлешнсоверинг» (256).
#
# Тип пастбища: холмистые пастбища преобладают (351 против 278).
#
# Порода папы быка: обе породы почти равны по частоте, но «айдиал» немного чаще (318 против 311).
#
# Вкус молока: большинство коров дают вкусное молоко (371 против 258).
#
# Возраст: основная часть коров старше 2 лет (519), молодых — значительно меньше (110).

# %% [markdown]
# ### 3.2 Постройте графики для каждого признака. Помните, что количественным и категориальным признакам подходят разные графики.

# %% [markdown]
# Построим сначала графики для категориальных признаков. Это позволит нам наглядно оценить баланс классов. Упростит понимание распределения категорий. Поможет нам  найти аномалии.

# %%
# Построим графики для категориальных признаков
plt.figure(figsize=(16, 10))

for i, col in enumerate(cat_features):
    plt.subplot(2, 3, i + 1)  # делаем сетку 2 строки × 3 столбца
    sns.countplot(data=main_df, x=col, order=main_df[col].value_counts().index)
    plt.title(f'Распределение: {col}')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# ![image.png](attachment:image.png)
#
# Наблюдаешь ли дисбаланс в целевой переменной (таргете)? **Если наблюдаешь, то как этот факт отражается на выборе метрики для моделей МО?**
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#         <font color='4682B4'>Глядя на распределение классов в столбце вкус_молока можно отметить, что один класс "вкусно" встречается чаще "не_вкусно". Согласно графику: класс вкусно — примерно 360 наблюдений, а класс не вкусно — примерно 260 наблюдений. Это не сильный, но заметный дисбаланс классов (58% на 42%). Когда есть дисбаланс, нужно смотреть на: Precision — точность: как много из предсказанных вкусных — действительно вкусные. Recall — полнота: как много из всех настоящих вкусных коров модель нашла. F1-score — гармоническое среднее между precision и recall.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
#
# Да, верно! Вкратце, только не accuracy ))) Эта метрика в условиях дисбаланса классов ничего о производительности модели не скажет. Почему так? Представим, у нас есть модель, которая обучается на датасете, где 95% примеров принадлежат к классу A, а оставшиеся 5% - к классу B. Если модель просто всегда предсказывает класс A, она достигнет accuracy в 95%, что может показаться впечатляющим результатом.
#
# Однако, с точки зрения решаемой задачи, модель практически бесполезна, потому что она не улавливает примеры класса B. В случае дисбаланса классов, когда один класс сильно преобладает, метрика accuracy может быть высокой даже для моделей, которые не выполняют задачу правильно.
#
# Вместо accuracy в таких случаях рекомендуется использовать другие метрики, такие как:
#
# * Precision (точность): Показывает, какая доля положительных предсказаний верна.
#
# * Recall (полнота): Показывает, какая доля истинных положительных примеров была уловлена моделью.
#
# * F1-мера: Сочетание точности и полноты.
#
# * Матрица ошибок (Confusion Matrix): Позволяет увидеть, какие именно ошибки совершает модель, а не просто общую долю правильных предсказаний.
#
# Эти метрики более информативны в контексте задач с дисбалансом классов, поскольку они учитывают различные аспекты работы модели и ее способность корректно предсказывать оба класса.
# </div>

# %% [markdown]
# 1. Признак порода
#
# Категории: «вис бим айршир» и «рэдхолштиносвежийт»
#
# Распределение: Наблюдается дисбаланс — «вис бим айршир» встречается чаще.
#
# Комментарий: Может повлиять на обучение модели, так как этот признак важен для таргета - вкус_молока.
#
# 2. Признак тип_пастбища
#
# Категории: «холмистое» и «равнинное»
#
# Распределение: Чуть больше «холмистое», но в целом довольно сбалансировано.
#
# Комментарий: Признак сбалансирован, что хорошо для модели.
#
# 3. Признак порода_папы_быка
#
# Категории: «айршир» и «оверрим»
#
# Распределение: Почти равное количество.
#
# Комментарий: Признак идеально сбалансирован.
#
# 4. Признак вкус_молока
#
# Категории: «вкусно» и «не вкусно»
#
# Распределение: Значительное доминирование «вкусно».
#
# Комментарий: Это целевая переменная.
#
# 5. Признак возраст
#
# Категории: «более_2_лет» и «менее_2_лет»
#
# Распределение: Сильный дисбаланс в сторону «более_2_лет».
#
# Комментарий: Дисбаланс может повлиять на модель, возраст — важный признак.
#
# Вывод:
#
# Сбалансированы: тип_пастбища, порода_папы_быка
#
# Умеренно несбалансированы: порода, вкус_молока
#
# Сильно несбалансированы: возраст.
#
# Вкус_молока — таргет, нам обязательно стоит учитывать дисбаланс классов.

# %% [markdown]
# Визуализируем количественные признаки — начнем с гистограмм и boxplot’ов, а потом перейдем к корреляционной матрице.

# %%
# Исключаем 'id' из визуализации
features_for_plot = [col for col in num_features if col != 'id']

# Размер сетки под количество признаков
n_cols = 3
n_rows = (len(features_for_plot) + n_cols - 1) // n_cols

plt.figure(figsize=(n_cols * 6, n_rows * 4))

for i, col in enumerate(features_for_plot, 1):
    plt.subplot(n_rows, n_cols, i)
    sns.histplot(main_df[col], kde=True, bins=30)
    plt.title(f'Распределение: {col}')
    plt.xlabel(col)
    plt.ylabel('Частота')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Просто супер: график подписан, оси подписаны. Не часто на самом деле такой скрупулёзный подход к оформлению встречается. Молодец!
#
# Я закончил физико-математический факультет Петрозаводского государственного университета. Нас там с первого курса приучили - если на сдачу лабораторной работы по физике приходишь с графиком, на котором не подписано общее название, названия осей (с единицами измерений), единичная шкала - всё сдача заканчивается не начавшись. Или если у моей лабораторной работы отсутствует вывод: что делали? по какой методике? что "намеряли"? как интерпретировали? какой финальный вывод? - всё, тоже на выход. Ну и в принципе сейчас, на текущей работе: код, который написан в тетрадке мало кому понятен и не сильно кому интересен. Важнее детальные выводы и тренды, которые попадут на слайд презентации в PowerPoint. Именно поэтому столь важное значение в аналитике данных придается промежуточным выводам и уж тем более финальному.
#
# ---
# (МЕТОДИЧЕСКИЕ МАТЕРИАЛЫ ПО ОФОРМЛЕНИЮ ГРАФИКОВ):
#
# При работе с графиками важно соблюдать следующие правила:
#
# 1. Стоит подписать названия осей X и Y.
#
# 2. Также стоит дать название графику.
#
# 3. Технические комментарии типа `<AxesSubplot:xlabel='datetime'>` стоит убирать - это можно сделать, поставив точку с запятой в последней строке кода в блоке визуализации, либо сделать последней строкой кода этого блока метод plt.show().
#
# 4. Графики нужно сделать больше - графики дефолтного размера не очень удобны для чтения. Удобнее будет настроить параметр plt.rcParams["figure.figsize"] = (x,y) сразу в ячейке импорта библиотек, и все графики проекта будут одного размера.
#
# Несколько таких нехитрых приёмов повысят качество твоих визуализаций в проекте. **И здесь следует сказать что ты об правилах оформления всё знаешь! МОЛОДЕЦ!**
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# ![image-2.png](attachment:image-2.png)
#
# (на примере моего скрина ниже) Вот здесь уже видно, что этот  признак - кандидат на перевод в категориальную шкалу (из 2х или из 3х элементов - что надо проверять качеством модели итоговой).
#
#
# </div>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Согласен! СПО как признак - кандидат на перевод в категориальную шкалу.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# ![image-2.png](attachment:image-2.png)
#
# (на примере моего скрина ниже) Признак "жирность" тоже кажется потенциально той фичей, которую имело бы смысл перевести в категориальную шкалу: "низкая"-"средняя"-"высокая" (хотя в отличии от СПО это в ТЗ не требуется ... но попытаться сделать можно. После этого посмотреть как это скажется на качестве модели). На примере моего(!) скрина: возможные отсечки по категориям ...
#
#
# </div>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Я об этом сразу и не подумал! Жирность - кандидат на перевод в категориальную шкалу (на примере твоего скрина: возможные отсечки по 3 категориям).
#         В нашем случае видны 3 «естественные» группы:
# низкая ≈ до 3.5; средняя ≈ 3.5–3.68; высокая ≈ 3.68+
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, по условию задачи с жирностью можно ничего не делать, но в реальном проекте такой график был бы аргументом для создания синтетического категориального признака "уровень жирности".
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image.png](attachment:image.png)
#
# "Провалы" в значениях гистограммы реально существуют? Или они появляются ввиду ошибочно выбранного значения bins?
#
# ---
# Есть ряд техник, которые позволяют "плюс/минус" определиться с числом бинов, например **правило Стёрджеса**: число bins равно log2(n) + 1, где n - количество наблюдений.
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#         На графике "белок_проц" можно заметить провалы между соседними интервалами. Это действительно может быть связано не с реальными выбросами, а с неудачным числом бинов (`bins=30`). Я пересчитаю число бинов по правилу Стёрджеса: `bins = log2(n) + 1`, где `n` — количество наблюдений.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, вижу исправление ниже.
# </div>

# %%
# Количество наблюдений
n = main_df['белок_проц'].dropna().shape[0]
sturges_bins = int(np.log2(n)) + 1

# Построим 2 графика рядом
plt.figure(figsize=(14, 5))

# График 1: фиксированные bins=30
plt.subplot(1, 2, 1)
sns.histplot(main_df['белок_проц'], kde=True, bins=30, color='skyblue', edgecolor='black')
plt.title('Белок_проц — фиксированные bins=30')
plt.xlabel('белок_проц')
plt.ylabel('Частота')
plt.grid(True)

# График 2: правило Стёрджеса
plt.subplot(1, 2, 2)
sns.histplot(main_df['белок_проц'], kde=True, bins=sturges_bins, color='lightgreen', edgecolor='black')
plt.title(f'Белок_проц — правило Стёрджеса (bins={sturges_bins})')
plt.xlabel('белок_проц')
plt.ylabel('Частота')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#         Я пересчитал число бинов по правилу Стёрджеса. Это дало более гладкое и интерпретируемое распределение. Спасибо за инсайт! Выводы ниже.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Отлично Дмитрий! Нез!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# ![image.png](attachment:image.png)
#
# В наших данных нет ни одного признака с нормальным распределением. Ты можешь проверить мои слова.
#
# У нормального распределения не может быть никаких **скосов / смещений / мультимод / ассиметрии / выбросов / пиков** - нормальное распределение **АБСОЛЮТНО СИММЕТРИЧНОЕ**.
#
# ---
# (Не)нормальность распределения данных проверяешь "на глаз", но это несколько некорректно - есть вероятность ошибки (понятно что не в нашем случае - тут всё ясно ... но вот в случае распределения похожего на Гауссиану). Что надо сделать чтобы строго подтвердить или опровергнуть нормальность распределения случайной величины?
#
# Вот полезные материалы материалы на эту тему: https://education.yandex.ru/handbook/data-analysis/article/bazovye-statisticheskie-testy и https://education.yandex.ru/handbook/data-analysis/article/bazovye-statisticheskie-testy-v-python
#
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#         Я исправил выводы, ниже обновленные выводы по графикам распределения.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Супер! Спасибо что прислушался к совету!
# </div>

# %% [markdown]
# 1. Удой (удой_кг)
#
# Форма: сильно правосторонне скошенное распределение с несколькими выбросами (особенно сильным — более 45 000 кг).
# Вывод: распределение несимметричное, с длинным хвостом. Присутствуют экстремальные выбросы. Перед обучением модели нужно обязательно проверить и удалить выбросы.
#
# 2. ЭКЕ (эке_энергетическая_кормовая_единица)
#
# Форма: умеренно асимметричное, ближе к равномерному, чем к нормальному.
# Вывод: не является нормальным распределением. Скос влево, выбросов не видно. Оставим как есть, опционально — можно нормализовать.
#
# 3. Сырой протеин (сырой_протеин_г)
#
# Форма: скошенное влево распределение, несимметричное, длинный левый хвост.
# Вывод: распределение не нормальное. Возможны умеренные выбросы влево. Стоит проверить на выбросы с помощью boxplot, при необходимости — масштабировать или трансформировать.
#
# 4. СПО-сахаро-протеиновое_соотношение
#
# Форма: мультимодальное (двугорбое) распределение.
# Вывод: чёткое указание на две подгруппы в выборке. Нормальным такое распределение не назвать.
# Рассмотреть бинаризацию или кластеризацию, может быть важным фактором, влияющим на вкус молока.
#
# 5. Жирность (жирность_проц)
#
# Форма: сильно скошено вправо, значительное смещение.
# Вывод: распределение явно не нормальное. Присутствуют выбросы влево. Проверим на выбросы. При необходимости использовать масштабирование.
#
# 6. Белок (белок_проц)
#
# Форма: визуально близко к нормальному, но наблюдается лёгкая асимметрия и неидеальность.
# Вывод: не идеальное нормальное распределение — небольшой перекос, пики. Оставим как есть, т.к. распределение близко к нормальному и выбросов нет. При необходимости, использовать масштабирование.
#
# Общий вывод:
#
# В наших данных нет признаков с идеальным нормальным распределением — как ты и отметил, это важно.
#
# У многих признаков есть асимметрия, выбросы или мультимодальность. Это учтем при дальнейшей работе и выборе моделей.

# %%
plt.figure(figsize=(14, 8))  # Размер всей фигуры

for i, col in enumerate(num_features[1:]):  # начинаем с индекса 1, исключая 'id'
    plt.subplot(2, 3, i+1)  # создаём 2 строки и 3 колонки подграфиков
    sns.boxplot(data=main_df, x=col)  # строим boxplot
    plt.title(f'Boxplot: {col}')  # название графика

plt.tight_layout()  # убираем наложения
plt.show()  # показываем графики

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично!  Боксплот рядом с гистограммой - это отлично! Гистограмма будет показывать нам распределение количественного признака, а боксплот даст информацию о **возможных выбросах** (пишу **возможных**, потому что нужно анализировать бизнесовый смысл значений показанных как выбросы ... просто так удалять то, что показывает боксплот за пределами 1,5 IQR от границ "ящика" - неверно) и основных статистиках (квартилях) признака.
# </div>

# %% [markdown]
# ### 3.3 Сделайте выводы о данных
# Напишите, заметили ли вы выбросы, необычное распределение количественных признаков или другие особенности;
# расскажите, как вы планируете улучшить данные.

# %% [markdown]
# **Удой (удой_кг)**
#
# Boxplot: подтверждает мощный выброс. Один экстремальный случай около 45 000 кг.
#
# Вывод: выброс очень сильный. Это может исказить линейную модель, поэтому: удаляем.
#
# **ЭКЕ (эке_энергетическая_кормовая_единица)**
#
# Boxplot: почти идеален — нет выбросов.
#
# Вывод: признак можно использовать в модели без обработки.
#
# **Сырой протеин (сырой_протеин_г)**
#
# Boxplot: видно несколько умеренных выбросов справа (выше 2300 г).
#
# Вывод: выбросов немного, можно оставить как есть.
#
# **СПО-сахаро-протеиновое соотношение**
#
# Boxplot: почти все данные внутри, выбросов нет.
#
# Вывод: можно оставить без изменений. Но помним, что распределение двугорбое — возможно, есть скрытые группы.
#
# **Жирность (жирность_проц)**
#
# Boxplot: много выбросов снизу — жирность ниже 3.5% сильно выделяется.
#
# Вывод: эти данные могут представлять "слабых" коров. Оставим, это поможет нам изучить влияние на вкус.
#
# **Белок (белок_проц)**
#
# Boxplot: несколько очень лёгких выбросов по краям.
#
# Вывод: признак можно использовать без обработки. Отличная форма.

# %%
# Сначала посмотрим на ТОП-значения удой_кг:
main_df['удой_кг'].sort_values(ascending=False).head(10)
# Out:
# 16     45616
# 70      7222
# 135     7207
# 296     7201
# 294     7197
# 593     7174
# 46      7173
# 176     7141
# 264     7133
# 194     7113
# Name: удой_кг, dtype: int64

# %% [markdown]
# Значение 45616 кг — это экстремальный выброс, примерно в 6 раз выше следующего значения (7222 кг).
#
# Остальные значения от 7100 до 7200 кг выглядят реалистично и гладко распределены, скорее всего, это верхушка нормального распределения. 45616 кг — это явный выброс, удалим его.

# %%
# Удалим только максимальное значение (45616 кг) и сброим индексы
main_df = main_df[main_df['удой_кг'] != main_df['удой_кг'].max()].reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Есть, отлично, выброс по удою обнаружен и удален в таблице с текущим стадом фермера.
#
# </div>

# %%
# Проверим результат после удаления макс значения удоя (45616 кг)

plt.figure(figsize=(8, 4))
sns.boxplot(x=main_df['удой_кг'])
plt.title('Boxplot без экстремального выброса')
plt.show()

# Проверим распределение после удаления макс значения удоя (45616 кг)
plt.figure(figsize=(8, 4))
sns.histplot(main_df['удой_кг'], kde=True, bins=30)
plt.title('Гистограмма удой_кг после удаления выброса')
plt.show()

# %% [markdown]
# **Boxplot без экстремального выброса:**
#
# После удаления экстремального выброса видно что диапазон удоя стал визуально адекватным и информативным.
#
# Нижняя граница — около 5250 кг, верхняя — около 7250 кг.
#
# Медиана — примерно 6200–6300 кг. Распределение выглядит умеренно симметричным, без сильных перекосов.
#
# **Вывод:** Удаление экстремального значения позволило корректно отобразить центральную тенденцию и межквартильный размах.
#
# **Гистограмма удой_кг после удаления выброса:**
#
# Распределение немного скошено вправо (правосторонняя асимметрия).
#
# Пик находится в районе 6200–6600 кг.
#
# Данных в диапазоне >7000 кг немного, но они больше не являются выбросами.
#
# **Вывод:**
#
# В целевом признаке распределение после удаления стало гладким, что положительно скажется на работе моделей.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Выводы по гистограммам и/или боксплотам (то что вижу я ... для сопоставления наших позиций):
#
# - явная бимодальность в данных. Т.е. надо углублять в анализы подгрупп, прежде чем делать какие-то выводы.
#
# - есть супервыброс по удою. Остальные точки на "ящиках с усами" - можно считать приемлимыми значениями на данном этапе. При моделировании (когда будем выполнять анализ остатков) посмотрим детальнее.
#
# - признаки СПО и Жирность: есть подозрение, что их лучше перевести в категориальную шкалу, т.к. есть большая ассиметрия - скорее всего тут прячутся две-три группы.
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#         Действительно видны признаки бимодальности СПО. А признак жирность по твоему предложению далее переведем в категориальный и разобьем на 3 подгруппы. Спасибо за ценный инсайт!
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Данные загружены, отлично.
#
# Хорошо, что применяешь метод .head()/.sample() таким образом в память не будет загружен весь датасет, объем которого может быть огромным.
#
# Методы .info, .describe, .value_counts(), .unique() как правило часто встречаются и обязательны к применению в задачах по исследованию данных, ведь с их помощью можно получить первые инсайты.
#
# Итак, мы провели предварительный анализ данных, проверили данные на наличие пропусков и затем обработали их (аргументированно заполнили / удалили / оставили как есть). Провели графический анализ. Сделали и озвучили выводы. Теперь можно приступать собственно к моделированию и ответам на вопросы проекта.
#
# </div>

# %% [markdown]
# ## Шаг 4. Корреляционный анализ

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Смотришь скоррелированность признаков - отлично! Об этом чуть ниже подробней напишу....
#
# ---
# p.s. присмотрись к библиотеке phik! Она (Phi_K correlation) представляет собой инструмент для вычисления и визуализации корреляции между категориальными и количественными переменными. Она может быть полезной в анализе данных перед построением моделей машинного обучения, так как позволяет обнаружить скрытые взаимосвязи между переменными, которые могли бы остаться незамеченными при обычных методах корреляционного анализа.
# Преимущества использования **phik**:
#
# 1. **Учет категориальных переменных**: Традиционные методы вычисления корреляции, такие как коэффициент корреляции Пирсона, применяются только к количественным переменным. phik позволяет вычислять корреляцию между категориальными и количественными переменными, что делает его мощным инструментом для анализа разнообразных типов данных.
#
# 2. **Обнаружение нелинейных зависимостей**: phik способен обнаруживать нелинейные связи между переменными, которые могли бы быть упущены традиционными методами. Это особенно важно в анализе данных, где зависимости могут быть сложными и нелинейными (что может влиять на твой выбор признаков для моделей МО).
#
# 3. **Подходит для больших наборов данных**: phik обладает хорошей масштабируемостью, что позволяет использовать его для анализа больших наборов данных без серьезного снижения производительности.
#
# 4. **Визуализация результатов**: Библиотека предоставляет инструменты для визуализации матрицы корреляции между переменными, что помогает лучше понимать зависимости в данных.
#
# Вот пример кода, как использовать phik для вычисления корреляции:
#
#     # Установим "руками", если не установлена
#     !pip install phik -q
#
#     # Импортируем
#     import phik
#     import pandas as pd
#
#     # Загрузка данных
#     data = pd.read_csv('data.csv')
#
#     # Вычисление матрицы корреляции с использованием phik
#     corr_matrix = data.phik_matrix(interval_cols= ...)
#
#     # Визуализация матрицы корреляции
#     import seaborn as sns
#     import matplotlib.pyplot as plt
#
#     plt.figure(figsize=(10, 8))
#     sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
#     plt.title('Phi_K Correlation Matrix')
#     plt.show()
#
# p.s. у этой библиотеки есть ограничение с которым я например сталкивался: когда в даных есть столбцы с очень большим количеством уникальных значений, то phik может "упасть" с сообщением об ошибке (суть которого в том, что не хватает памяти для обработки такого количества "уников"). При этом на компьютере у меня 32 Гб памяти и большая часть её не занята. Я подозреваю что это некое внутреннее ограничение библиотеки.
# </div>

# %% [markdown]
# ### 4.1 Изучите взаимосвязь между признаками: рассчитайте коэффициенты корреляции между всеми признаками.

# %% [markdown]
# Рассчитаем корреляционную матрицу между количественными признаками. Это нам поможет:
#
# - выявить влиятельные переменные;
#
# - понять, какие признаки сильно связаны с целевым удой_кг;
#
# - возможно обнаружим мультиколлинеарность (избыточно скоррелированные признаки между собой).

# %%
# Создадим список количественных признаков (без id):

num_features = [
    'удой_кг',
    'эке_энергетическая_кормовая_единица',
    'сырой_протеин_г',
    'спо_сахаро-протеиновое_соотношение',
    'жирность_проц',
    'белок_проц'
]

# Рассчитаем корреляционную матрицу по Спирмену
corr_matrix_spearman = main_df[num_features].corr(method='spearman')

# Визуализация
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix_spearman, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Корреляционная матрица (Спирмен)')
plt.show()

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image-2.png](attachment:image-2.png)
#
# Нормально ли распределены наши признаки? Если нет, то каким методом надо считать коэффициенты корреляции?
#
# Небольшая напоминалка на скрине: Пирсон - это дефолтный метод.
# </div>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#         Так как количественные признаки не распределены нормально (имеют скошенность, выбросы, бимодальность), то для оценки корреляций применим метод Спирмена. Он устойчив к таким особенностям распределения и даёт более надёжную картину связей между признаками в наших данных. Исправил код и скорректировал выводы на основе обновленных результатов! Спасибо за профессиональный совет!
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
#
# Есть, отлично, понимание структуры данных дает нам основание использовать метод Спирмена/Кендалла, а не Пирсона (при оценки степени корреляции признаков).
#
# Присоединяю табличку в помощь (и для последующих повторных обращений к ней):
# </div>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Обновленные выводы:
#
# **Сильные положительные связи:**
#
# удой_кг — спо_сахаро-протеиновое_соотношение: 0.79
#
# Увеличение СПО связано с увеличением удоя. Это может быть важный фактор при отборе.
#
# удой_кг — эке_энергетическая_кормовая_единица: 0.76
#
# Чем больше энергии в корме — тем выше удой.
#
# спо — эке: 0.74
#
# Они тесно связаны между собой, что логично: СПО — производная от состава рациона.
#
# удой_кг — жирность_проц: 0.69
#
# Интересный факт: жирность тоже растёт с удоем (возможно, лучше питание).
#
# **Умеренные связи:**
#
# удой_кг — сырой_протеин_г: 0.44
#
# Протеин влияет, но слабее, чем ЭКЕ и СПО.
#
# сырой_протеин_г — жирность_проц: 0.39
#
# Лёгкая связь: возможно, жирность немного зависит от протеина.
#
# **Слабая или отсутствующая связь:**
#
# белок_проц почти со всеми: значения от -0.01 до 0.23
#
# Этот признак почти не связан с другими, его влияние автономно.
#
# Важно: это хорошо для модели логистической регрессии (низкая мультиколлинеарность).
#
# **Что учитывать для моделей:**
#
# Между "эке" и "спо": сильная корреляция → можно оставить только один в простых моделях, или провести PCA.
#
# Удой зависит сразу от нескольких факторов, и ни один из них не даёт полной картины — логично применять линейную регрессию.
#
# Белок — независимый предиктор, может быть полезен для классификации вкуса.

# %% [markdown]
# **Что изменилось? по Спирмену vs по Пирсону**
#
# **Новый интересный момент:**
#
# удой — жирность по Спирмену = 0.69
#
# Это намного ближе к сильной корреляции, чем казалось при Пирсоне (0.60). Роль жирности стала более важнее, чем раньше.
#
# Межпризнаковые связи (мультиколлинеарность):
#
# спо и эке — Спирмен 0.74 (против 0.75 по Пирсону): остаются сильно связанными.
#
# Остальные (например, сырой протеин) всё ещё коррелируют слабо — это хорошо, они дают уникальную информацию.
#
# **Подтвердилось:**
#
# СПО и ЭКЕ — сильнейшие предикторы удоя.
#
# Белок — бесполезен для регрессии.
#
# Сырой протеин — можно оставить, слабая но положительная связь.
#
# СПО и ЭКЕ коррелируют между собой — в модели стоит отслеживать мультиколлинеарность.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Выводы **с учётом того, что уже выполено тобой в проекте, выше** (то что вижу я ... для сопоставления наших позиций):
#
# - очень высоких корреляций (0.9 +) не видно, скорее всего мультиколлинеарности нет.
#
# - есть подозрение на нелинейность связи удоя с "спо" и "жирностью".
#
# - по спо: постоянная зависимость на разных уровнях. до 0.91 - одна зависимость с целевой. После 0.91 - иная. Просто "видим" две группы (некоторые "видят" 3). Надо ввести новую категориальную переменную: "спо менее 0.9"/"спо более 0.9".
#
# - По жирности: история такая же. Наблюдается три зоны с разной зависимостью с целевой: до 3.5, и ещё две - на моем графике все 3 выделены красными прямоугольниками.
# </div>

# %% [markdown]
# ### 4.2 Постройте диаграммы рассеяния scatterplot для признака Удой, кг и всех количественных признаков с учётом значения категориальных признаков. Пример: диаграмма рассеяния для Удой, кг и Сырой протеин, г, цвет точек диаграммы отображает признак Порода. Учитывайте, что виды связи в подгруппах могут различаться — например, для разных пород.

# %%
# Список количественных признаков (числовых данных)
quant_features = ['эке_энергетическая_кормовая_единица',  
                  'сырой_протеин_г', 
                  'спо_сахаро-протеиновое_соотношение', 
                  'жирность_проц',
                  'белок_проц'] 

# Список категориальных признаков
cat_features = ['порода',
                'тип_пастбища',
                'порода_папы_быка',
                'вкус_молока',
                'возраст']

# Для каждого категориального признака из списка cat_features
for cat_col in cat_features:
    # Выводим название текущего категориального признака для удобства
    print(f'Hue по признаку: {cat_col}')
    
    # Создаем фигуру для графиков с размерами 16x10 дюймов
    plt.figure(figsize=(16, 10))

    # Для каждого количественного признака из списка quant_features
    for i, num_col in enumerate(quant_features):
        # Создаем подграфик, расположенный в 2 строках и 3 столбцах
        plt.subplot(2, 3, i+1)
        
        # Строим диаграмму рассеяния с учетом категориального признака (цвет точек зависит от значения признака)
        sns.scatterplot(data=main_df, x=num_col, y='удой_кг', hue=main_df[cat_col], alpha=0.6)
        
        # Добавляем заголовок, который указывает на сочетание количественного признака и категориального признака
        plt.title(f'{num_col} vs удой_кг\n(hue = {cat_col})')
        
        # Подписываем оси
        plt.xlabel(num_col)
        plt.ylabel('удой_кг')

    # Настроить расположение графиков без перекрытия
    plt.tight_layout()
    
    # Отображаем все графики
    plt.show()
# Out:
# Hue по признаку: порода
# Hue по признаку: тип_пастбища
# Hue по признаку: порода_папы_быка
# Hue по признаку: вкус_молока
# Hue по признаку: возраст

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# ![image-2.png](attachment:image-2.png)
#
# На примере моего(!) скрина отчётливо видно что ЭКЕ с удоем связно нелинейно (квадратично) и возведение ЭКЕ в степень улучшит наверняка линейную модель.
#
# Также видно что СПО имеет смысл перевести в категорию (на уровне между 0.91 - 0.92, примерно ... тоже на примере моего скрина).
#
# p.s. **Эти 2 графика (с "добавлениями" на них) - они к тому, что волшебства в решении сделать СПО категориальным, а ЭКЕ квадратичным нет. Это решение мы принимаем не потому что нас осенило, а потому что нам графики это показывают. Это первый важный момент который не всегда мы чётко понимаем. Но есть и 2ой важный момент. Визуализации в ДА/ДС проекте - это не просто "красивые картинки". Это отображение данных в том виде, который позволяет РЕШЕНИЯ ПРИНИМАТЬ.**
# </div>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#         Видна вогнутая кривая, похожая на параболу: это действительно говорит о нелинейной связи между ЭКЕ и удоем. На графике видно: удой сначала растёт быстро, потом медленнее — типичная квадратичная зависимость. СПО имеет смысл перевести в категорию (на уровне между 0.91 - 0.92). Спасибо за подсказку!
#     </font>
# </div>

# %% [markdown]
# **Hue по признаку: порода**
#
# На изображении представлены диаграммы рассеяния между удоем (удой_кг) и различными количественными признаками, где цвет (hue) показывает породу коровы:
#
# 🔵 Синий — вис бик айдиал
#
# 🟠 Оранжевый — рефлешнсоверинг
#
# Подробный анализ по каждому графику:
#
# 1. Эке_энергетическая_кормовая_единица vs удой_кг
#
# Заметна чёткая положительная зависимость: чем выше энергетическая кормовая ценность, тем выше удой.
# Обе породы показывают сходную положительную тенденцию, но кажется, что у породы вис бик айдиал больше точек с высоким удоем при высоких значениях кормовой единицы.
#
# Вывод: энергетическая кормовая единица — сильный фактор для удоя. Порода может немного влиять, но не критично.
#
# 2. Сырой_протеин_г vs удой_кг
#
# Связь между признаками слабая: точки раскиданы хаотично.
# Разделения по породе не прослеживается — распределение обеих пород равномерное.
#
# Вывод: сырой протеин не сильно влияет на удой, и порода тут значения не имеет.
#
# 3. Спо_сахаро-протеиновое_соотношение vs удой_кг
#
# Значения признака дискретны (много точек на одной вертикали).
# Породы перемешаны — нет явной зависимости ни от соотношения, ни от породы.
#
# Вывод: данный признак не влияет на удой, влияние породы также не видно.
#
# 4. Жирность_проц vs удой_кг
#
# Почти все значения жирности — около 3.7%.
# Точки обеих пород смешаны, нет выраженного разделения.
#
# Вывод: жирность стабильна, и порода не влияет на удой в этом контексте.
#
# 5. Белок_проц vs удой_кг
#
# Значения белка очень узкие — почти по вертикали.
# Небольшой визуальный сдвиг вверх у породы рефлешнсоверинг, но он неубедительный и может быть случайным.
#
# Вывод: признак белок_проц слабо влияет на удой. Порода тоже не оказывает существенного влияния.
#
# **Общие выводы:**
#
# Эке_энергетическая_кормовая_единица — самый значимый признак для предсказания удоя.
#
# Порода оказывает незначительное влияние на удой. Возможна слабая тенденция у породы "вис бик айдиал" к немного большему удою при одинаковых условиях кормления.
#
# По остальным признакам (сырой протеин, жирность, белок, соотношение сахара/протеина) нет выраженной зависимости ни от признака, ни от породы.
#
# При построении модели предсказания удоя стоит: оставить признак "порода", но ожидать от него слабой значимости сосредоточиться на "эке_энергетическая_кормовая_единица" как ключевом факторе.

# %% [markdown]
# **Hue по признаку: тип_пастбища**
#
# На графике показана зависимость удоя (в кг) от различных количественных признаков, при этом цвет точек (hue) обозначает тип пастбища:
#
# 🔵 Синие точки — равнинное пастбище
#
# 🟠 Оранжевые точки — холмистое пастбище
#
#
# 1. Эке_энергетическая_кормовая_единица vs удой_кг
#
# Заметна положительная линейная зависимость: с ростом энергетической кормовой единицы увеличивается удой.
# Тип пастбища почти не влияет: точки обоих типов (равнинное и холмистое) расположены схожим образом, зависимости одинаковые.
#
# Вывод: энергетическая кормовая единица — сильный предиктор удоя, тип пастбища здесь не влияет.
#
# 2. Сырой_протеин_г vs удой_кг
#
# Связь между сырым протеином и удоем размытая и неявная.
# Оба типа пастбища распределены равномерно и хаотично, без различий в тренде.
#
# Вывод: сырые протеины слабо связаны с удоем, влияние типа пастбища не наблюдается.
#
# 3. Спо_сахаро-протеиновое_соотношение vs удой_кг
#
# Видны горизонтальные кластеры, что может свидетельствовать об ограниченном количестве уникальных значений этого признака.
# Различий между типами пастбищ не видно — распределение точек практически идентично.
#
# Вывод: Сахаро-протеиновое соотношение не имеет явной зависимости с удоем. Тип пастбища не оказывает заметного влияния.
#
# 4. Жирность_проц vs удой_кг
#
# Большая часть значений жирности сосредоточена около 3.7%, и они слабо варьируются.
# Разделения по типу пастбища практически нет, все группы перемешаны.
#
# Вывод: жирность не влияет на удой, а тип пастбища не вносит различий.
#
# 5. Белок_проц vs удой_кг
#
# Значения белка сгруппированы в узком диапазоне (почти по вертикали).
# Заметен небольшой визуальный сдвиг: у коров с холмистого пастбища удой чуть выше в верхней части графика, но различие незначительное.
#
# Вывод: признак "белок_проц" слишком стабилен, тип пастбища может иметь очень слабое влияние.
#
# **Общие выводы:**
#
# Тип пастбища (равнинное или холмистое) не оказывает заметного влияния на удой при сравнении с основными количественными признаками.
#
# Наиболее выраженная зависимость между признаком и удоем наблюдается: эке_энергетическая_кормовая_единица (прямая линейная связь).
#
# Остальные признаки (сырой протеин, белок, жирность и соотношение сахара/протеина) либо имеют слабую, либо нечёткую зависимость от удоя.
#
# Разделение по типу пастбища не приводит к различным трендам, что может означать, что он не является значимым фактором при моделировании удоя.

# %% [markdown]
# **Hue по признаку: порода_папы_быка**
#
# На графиках изображена зависимость удоя (удой_кг) от различных количественных признаков, где цвет точек (hue) отражает породу отца быка:
#
# 🔵 Синий — айдиал
#
# 🟠 Оранжевый — соверин
#
# Разберём каждый график:
#
# 1. Эке_энергетическая_кормовая_единица vs удой_кг
#
# Заметна сильная положительная зависимость: с ростом кормовой энергетической единицы увеличивается удой.
#
# Разделение по породе отца отчётливо:
#
# потомки быков айдиал чаще встречаются среди коров с высоким удоем;
#
# потомки соверина чаще — в нижней части графика (меньший удой).
#
# Вывод: порода отца влияет на удой: айдиал — более продуктивное потомство.
#
# 2. Сырой_протеин_г vs удой_кг
#
# Общая связь между признаками слабая.
# Однако видно, что у потомков айдиала чаще встречаются высокие значения удоя, даже при одинаковом уровне протеина.
#
# Вывод: хотя сам признак не связан с удоем напрямую, порода отца (айдиал) может играть роль.
#
# 3. Спо_сахаро-протеиновое_соотношение vs удой_кг
#
# Структура разреженная (дискретные значения признака).
# Породы отца распределены равномерно, различий по удою не наблюдается.
#
# Вывод: ни порода отца, ни сам признак не оказывают явного влияния.
#
# 4. Жирность_проц vs удой_кг
#
# Значения жирности сконцентрированы около 3.7%. Но даже в этих условиях у потомков айдиала удой чаще выше.
#
# Вывод: жирность стабильна, но айдиал снова показывает лучшие удои.
#
# 5. Белок_проц vs удой_кг
#
# Признак почти не меняется (вертикальные полосы). Но, как и прежде, у потомков айдиала больше точек в верхней части по удою.
#
# Вывод: при одинаковом уровне белка, айдиал даёт больше удоя.
#
# **Общие выводы:**
#
# Порода отца быка — важный фактор, особенно заметный при анализе с энергетической кормовой единицей.
#
# Потомки айдиала стабильно показывают больший удой, вне зависимости от значения других признаков.
#
# Важнейшие признаки в контексте этого анализа: эке_энергетическая_кормовая_единица, порода_папы_быка.
#
# Рекомендуется включить признак порода_папы_быка в модель предсказания удоя — он показывает заметный вклад в результат.

# %% [markdown]
# **Hue по признаку: вкус_молока**
#
# На графиках показана зависимость удоя (удой_кг) от различных количественных признаков, при этом цвет (hue) показывает категориальный признак вкус_молока:
#
# 🔵 Синий — вкусно
#
# 🟠 Оранжевый — не вкусно
#
# Разберем каждый график по отдельности:
#
# 1. Эке_энергетическая_кормовая_единица vs удой_кг
#
# Заметна чёткая положительная зависимость — с ростом кормовой энергетической единицы растёт и удой.
# Точки "вкусного" и "невкусного" молока перемешаны, но: наблюдается незначительное смещение — у коров с "вкусным" молоком немного больше точек с высоким удоем.
#
# Вывод: удой зависит от энергетической кормовой единицы, а вкус молока — возможно, слабый косвенный маркер более высокой продуктивности, но влияние незначительное.
#
# 2. Сырой_протеин_г vs удой_кг
#
# Связь между сырым протеином и удоем хаотична, точки распределены без выраженной структуры.
# Разделения по вкусу нет — и "вкусное", и "невкусное" молоко встречается при любых значениях.
#
# Вывод: ни сырой протеин, ни вкус молока здесь не влияют на удой.
#
# 3. Спо_сахаро-протеиновое_соотношение vs удой_кг
#
# Горизонтальные полосы указывают на дискретные значения.
# Обе категории вкуса равномерно распределены, разницы не видно.
#
# Вывод: этот признак не влияет на удой, а вкус молока никак не связан с ним в этом контексте.
#
# 4. Жирность_проц vs удой_кг
#
# Основное скопление жирности — около 3.7%, сильной вариативности нет.
# Синие точки ("вкусно") немного преобладают при высоком удое, но различие визуально слабое.
#
# Вывод: жирность стабильна, возможно, вкусное молоко чуть чаще встречается у более продуктивных коров, но без выраженной связи.
#
# 5. Белок_проц vs удой_кг
#
# Показатель белка почти не варьируется.
# Цвета точек перемешаны, никакой зависимости от вкуса не видно.
#
# Вывод: признак не влияет на удой, и вкус молока здесь не информативен.
#
# **Общие выводы:**
#
# Основная зависимость между удоем и признаками сохраняется у эке_энергетическая_кормовая_единица.
#
# Признак вкус_молока может быть слабо связан с удоем, но: в целом он не влияет существенно; не создаёт разных трендов в данных; может быть лишь вторичным следствием других факторов (например, хорошее кормление и высокий удой = вкусное молоко).

# %% [markdown]
# **Hue по признаку: возраст**
#
# На графиках представлена зависимость удоя (удой_кг) от различных количественных признаков, где цвет точек (hue) обозначает категориальный признак возраст:
#
# 🔵 Синий — более_2_лет
#
# 🟠 Оранжевый — менее_2_лет
#
# Разберем каждый график:
#
# 1. Эке_энергетическая_кормовая_единица vs удой_кг
#
# Очень сильная положительная зависимость. При этом видно, что:
#
# Коровы старше 2 лет (синие точки) демонстрируют более высокие удои при любых значениях энергетической единицы.
#
# Коровы моложе 2 лет — всегда в нижнем диапазоне удоев.
#
# Вывод: возраст — значимый фактор. Более взрослые коровы дают значительно больше молока при равных условиях кормления.
#
# 2. Сырой_протеин_г vs удой_кг
#
# Нет выраженной зависимости между количеством протеина и удоем. Однако:
#
# У коров старше 2 лет удой в среднем сильно выше, чем у молодых.
#
# У молодых коров (оранжевые точки) значения удоя сконцентрированы внизу.
#
# Вывод: протеин не влияет напрямую, но возраст чётко разделяет группы по удою.
#
# 3. Спо_сахаро-протеиновое_соотношение vs удой_кг
#
# Признак имеет дискретную структуру. Тем не менее:
#
# У коров старше 2 лет удои заметно выше при любых значениях признака.
#
# У коров младше 2 лет значения в нижней части графика.
#
# Вывод: сам признак слабый, но возраст стабильно связан с более высоким удоем.
#
# 4. Жирность_проц vs удой_кг
#
# Значения жирности сгруппированы вокруг 3.7%. Но:
#
# У коров более 2 лет — весь диапазон удоя, включая высокие значения.
#
# У молодых — удой всегда низкий.
#
# Вывод: жирность не влияет на удой, но возраст чётко отделяет продуктивных коров.
#
# 5. Белок_проц vs удой_кг
#
# Признак почти не варьируется. Тем не менее:
#
# У коров старше 2 лет удой охватывает весь диапазон.
#
# У младших — удой стабильно ниже.
#
# Вывод: белок не информативен, но возраст влияет на результат.
#
# **Общие выводы:**
#
# Возраст — один из самых сильных факторов, влияющих на удой. Во всех графиках коровы моложе 2 лет имеют значительно меньший удой независимо от значений других признаков.
#
# Следовательно:
#
# - возраст нужно обязательно включать в модель предсказания;
#
# - его можно даже рассматривать как границу сегментации данных (разные модели для разных возрастов).

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Выводы **с учётом того, что уже выполено тобой в проекте, выше** (то что вижу я ... для сопоставления наших позиций):
#
# - можем сказать, что выводы теже, что и в пункте выше: есть не линейность с спо и жирностью во всех группах. Однозначно стоит создавать новые факторы.
#
# - по мультиколлинеарности: скорее всего её нет (нет "узкого облака", похожего на четкую линейную зависимость).
#
# - по эке - возможно иная зависимость между целевой и эке. Наверное надо попробовать "ввести нелинейность" (квадрат этого фактора), чтобы учесть кривизну. Результат (есть ли положительный эффект) проверим ниже, во 2ой линейной модели.
#
# - отлично видно, что возраст влият на удой. Более молодые коровы меньше дают молока.
#
# - видно, что спо только для возрастных коров используется.
#
# p.s. некоторые зависимости, которые я здесь описываю - я взял не просто из головы, а потому что сам этот проект выполнял (и скаттерплоты (sns.scatterplot()) "рисовал"). Если построишь аналогичные зависимости - увидишь подтверждение моим словам.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Несколько моментов "на будущее" (сейчас забегаю чуть вперед, но будущем это будет важно) которые я хотел озвучить перед переходом к собственно исследованию (некоторые из этих моментов в твоем проекте реализованы):
#
# - имеет смысл критично посмотреть на данные с точки зрения наличия пропусков в признаках (вопрос: все ли ml-модели "любят" пропуски?) и обработать или удалить их
#
# - имеет смысл явно обозначить какую задачу мы будем решать: с учителем / без учителя, классификации / регрессии ...
#
# - в моделях бинарной классификации (если бы это был бы наш случай!) имеет смысл смотреть на баланс классов. Два взгляда (с разных сторон) на эту проблему тут: https://alexanderdyakonov.wordpress.com/2021/05/27/imbalance/ и https://habr.com/ru/post/349078/
#
# - имеет смысл смотреть на корреляцию признаков. При высокой их степени коррелированности возникает проблема  мультиколлиниарность признаков. Проблема "мультиколлинеарности" это и про переобучение модели и про её интерпретируемость и про сложность модели (содержание в модели избыточного количества переменных). В чем негативный эффект сложной модели? Вот в чем: усложняется интерпретация параметров, оценки параметров ненадежны – получаются большие стандартные ошибки, которые меняются с изменением объема наблюдений, что делает модель регрессии непригодной для прогнозирования.
#
# <br>
# <br>
# <details>
# <summary style="color: blue; font-size: 18px; font-weight: bold;">▶ <u>Подробнее ...</u></summary>
#
# Вот несколько причин, почему проблема мультиколлинеарности (МК) важна:
#
# 1. Неоднозначность коэффициентов: МК делает оценку коэффициентов модели неустойчивой. Когда существует сильная корреляция между признаками, модель становится неспособной разделить влияние каждого признака на целевую переменную. Это может привести к неоднозначным и неправильным оценкам коэффициентов, что затрудняет интерпретацию важности каждого признака. Согласись - это важно, чтобы результат, который выдает модель можно было бы понять и объяснить с точки зрения предметной области. В случае включения в модель высокоскоррелированных признаков - может случиться так, что коэффициенты (да, проблема присуща моделям линейным ... регрессия среди них!) могут менять знаки и попытка объяснения предметной области с помощью этих коэффициентов будет противоречить здравому смыслу.
#
# 2. Плохая обобщающая способность: МК может снизить способность модели обобщаться на новые данные. Когда сильно коррелированные признаки присутствуют в модели, модель может стать "перегенерированной" и склонной к переобучению на обучающих данных. В результате модель может показывать хорошую производительность на обучающих данных, но плохо обобщаться на новые данные.
#
# 3. Ухудшение точности и устойчивости модели: МК может привести к численным проблемам при решении линейных уравнений, используемых для оценки коэффициентов модели. Это может привести к нестабильности и неточности оценок. Кроме того, небольшие изменения в данных могут привести к большим изменениям в оценках коэффициентов модели, что делает модель неустойчивой.
#
# 4. Избыточность информации: Когда признаки сильно коррелированы, они предоставляют практически одинаковую информацию о целевой переменной. Такая избыточность может привести к неэффективности модели и увеличению сложности модели без значительного улучшения производительности.
#
# В целом, МК может иметь отрицательное влияние на производительность, стабильность, интерпретируемость и обобщающую способность.
#
# ---
# Для деревянных моделей и моделей градиентного бустинга проблема МК  не является такой критической, как для линейных моделей. Вот несколько причин:
#
# 1. Нелинейность: Деревянные модели и модели градиентного бустинга являются нелинейными моделями. Они способны обрабатывать сложные взаимодействия между признаками и целевой переменной. В отличие от линейных моделей, они могут более гибко адаптироваться к наличию мультиколлинеарности в данных.
#
# 2. Рекурсивное разбиение: Деревья принятия решений в деревянных моделях и моделях градиентного бустинга используют рекурсивное разбиение для разделения данных на более чистые группы. Это означает, что деревья могут независимо выбирать разные признаки для разделения, даже если они сильно коррелированы. Таким образом, деревья могут игнорировать мультиколлинеарность и использовать другие признаки для принятия решений.
#
# 3. Ансамбль деревьев: Модели градиентного бустинга строятся на основе ансамбля слабых деревьев решений. Каждое дерево добавляется постепенно для уменьшения ошибки предыдущих деревьев. Это позволяет модели градиентного бустинга восстанавливать ошибки, вызванные мультиколлинеарностью, поэтапно улучшая прогнозы.
#
# Хотя мультиколлинеарность не является проблемой в деревянных моделях и моделях градиентного бустинга в той же степени, что и в линейных моделях, она все еще может оказывать влияние на производительность и интерпретируемость модели. Сильно коррелированные признаки могут вносить избыточность в модель и увеличивать сложность, не принося значительного улучшения в прогнозах. Поэтому, хотя деревья могут быть более устойчивыми к мультиколлинеарности, все же рекомендуется выполнять анализ корреляции признаков и, при необходимости, применять методы снижения размерности или регуляризации для улучшения модели.
#
# Вот классная статья. Простым языком, на примере показана проблема. А также, что важно - разобраны варианты как её (проблему) победить. Статья: https://habr.com/ru/company/akbarsdigital/blog/592493/
#
# </details>
# <br>
# <br>
# </div>

# %% [markdown]
# ### 4.3 Сделайте выводы о взаимосвязи признаков.
# Какой тип взаимосвязи между целевым и входными признаками? Есть ли нелинейные связи между целевым и входными признаками? Нужно ли вводить в модель дополнительные признаки, чтобы это учесть? Наблюдается ли мультиколлинеарность между входными признаками?

# %% [markdown]
# **Обновленные выводы**
#
# 1. Тип взаимосвязи между целевым и входными признаками.
#
# Анализ матрицы корреляций (по Спирмену) и графиков рассеяния показывает наличие сильных и умеренных монотонных связей между целевым признаком удой_кг и некоторыми входными признаками:
#
# спо_сахаро-протеиновое_соотношение: коэффициент корреляции ≈ 0.79
#
# эке_энергетическая_кормовая_единица: ≈ 0.76
#
# жирность_проц: ≈ 0.69
#
# Это говорит о том, что между этими признаками и удоем наблюдается сильная монотонная зависимость (не обязательно линейная!). Однако, причинно-следственная связь не предполагается — коэффициент корреляции не доказывает, что один признак влияет на другой, он лишь измеряет степень их совместного изменения.
#
# 2. Нелинейные зависимости
#
# На диаграмме рассеяния видно, что между эке_энергетическая_кормовая_единица и удой_кг связь нелинейная, визуально похожая на параболу. Это подтверждает целесообразность добавления квадратичного признака: такой приём поможет линейной модели уловить скрытую нелинейную зависимость.
#
# 3. Категоризация признаков
#
# Признак спо_сахаро-протеиновое_соотношение имеет выраженную ступенчатую структуру значений. В проекте далее он был переведён в бинарную категорию (спо_бинарный) с порогом ≈ 0.915.
#
# Признак жирность_проц распределён неравномерно, с длинным правым хвостом. По твоему профессиональному совету будет выполнена категоризация на низкую / среднюю / высокую жирность, что может быть полезно для модели классификации.
#
# 4. Мультиколлинеарность
#
# Взаимные коэффициенты корреляции между входными признаками показывают умеренную степень мультиколлинеарности:
#
# спо_сахаро-протеиновое_соотношение - эке_энергетическая_кормовая_единица: ≈ 0.74
#
# жирность_проц - эке_энергетическая_кормовая_единица: ≈ 0.69
#
# жирность_проц - спо_сахаро-протеиновое_соотношение: ≈ 0.70
#
# Это указывает на возможность частичного дублирования информации. Для дальнейшей диагностики стоит рассчитать VIF (Variance Inflation Factor) и исключить избыточные признаки при необходимости.
#
# 5. Слабые и нерелевантные признаки
#
# белок_проц: почти отсутствует связь с целевой переменной (корреляция ≈ 0.00), как по графику, так и по матрице Спирмена. Его можно исключить из модели линейной регрессии.
#
# Итог:
#
# Для прогнозирования удоя важно учитывать СПО, ЭКЕ, жирность — с учётом нелинейностей и мультиколлинеарности.
#
# Квадрат ЭКЕ и бинарный СПО — улучшит качество модели. Признак жирность_проц — кандидат на категоризацию.
#
# Использование коэффициента Спирмена позволило лучше учесть нелинейный характер зависимостей, что актуально для наших данных.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image.png](attachment:image.png)
#
# Дьявол кроется в формулировках - говорить так неверно.
#
# ---
# Формулировать, что коэффициент  корреляции между 2 переменными есть показатель того, что один из них **влияет** на другой  - неверно. Корреляция не подразумевает наличие причинно-следственной связи между переменными.
#
# Коэффициент свидетельствует **о наличии или отсутствии линейной связи** между переменными, и **измеряет выраженность** этой связи. Другими словами, коэффициент корреляции - это инструмент, с помощью которого можно проверить гипотезу о **линейной** зависимости и измерить степень этой зависимости.
#
# Понимаешь, нет влияния одного признака на другой. Коэффициент корреляции Пирсона не про это. Он про линейную зависимость 2-х переменных. И ещё, это коэффициент **НЕ ОБЪЯСНЯЕТ** зависимость, он **НЕ ГОВОРИТ** почему наблюдается такой эффект, но просто констатирует факт, что корреляция наблюдается (например: "продажи мороженного увеличиваются когда на улице наблюдается массовый вылет насекомых (мух)". А вот почему мороженное начинается продаваться лучше - можно только предполагать ... разные причины могут быть (но мухи вряд ли на это влияют ... а вот то, что наступает жаркое лето - очень даже влияет)).
#
# Вот смешная статейка на эту тему: https://ktonanovenkogo.ru/voprosy-i-otvety/korrelyaciya-chto-ehto-takoe-prostymi-slovami.html
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      Скорректировал свои выводы выше. Использование коэффициента Спирмена позволило лучше учесть нелинейный характер зависимостей, что актуально для наших данных.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Исправлено.
# </div>

# %%
# Список количественных входных признаков (без целевой переменной)
features = [
    'эке_энергетическая_кормовая_единица',
    'сырой_протеин_г',
    'спо_сахаро-протеиновое_соотношение',
    'жирность_проц',
    'белок_проц'
]

# Создаем датафрейм только с этими признаками
X = main_df[features].copy()

# Добавляем константу (обязательно для корректного расчета VIF)
X_const = add_constant(X)

# Создаем таблицу с результатами
vif_data = pd.DataFrame()
vif_data["Признак"] = X_const.columns
vif_data["VIF"] = [variance_inflation_factor(X_const.values, i) for i in range(X_const.shape[1])]

# Отображаем результат
vif_data
# Out:
#                                Признак           VIF
# 0                                const  1.565940e+06
# 1  эке_энергетическая_кормовая_единица  2.570253e+00
# 2                      сырой_протеин_г  1.342839e+00
# 3   спо_сахаро-протеиновое_соотношение  2.646003e+00
# 4                        жирность_проц  1.875846e+00
# 5                           белок_проц  1.079267e+00

# %% [markdown]
# **VIF (фактор инфляции дисперсии)** позволяет оценить, насколько сильно каждый входной признак коррелирует с другими признаками в модели.
#
# - **VIF от 1 до 5** — признак имеет **слабую или отсутствующую мультиколлинеарность**. Его можно безопасно использовать в модели.
# - **VIF от 5 до 10** — наблюдается **умеренная мультиколлинеарность**. Следует обратить внимание: возможно, признак частично дублирует информацию других переменных.
# - **VIF > 10** — **сильная мультиколлинеарность**. Такой признак желательно **исключить или заменить**, поскольку он может негативно влиять на стабильность и интерпретацию модели.
#
# Таким образом, значения VIF помогают выбрать наиболее информативные и независимые признаки для построения линейных моделей.
#
# **Интерпретация:**
#
# Был выполнен расчёт коэффициента VIF (Variance Inflation Factor) для количественных входных признаков.
# Результаты:
#
# | Признак                                 | VIF     |
# |----------------------------------------|---------|
# | ээ_энергетическая_кормовая_единица     | 2.57    |
# | сырой_протеин_г                         | 1.34    |
# | спо_сахаро-протеиновое_соотношение     | 2.65    |
# | жирность_проц                          | 1.88    |
# | белок_проц                             | 1.08    |
#
#
# - Все признаки имеют **VIF < 5**, что указывает на **отсутствие серьёзной мультиколлинеарности**.
# - Признаки `ээ_энергетическая_кормовая_единица` и `спо_сахаро-протеиновое_соотношение` демонстрируют **умеренную корреляцию между собой**, но их VIF остаётся в допустимых пределах.
# - Остальные признаки (`сырой_протеин_г`, `жирность_проц`, `белок_проц`) имеют **низкие значения VIF** — мультиколлинеарность отсутствует.
# - Признак `белок_проц`, несмотря на допустимый VIF, по результатам корреляционного анализа не связан с целевым признаком `удой_кг` (r = 0.00), и может быть исключён из модели как неинформативный.
#
# **Вывод:**
# Все признаки можно безопасно использовать в модели линейной регрессии. При необходимости можно исключить `белок_проц` для упрощения модели, так как он не влияет на результат. Дополнительные меры борьбы с мультиколлинеарностью (например, регуляризация или удаление признаков) **не требуются**.

# %% [markdown]
# **Признак белок_проц может повлиять на вкус молока, хоть он и не связан с удоем.**

# %%
# Проверим, влияет ли белок_проц на вкус молока: построим boxplot:
sns.boxplot(x='вкус_молока', y='белок_проц', data=main_df)
plt.title('Распределение белка по категориям вкуса молока')
plt.show()

# %% [markdown]
# Медианы отличаются — это сигнал, что зависимость есть.

# %%
# Проведем t-тест между группами: 'вкусно' vs 'не вкусно'
group1 = main_df[main_df['вкус_молока'] == 'вкусно']['белок_проц']
group2 = main_df[main_df['вкус_молока'] == 'не вкусно']['белок_проц']

stat, p = ttest_ind(group1, group2, equal_var=False)
print(f'p-value: {p:.4f}')
# Out:
# p-value: 0.0013

# %% [markdown]
# **Корректный вывод:**
#
# p-value: 0.0013 — это значение значительно меньше порогового уровня значимости 0.05.
#
# Следовательно, у нас есть статистические основания отвергнуть нулевую гипотезу о равенстве средних значений белок_проц между группами «вкусно» и «не вкусно».
#
# Вывод:
#
# Между двумя группами — «вкусно» и «не вкусно» — наблюдается статистически значимая разница в уровне белка.
# Это не означает, что белок влияет на вкус, но позволяет предположить, что белок может быть важным фактором для модели классификации.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image.png](attachment:image.png)
#
# Нельзя сделать вывод, что тест "подтвердил" одну из гипотез (в статистике гипотезы подтвердить невозможно) или "подтвердил" равенство/неравенство (можно говорить только о статистически (не)значимом различии). Например так: «У нас нет оснований утверждать, что средние пользовательские рейтинги платформ Xbox One и PC значимо различаются».
#
# И ещё на эту же тему: никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана. Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу. Статья на эту тему: https://allatambov.github.io/psms/pdf/hypo-test.pdf
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      Я перечитал теорию и исправил предыдущий вывод на корректный. Мы не доказываем причинно-следственную связь, а лишь фиксируем факт различий между группами. В статистике мы никогда не подтверждаем гипотезу — мы можем только либо отвергнуть нулевую гипотезу, либо не отвергнуть её на основе данных. Это важный вывод, который я запомнил. Спасибо за профессиональный комментарий.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Исправлено.
# </div>

# %% [markdown]
# ## Шаг 5. Обучение модели линейной регрессии

# %% [markdown]
# Предстоит обучить три модели простой линейной регрессии.

# %% [markdown]
# ### 5.1 Подготовьте данные датасета ferma_main.csv и обучите на них первую модель LinearRegression.

# %% [markdown]
# **Подготовка данных для первой модели линейной регрессии**
#
# 1. Целевой признак: удой_кг
#
# 2. Признаки для модели оставим только те, у которых есть логическая связь с целевым признаком и подтверждена визуальным и корреляционным анализом:
#
# **Количественные признаки:**
#
# - эке_энергетическая_кормовая_единица
#
# - сырой_протеин_г
#
# - спо_сахаро-протеиновое_соотношение
#
# - жирность_проц
#
# **Категориальные признаки:**
#
# - порода
#
# - тип_пастбища
#
# - порода_папы_быка
#
# - возраст
#
# **Примечание:** признак белок_проц мы исключаем, так как его корреляция с удоем равна нулю и логической зависимости тоже не прослеживается.

# %% [markdown]
# **Что нам нужно сделать:**
#
# Удалить id перед обучением модели. Преобразовать категориальные признаки через OneHotEncoder. Масштабировать числовые признаки через StandardScaler. Разделить данные на train и test. Обучить модель LinearRegression. Посчитать R² и визуализировать остатки.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# id из признаков подаваемых в модель МО - верно удаляешь. Он НЕ информативен в этой роли (так как является просто инкрементом, порядковым номером коровы).
# </div>

# %%
# Целевой признак и входные признаки
target = 'удой_кг'
num_features = [
    'эке_энергетическая_кормовая_единица',
    'сырой_протеин_г',
    'спо_сахаро-протеиновое_соотношение'
    # исключили 'жирность_проц', так как она не влияет на удой
]
cat_features = ['порода', 'тип_пастбища', 'порода_папы_быка', 'возраст']

# Подготовка данных
main_df_model = main_df.drop(columns=['id'])
X = main_df_model[num_features + cat_features]
y = main_df_model[target]

# Разделение на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# Проверка размерностей
print("Размер X_train:", X_train.shape)
print("Размер X_test:", X_test.shape)
print("Размер y_train:", y_train.shape)
print("Размер y_test:", y_test.shape)

# Масштабирование числовых признаков
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train[num_features])
X_test_scaled = scaler.transform(X_test[num_features])

# Кодирование категориальных признаков (без дамми-ловушки, но с защитой от ошибок)
encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)
X_train_encoded = encoder.fit_transform(X_train[cat_features])
X_test_encoded = encoder.transform(X_test[cat_features])
encoder_columns = encoder.get_feature_names(cat_features)

# Объединение признаков
X_train_final = pd.concat([
    pd.DataFrame(X_train_scaled, columns=num_features, index=X_train.index),
    pd.DataFrame(X_train_encoded, columns=encoder_columns, index=X_train.index)
], axis=1)

X_test_final = pd.concat([
    pd.DataFrame(X_test_scaled, columns=num_features, index=X_test.index),
    pd.DataFrame(X_test_encoded, columns=encoder_columns, index=X_test.index)
], axis=1)

# Обучение модели линейной регрессии
model = LinearRegression()
model.fit(X_train_final, y_train)
predictions = model.predict(X_test_final)

# Расчёт метрик
residuals = y_test - predictions
r2 = r2_score(y_test, predictions)
print(f'R² модели: {r2:.4f}')

# Визуализация остатков
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.histplot(residuals, kde=True)
plt.title('Гистограмма остатков')
plt.xlabel('Остатки')

plt.subplot(1, 2, 2)
plt.scatter(predictions, residuals, alpha=0.5)
plt.axhline(0, color='red', linestyle='--')
plt.title('Остатки vs Предсказания')
plt.xlabel('Предсказания')
plt.ylabel('Остатки')

plt.tight_layout()
plt.show()

# Сохраняем предсказания
y_test_1 = y_test.copy()
pred_1 = pd.Series(predictions, index=y_test.index)
# Out:
# Размер X_train: (471, 7)
# Размер X_test: (157, 7)
# Размер y_train: (471,)
# Размер y_test: (157,)
# R² модели: 0.7844

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image.png](attachment:image.png)
#
# "Жирность молока" как связана с тем "сколько корова дает молока"? Если никак, то почему этот признак передается в модель, которая должна предсказать удой коровы?
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      Благодарю за замечание! Действительно, признак жирность_проц не имеет явной причинно-следственной связи с целевым признаком удой_кг, и его включение в модель не было обосновано.
#
# Ранее я ориентировался на умеренную корреляцию (около 0.60 по Пирсону / 0.69 по Спирмену), но, как справедливо ты ранее заметил, корреляция не говорит о наличии влияния одного признака на другой. По смыслу — жирность отражает качество молока, а не его объём. В связи с этим я исключил жирность_проц из модели линейной регрессии для предсказания удоя, чтобы избежать логических и статистических ошибок.
#
# Спасибо за уточнение — этот момент помог мне глубже понять принципы построения моделей и важность смыслового анализа признаков.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# **По смыслу — жирность отражает качество молока, а не его объём** - верно! Исправлено.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# 1. Здесь хорошо, происходит фиксация random_state. Воспроизводимость результатов разбиения выборки на обучающую (тренировочную) и тестовую мы обеспечили, значит при всех последующих запусках нашего кода подвыборки будут идентичными.
#
# 2. Доли размеров train/test как 3:1 - хорошо.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Я бы рекомендовал после разбиения данных на выборки посмотреть на их **размеры и размерности**. Метод shape для этого - идеальный помощник. "Цифры" по выборкам покажут верно ли мы произвели "разделение" данных.
#
# p.s. так (**псевдокод**): X_train.shape[0] – «покажет» количество строк в тренировочной выборке, а X_train.shape[1] - количество столбцов в ней же. Ну а X_train.shape – выведет размерность train'а в виде кортежа с 2мя значениями (первое число – количество строк, второе – столбцов).
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Здесь всё верно. Масштабирование "обучается" на тренировочной выборке, а затем РЕЗУЛЬТАТ (обычно это scaler) последовательно  применяется к тренировочной и к тестовой выборкам (и к валидационной тоже, если она имеется).
#
# Для чего нужно масштабировать признаки перед подачей в линейную модель машинного обучения (например в линейную регрессию)? Нам нужно минимизировать функцию потерь методом градиентного спуска. В случае разных масштабов признаков (например, год рождения и количество детей) её линии уровня будут иметь вид вытянутых эллипсов. Тогда вектор антиградиента и направление от текущей точки к минимуму функции потерь могут не совпадать, мы можем уйти далеко и не в ту сторону, и, в зависимости от шага градиентного спуска, либо придётся сделать больше итераций, либо вообще не будет сходимости. Если же признаки отмасштабированы, то линии уровня похожи на окружности. И проблема несовпадения антиградиента и направления к минимуму не так выражена.
#
# p.s. Для "деревянных моделей" масштабирование данных не обязательно, так как они не зависят от расстояния между объектами или величины признаков (суть работы "деревянных моделей" - разбиение пространства признаков на области, в которых принимается одно решение).</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично, молодец! Ты используешь OneHotEncoder из sklearn (а не get_dummies() из Pandas).
#
# (Небольшое рассуждение): Get_dummies подходит больше для анализа данных, а для машинного обучения более предпочтителен OneHotEncoding, т.к. он позволяет избежать ряд ошибок при обучении моделей, в том числе может работать с неизвестными ранее уровнями категорий, которых не было изначально (например, если появится еще одна страна, скажем Italy). Get_dummies с неизвестными категориями "из коробки" не работает, но есть лайфхак описанный здесь: https://pythonsimplified.com/difference-between-onehotencoder-and-get_dummies/ (*Though get_dummies can’t handle unknown categories natively, you could get around this inconsistency by applying the below technique. You will have to save the columns of the train set and load it during prediction on test set. Then you need to apply reindex and after filling the missing values will get you the same features as the train set*)
#
# Пандасовский Get_dummies не имеет методов fit и transform, поэтому кодируем категории на полном датафрейме (ДО разбиения на выборки ... так мы кстати обходим и проблему "неизвестных/новых категорий"), затем "режем" данные на выборки.
#
# В нашем же случае, используя OneHot-Encoding, мы кодируем данные ПОСЛЕ разбиения данных на выборки. Если кодирование (и/или масштабирование) выполняются до разбиения данных на выборки, то информация из тестовой выборки может просочиться в обучающую выборку. Это может привести к переобучению модели и неверным результатам. Нет, конечно OneHot-Encoding можно применять и до разбиения на выборки. Однако, если ты собираешся применять OHЕ до разбиения на выборки, то нужно обязательно использовать только те значения (записи), которые был представлены в обучающей выборке (а это усложнит код - нужно отбирать соответсвующие строки используя индексы). Если же использовать значения из всего набора данных, то повторюсь - это может привести к переобучению моделей (ввиду утечки данных).
#
# Также ты делаешь верно и то, что кодируешь категориальные и масштабируешь числовые признаки "по отдельности" (если так можно выразиться).
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image.png](attachment:image.png)
#
# Дмитрий - здесь у тебя сразу 2 ошибки:
#
# 1. Дамми-ловушка
#
# 2. Стоит настроить работу энкодера OneHotEncoder на работу с неизвестными значениями признаков - сейчас энкодер "при встрече с неизвестной категорией" (это может случиться в проде) - будет выбрасывать ошибку. Для непрерывности процесса моделирования **НУЖНО** настроить параметр **handle_unknown='ignore'**, чтобы новые, ранее неизвестные значения игнорировались и не включались в итоговую матрицу.
#
# Также среди параметров OneHotEncoder должен присутствовать **drop='first'** (иначе будет так называемая "дамми-ловушка").
#
# **ОЧЕНЬ ВАЖНО: Может понадобиться обновление библиотеки sklearn, так как в ранних версиях параметры handle_unknown и drop конфликтовали друг с другом, но в актуальной версии библиотеки такой проблемы нет**.
#
# ВАЖНО: прошу тебя аналогичные моменты исправить и ниже (если подобные ошибки встречаются) - на следующей итерации посмотрю этот момент.
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      Учёл рекомендации:
#
# Добавил .shape для проверки размерностей выборок.
# Обновил OneHotEncoder: drop='first' для устранения дамми-ловушки, handle_unknown='ignore' — для корректной обработки новых значений.
#     </font>
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      По причине несовместимости параметров drop='first' и handle_unknown='ignore' в используемой версии sklearn, оставил только handle_unknown='ignore', чтобы избежать ошибки при встрече с новыми категориями.
# При необходимости дамми-ловушку можно обработать вручную после кодирования.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# **По причине несовместимости параметров drop='first' и handle_unknown='ignore' в используемой версии sklearn** - Дмитрий, если бы это был реальный проект, то ты мог бы в самом начале проекта обновить версию библиотеки пусть не до текущей, но до одной из последних, например вот так:
#
#     !pip install scikit-learn==1.5.0
#
# и тогда код ( drop='first' + handle_unknown='ignore') стал работать. На Платформе установлена старая версия, 0.24, поэтому и ругается "*handle_unknown must be 'error' when the drop parameter is specified*". Мы можем управлять нужными нам версиями библиотек, даже если в каком-то окруженнии установлены старые версии.
#
# А проверить версию после установки можно так:
#
#     import sklearn
#     print(sklearn.__version__)
#
# **оставил только handle_unknown='ignore', чтобы избежать ошибки при встрече с новыми категориями. При необходимости дамми-ловушку можно обработать вручную после кодирования.** - исправлено.
# </div>

# %% [markdown]
# **Анализ результатов:**
#
# 1. Значение метрики R² = 0.7844
#
# Это означает, что около 78% дисперсии целевого признака удой_кг объясняется моделью. Это довольно высокий показатель для простой линейной регрессии — значит, выбранные признаки действительно полезны для прогнозирования.
#
# 2. Анализ гистограммы остатков
#
# Распределение остатков выглядит похожим на нормальное, что является хорошим признаком: это говорит о том, что модель не систематически ошибается в одну сторону.
#
# Однако видно небольшую асимметрию, особенно в левой части (отрицательные остатки уходят чуть дальше вправо). Это допустимо.
#
# 3. Анализ графика "Остатки vs Предсказания"
#
# Облако точек хаотичное и не показывает чёткой структуры — это хорошо. Оно говорит о том, что нет ярко выраженной зависимости остатков от предсказаний, а значит, модель не систематически пере- или недооценивает. Можно заметить небольшую дисперсию остатков в правой части графика - возможно, модель менее точна на больших значениях удоя. Это можно будет уточнить позже.
#
# **Выводы по модели:**
#
# Модель объясняет значительную часть дисперсии и показывает хорошие остатки. Ошибки в пределах разумного, распределены нормально. Пока дополнительные улучшения не обязательны, но ты сможешь сравнить с последующими моделями (в том числе после устранения нелинейности).

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Выводы (то что вижу я ... для сопоставления наших позиций):
#
# - R2 высокий. Это хорошо, но можно попытаться "вырастить" R2 ещё больше ....
#
# - Анализ остатков модели: есть участки, где ошибки неустойчивы. До 6000 - один уровень разброса. Более 6000 - разброс ошибки выше. Однозначно модель использовать нельзя - наблюдается гетероскедастичность (не постоянство дисперсии)
#
# - Гистограма - "колокол". Но есть локальные всплески. Которые тоже говорят о том, что модель можно улучшать
#
# **Общий вывод**: модель можно и нужно улучшать. В EDA мы видели, что факторы 'cпо' и 'эке' имеют не линейную связь с целевой. Поэтому их стоит преобразовать ('эке' ** 2). Из 'спо' же сделаем категориальную переменную. Для этого надо ещё раз внимательно посмотреть на границы возможных категорий.
# </div>

# %% [markdown]
# ### 5.2 Подготовьте данные с учётом связи входных признаков с целевым и обучите на них вторую модель LinearRegression.
#
# Посмотрите на диаграммы рассеяния: на них можно увидеть, что некоторые входные признаки связаны с целевым нелинейно. Исключите нелинейность, чтобы эти признаки были информативны для линейной регрессии. Вот несколько способов, которыми это можно сделать:
# - Вы обнаружите, что СПО и Удой связаны нелинейно. На их диаграмме рассеяния наблюдения сгруппированы в два кластера, причём есть такое значение СПО, которое можно считать границей между кластерами. Чтобы устранить нелинейность, преобразуйте СПО в категориальный бинарный признак, использовав эту границу.
# - Вы обнаружите, что ЭКЕ и Удой также связаны нелинейно. Нелинейность между ними можно исключить, если ввести новый признак ЭКЕ в квадрате.
#
# Повторите шаги из пункта 1 и создайте вторую модель: подготовьте данные, обучите модель, оцените её качество и напишите выводы.

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      Так как признак жирность_проц не имеет явной причинно-следственной связи с целевым признаком удой_кг, то его убираем.
#     </font>
# </div>

# %%
# Создадим копию и добавим новые признаки
main_df_modified = main_df.copy()

# Добавим квадрат ЭКЕ и бинарный признак по СПО
main_df_modified['эке_энергетическая_кормовая_единица_в_кв'] = main_df_modified['эке_энергетическая_кормовая_единица'] ** 2
main_df_modified['спо_бинарный'] = (main_df_modified['спо_сахаро-протеиновое_соотношение'] > 0.915).astype(int)

# Обновлённые признаки
target = 'удой_кг'
num_features_v2 = [
    'эке_энергетическая_кормовая_единица',
    'сырой_протеин_г',
    'эке_энергетическая_кормовая_единица_в_кв',
    'спо_бинарный'
]

cat_features_v2 = ['порода', 'тип_пастбища', 'порода_папы_быка', 'возраст']

# Подготовка данных
main_df_model_v2 = main_df_modified.drop(columns=['id'])
X = main_df_model_v2[num_features_v2 + cat_features_v2]
y = main_df_model_v2[target]

# Разделение
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# Масштабирование и кодирование
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train[num_features_v2])
X_test_scaled = scaler.transform(X_test[num_features_v2])

encoder = OneHotEncoder(drop='first', sparse=False)
X_train_encoded = encoder.fit_transform(X_train[cat_features_v2])
X_test_encoded = encoder.transform(X_test[cat_features_v2])
encoder_columns = encoder.get_feature_names(cat_features_v2)

# Объединение
X_train_final_v2 = pd.concat([
    pd.DataFrame(X_train_scaled, columns=num_features_v2, index=X_train.index),
    pd.DataFrame(X_train_encoded, columns=encoder_columns, index=X_train.index)
], axis=1)

X_test_final_v2 = pd.concat([
    pd.DataFrame(X_test_scaled, columns=num_features_v2, index=X_test.index),
    pd.DataFrame(X_test_encoded, columns=encoder_columns, index=X_test.index)
], axis=1)

# Обучение модели
model_v2 = LinearRegression()
model_v2.fit(X_train_final_v2, y_train)
predictions_v2 = model_v2.predict(X_test_final_v2)

# Анализ
residuals_v2 = y_test - predictions_v2
r2_v2 = r2_score(y_test, predictions_v2)

# Визуализация остатков
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.histplot(residuals_v2, kde=True)
plt.title('Гистограмма остатков')
plt.xlabel('Остатки')

plt.subplot(1, 2, 2)
plt.scatter(predictions_v2, residuals_v2, alpha=0.5)
plt.axhline(0, color='red', linestyle='--')
plt.title('Остатки vs Предсказания')
plt.xlabel('Предсказания')
plt.ylabel('Остатки')

plt.tight_layout()
plt.show()

# Выводим R²
print(f'R² модели: {r2_v2:.4f}')

# Сохраним значения для дальнейшего анализа на шаге 5.4
y_test_2 = y_test.copy()
pred_2 = pd.Series(predictions_v2, index=y_test.index)
# Out:
# R² модели: 0.8173

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Отлично, 5 шагов (EDA, обработка аномалий и пропусков, разделение данных на выборки, масштабирование/нормировку и кодирование признаков), входящие в типичный пайплайн подготовки данных **к этому моменту должны быть выполнены** ...
#
# Я тебе совет дам: создай шаблон кода (или **ЛУЧШЕ - функцию/функции**), которые будут работать с момента загрузки данных и до получения выборок, готовых к передаче в модели МО.
#
# Зачем такой такая функция/функции нужна? Чтобы не ломать всякий раз голову, не вспоминать и писать руками один и тот же код (да ещё и с возможностью совершить "глупую" ошибку). В функции(ях) должны быть (как минимум) следующие рутинные процедуры, которые встречаются ну абсолютно в каждом МО-проекте:
#
# 1. разбиение данных на выборки,
#
# 2. масштабирование/нормировка.
#
# 3. обработка категориальных признаков,
#
# Затем ты эту функцию(и) будешь вставлять в каждый новый проект, чуть модифицировать его (имена переменных, названия столбцов) и гарантированно получать работающий и безошибочный код.
#
# А ресурсы головы ))) лучше тратить на подбор гиперпараметров и генерацию новых фичей - вот здесь находится то, что способно выделить твои модели, поднять их качество.
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      Спасибо за профессиональный совет!
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Присмотрись к использованию трансформеров и пайплайнов в машинном обучении. Да, это расширенный и поначалу сложный и непонятный концепт, НО ... вот их преимущества при использовании в коде:
#
# Преимущества использования трансформеров:
#
# 1. **Гибкость и модульность**: Трансформеры позволяют разбить сложные операции по предобработке данных на более мелкие и легко управляемые компоненты. Это делает код более читаемым и модульным.
#
# 2. **Переиспользование**: Трансформеры могут быть повторно использованы на разных этапах анализа данных и построения моделей. Например, ты можешь создать трансформер для нормализации данных и использовать его как в обучении модели, так и на этапе инференса.
#
# 3. **Работа с разными типами данных**: Трансформеры могут обрабатывать различные типы данных, включая текст, изображения и числовые значения. Это позволяет тебе создавать единые интерфейсы для предобработки разнообразных данных.
#
# Преимущества использования пайплайнов:
#
# 1. **Структурированность**: Пайплайны помогают организовать последовательность шагов обработки данных, начиная с загрузки и заканчивая подготовкой к обучению модели. Это обеспечивает структурированность и позволяет легко вносить изменения.
#
# 2. **Поддержание кода**: Пайплайны сокращают вероятность ошибок и упрощают поддержание кода. Отслеживание последовательности операций делает процесс отладки и оптимизации более прозрачным.
#
# 3. **Масштабируемость**: Пайплайны могут быть легко расширены новыми этапами обработки данных. Это позволяет добавлять новые операции без переписывания всего кода.
#
# Объединение трансформеров и пайплайнов позволяет создавать чистые, структурированные и гибкие рабочие процессы для подготовки данных. Например, ты можешь создать трансформеры для преобразования текстовых данных и числовых значений, а затем построить пайплайн, который последовательно применяет эти трансформеры и завершается обучением модели. Это существенно упростит управление и анализ данных перед обучением моделей машинного обучения.
#
# Несколько ссылок (*нужен vpn для подключения к сайтам + возможно понадобиться поиском поискать названия статей - если они были перемещены*), которые позволят погрузиться в тему:
#
# - [трансформеры](https://scikit-learn.org/stable/modules/generated/sklearn.compose.ColumnTransformer.html) и [пайплайны](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html) для организации предобработки (кодирования, масштабирования) и модели
# - применение пайплайна [A Basic Introduction to Pipelines in Scikit Learn](https://towardsdatascience.com/a-basic-introduction-to-pipelines-in-scikit-learn-bd4cee34ad95)
# - большой гайд как можно комбинировать разные этапы предобработки [Pipelines and composite estimators](https://scikit-learn.org/stable/modules/compose.html)
# - или можно написать свой класс-трансформер [Custom Transformers and Pipelines in Python](https://towardsdatascience.com/custom-transformers-in-python-part-ii-6fe111fc82e4)
# </div>

# %% [markdown]
# **Анализ второй модели:**
#
# Качество модели
#
# R² модели: 0.8173 — это лучше, чем у первой модели (0.7844), то есть объяснённая дисперсия улучшилась примерно на 3%. Добавление новых признаков дало положительный эффект. Это говорит о том, что нелинейные связи были учтены удачно, особенно преобразование СПО в бинарный признак и добавление ЭКЕ в квадрате.
#
# **График остатков**
#
# Гистограмма остатков примерно симметрична и приближается к нормальному распределению. Это хороший признак — линейная регрессия работает устойчиво.
#
# Диаграмма "Остатки vs Предсказания" показывает более плотное облако точек вокруг нуля, чем в первой модели. Однако остаются некоторые расхождения по краям и возможная гетероскедастичность (разброс остатков чуть увеличивается с ростом предсказаний). Это пока допустимо.
#
# **Выводы по модели:**
#
# Улучшение R² подтверждает, что устранение нелинейностей сделало модель точнее.
#
# Остатки распределены лучше, чем у предыдущей модели, а значит, предсказания более надёжны.
#
# Дополнительные признаки (особенно спо_бинарный) оказались полезными — это видно по корреляциям и по распределениям.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Выводы (то что вижу я ... для сопоставления наших позиций):
#
# - R2 увеличился на несколько пунктов. Здорово.
#
# - Анализ остатков модели: дисперсия разброса ошибки стала чуть стабильнее на всём дипазане фактичнеских данных. Это явное улучшение. И это важно. Наблюдаются две зоны ошибок. Но разница дисперсии ошибок не систематическая, а выборочная.
#
# - Гистограма: среднее и медиана совпадают, но распределение не нормальное (бимодальности, плюс смещение среднего влево от нуля). Значит потенциал для улучшения модели всё ещё есть.
#
# **Общий вывод**: Модель уже пригодна для прогнозирования.
# </div>

# %% [markdown]
# ### 5.3 Добавьте в данные новый признак и обучите на них третью модель LinearRegression.
# Добавьте признак Имя Папы из файла ferma_dad.csv, соединив его с остальными данными ferma_main.csv по ключу.
# Устраните нелинейность между признаками.
# Повторите шаги из пункта 1 и создайте третью модель: подготовьте данные, обучите модель, оцените её качество и напишите выводы.

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      Так как признак жирность_проц не имеет явной причинно-следственной связи с целевым признаком удой_кг, то его из модели уберем.
#     </font>
# </div>

# %%
# Объединение ferma_main и ferma_dad по 'id'
main_df_merged = main_df.merge(dad_df, on='id', how='left')
main_df_merged = main_df_merged[main_df_merged['имя_папы'].notna()].copy()

# Посмотрим размерности до объединения
print('Размер main_df:', main_df.shape)
print('Размер dad_df:', dad_df.shape)

# Объединение ferma_main и ferma_dad по 'id'
main_df_merged = main_df.merge(dad_df, on='id', how='left')
print('Размер main_df_merged (до фильтрации):', main_df_merged.shape)

# Оставим только строки, где имя папы известно
main_df_merged = main_df_merged[main_df_merged['имя_папы'].notna()].copy()
print('Размер main_df_merged (после фильтрации):', main_df_merged.shape)

# Добавим признаки
main_df_merged['эке_энергетическая_кормовая_единица_в_кв'] = main_df_merged['эке_энергетическая_кормовая_единица'] ** 2
main_df_merged['спо_бинарный'] = (main_df_merged['спо_сахаро-протеиновое_соотношение'] > 0.915).astype(int)

# Удалим строки с пропусками в числовых признаках
main_df_merged = main_df_merged.dropna(subset=[
    'удой_кг', 'эке_энергетическая_кормовая_единица',
    'сырой_протеин_г', 'жирность_проц'
])

# Целевой признак и группы признаков
target = 'удой_кг'
num_features = [
    'эке_энергетическая_кормовая_единица',
    'эке_энергетическая_кормовая_единица_в_кв',
    'сырой_протеин_г'
]

bin_features = ['спо_бинарный']
cat_features = ['порода', 'тип_пастбища', 'порода_папы_быка', 'возраст', 'имя_папы']

# Разделение на признаки и цель
X = main_df_merged[num_features + bin_features + cat_features]
y = main_df_merged[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# Масштабирование числовых признаков
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train[num_features]), columns=num_features)
X_test_scaled = pd.DataFrame(scaler.transform(X_test[num_features]), columns=num_features)

# Кодирование категориальных признаков
encoder = OneHotEncoder(drop='first', sparse=False)
X_train_encoded = pd.DataFrame(encoder.fit_transform(X_train[cat_features]))
X_test_encoded = pd.DataFrame(encoder.transform(X_test[cat_features]))
X_train_encoded.columns = encoder.get_feature_names(cat_features)
X_test_encoded.columns = encoder.get_feature_names(cat_features)

# Объединение признаков (сброс индексов для избежания NaN)
X_train_final = pd.concat([
    X_train_scaled.reset_index(drop=True),
    X_train[bin_features].reset_index(drop=True),
    X_train_encoded.reset_index(drop=True)
], axis=1)

X_test_final = pd.concat([
    X_test_scaled.reset_index(drop=True),
    X_test[bin_features].reset_index(drop=True),
    X_test_encoded.reset_index(drop=True)
], axis=1)

# Проверка на пропуски
print("NaN в X_train_final:", X_train_final.isna().sum().sum())
print("NaN в X_test_final:", X_test_final.isna().sum().sum())

# Обучение модели
model = LinearRegression()
model.fit(X_train_final, y_train)
predictions = model.predict(X_test_final)

# Будем использовать model_final позже в шаге 5.6.
model_final = model

# Оценка
residuals = y_test - predictions
r2 = r2_score(y_test, predictions)

# Визуализация остатков
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(residuals, kde=True)
plt.title('Гистограмма остатков')
plt.xlabel('Остатки')

plt.subplot(1, 2, 2)
plt.scatter(predictions, residuals, alpha=0.5)
plt.axhline(0, color='red', linestyle='--')
plt.title('Остатки vs Предсказания')
plt.xlabel('Предсказания')
plt.ylabel('Остатки')

plt.tight_layout()
plt.show()

print(f"R² модели: {r2:.4f}")

# Сохраним значения для анализа на шаге 5.4
y_test_3 = y_test.copy()
pred_3 = pd.Series(predictions, index=y_test.index)
# Out:
# Размер main_df: (628, 12)
# Размер dad_df: (629, 2)
# Размер main_df_merged (до фильтрации): (628, 13)
# Размер main_df_merged (после фильтрации): (628, 13)
# NaN в X_train_final: 0
# NaN в X_test_final: 0
# R² модели: 0.8288

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# В случае объединения/слияния датафреймов рекомендую тебе смотреть на размерости датафреймов ДО слияния и ПОСЛЕ него. В подобных операциях часто ошибки бывают.
# </div>

# %% [markdown]
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      Благодарю за рекомендацию!
#
# Я добавил в код контрольный вывод размерностей датафреймов перед объединением и после.
# Вот результаты:
#
# Размер main_df: (628, 12)
#
# Размер dad_df: (629, 2)
#
# Размер main_df_merged до фильтрации пропусков: (628, 13)
#
# Размер main_df_merged после фильтрации пропусков: (628, 13)
#
# Также проверил наличие пропущенных значений в признаках после подготовки данных:
#
# NaN в X_train_final: 0
#
# NaN в X_test_final: 0
#
# Вывод:
# Объединение прошло корректно — все объекты сохранены, пропусков нет.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# **Вывод: Объединение прошло корректно — все объекты сохранены, пропусков нет.** - отлично!
# </div>

# %% [markdown]
# **Анализ третьей модели:**
#
# R² модели: 0.8288 — это самый высокий R² из всех трёх моделей, значит модель 3 лучше объясняет вариацию удоя;
#
# Гистограмма остатков выглядит нормально распределённой;
#
# Диаграмма остатков vs предсказания не показывает явных трендов — хороший признак того, что модель не систематически ошибается.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Выводы (то что вижу я ... для сопоставления наших позиций):
#
# - R2 ещё увеличился! Наши факторы на 82,5% объясняют разброс в целевой переменной. Это успех.
#
# - Анализ остатков модели: дисперсия разброса ошибки осталась стабильной. Есть около десятка  "выдающихся" точек на высоких удоях, но это не системные дела, а разовая акция похоже. Можем признать, что ошибка равномерная на всём диапазоне значений. Т.е. остатки - гомоскедастичны. Это важно. Значит модель МОЖНО использовать для прогноза.
#
# - Гистограма: среднее и медиана совпадают, не смещены относительно 0. Но бимодальность присутствуют.
#
# **Общий вывод**: Потенциал для улучшения модели всё ещё есть, но на текущий момент признаём модель качественной (остатки гомоскедастичны) и пригодной для работы. Посмотрим на точность модели.
# </div>

# %% [markdown]
# ### 5.4 Сравните качество трёх моделей линейной регрессии, сопоставьте их R² и остатки.

# %%
# Значения R² из результатов шагов 5.1 — 5.3
r2_scores = {
    'Модель 1': 0.7844,
    'Модель 2': 0.8173,
    'Модель 3': 0.8288
}

# Визуализация R²
plt.figure(figsize=(7, 4))
sns.barplot(x=list(r2_scores.keys()), y=list(r2_scores.values()), palette='Blues_d')
plt.ylim(0.75, 0.85)
plt.ylabel('R²')
plt.title('Сравнение R² моделей линейной регрессии')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# **Анализ:**
#
# Модель 1 — базовая модель с линейными признаками, дала наименьшее качество.
# R² ≈ 0.7844 означает, что около 78% дисперсии удоя объясняется моделью.
#
# Модель 2 — добавление нелинейного признака (ЭКЕ²) и преобразование СПО улучшили объясняющую способность модели.
# R² вырос до 0.8173.
#
# Модель 3 — дополнительно учтён фактор имя_папы, как возможный источник наследственных признаков. Это дало наилучший результат: R² ≈ 0.8258. Видимо, генетика действительно играет роль!
#
# **Bыводы:**
#
# Модель 3 показала наивысший результат R² = 0.8288. По всем метрикам третья модель оказалась самой точной.
#
# Это подтверждает, что добавление признака «имя_папы» улучшает модель. Модель 3 объясняет 82.6% дисперсии удоя, что очень хорошо для линейной регрессии. Анализ остатков показал, что распределение ошибок близко к нормальному, систематических искажений нет. Улучшение от модели к модели идёт за счёт учёта нелинейности и новых информативных признаков. Новые источники информации (генетические) действительно помогают улучшить предсказания.

# %% [markdown]
# ### 5.5 Оцените качество каждой модели по трём метрикам: MSE, MAE, RMSE. Используйте функции для расчёта метрик.
# - Выберите лучшую модель;
# - Укажите доверительный интервал прогноза лучшей модели.
#
# Для этого рассчитайте квантили ошибки модели на тренировочных данных.

# %%
# Расчет метрик для всех трёх моделей
def calc_metrics(y_true, y_pred):
    return {
        'R²': r2_score(y_true, y_pred),
        'MSE': mean_squared_error(y_true, y_pred),
        'MAE': mean_absolute_error(y_true, y_pred),
        'RMSE': mean_squared_error(y_true, y_pred, squared=False)
    }

metrics_1 = calc_metrics(y_test_1, pred_1)
metrics_2 = calc_metrics(y_test_2, pred_2)
metrics_3 = calc_metrics(y_test_3, pred_3)

# Сравнительная таблица
metrics_df = pd.DataFrame([metrics_1, metrics_2, metrics_3], index=['Модель 1', 'Модель 2', 'Модель 3'])
display(metrics_df)

# Визуализация R²
plt.figure(figsize=(8, 5))
plt.bar(metrics_df.index, metrics_df['R²'], color='skyblue')
plt.ylabel('R²')
plt.title('Сравнение R² моделей')
plt.ylim(0, 1)
plt.grid(axis='y')
plt.show()

# Визуализация RMSE
plt.figure(figsize=(8, 5))
plt.bar(metrics_df.index, metrics_df['RMSE'], color='salmon')
plt.ylabel('RMSE')
plt.title('Сравнение RMSE моделей')
plt.grid(axis='y')
plt.show()

# Остатки
residuals_1 = y_test_1 - pred_1
residuals_2 = y_test_2 - pred_2
residuals_3 = y_test_3 - pred_3

# Доверительный интервал ошибки по модели 3 (лучшей)
lower_quantile = np.quantile(residuals_3, 0.025)
upper_quantile = np.quantile(residuals_3, 0.975)

print(f"Доверительный интервал ошибок модели 3 (95%): от {lower_quantile:.2f} до {upper_quantile:.2f}")
# Out:
#                 R²           MSE         MAE        RMSE
# Модель 1  0.784408  43887.015010  164.241945  209.492279
# Модель 2  0.817320  37187.220728  150.771505  192.839884
# Модель 3  0.828831  34844.101286  145.506027  186.665747
# Доверительный интервал ошибок модели 3 (95%): от -354.20 до 367.03

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Есть, вижу расчет доверительных интервалов.
# </div>

# %% [markdown]
# Мы обучили три модели для прогнозирования удоя коров. Каждая последующая модель улучшала предыдущую за счёт более богатого набора признаков и устранения нелинейностей.
#
# **Вывод: Лучшая модель — третья**
#
# Наилучшее качество: модель 3 имеет максимальный R² (доля объяснённой дисперсии) - 0.8288 и минимальный RMSE (средняя ошибка в кг) - 186,6 кг.
#
# Была улучшена за счёт: учёта нелинейной зависимости (ввели признак ЭКЕ²), добавления бинарного признака по СПО, добавления породного признака отца (имя папы из отдельного файла).
#
# **Точность модели 3:**
#
# 95% доверительный интервал ошибок: от −354 до +367 кг.
#
# Это означает, что в 95% случаев предсказание удоя будет отличаться от реального значения не более чем на ~±360 кг.
#
# **Рекомендации фермеру:**
#
# Использовать модель 3 для оценки продуктивности коров.
#
# Особенно важны: показатель ЭКЕ, жирность, порода отца.
#
# **В будущем можно улучшить модель:**
#
# - собрать больше данных о составе кормов и здоровье коров;
#
# - учесть дополнительные характеристики матерей (будет в следующем шаге).

# %% [markdown]
# ### 5.6 С помощью лучшей модели спрогнозируйте удой коров, которых фермер хочет купить. Данные о них находятся в датасете cow_buy.csv.
# - Добавьте недостающие признаки ЭКЕ (Энергетическая кормовая единица), Сырой протеин, г и СПО (Сахаро-протеиновое соотношение): возьмите из датасета ferma_main.csv, средние значения каждого из признаков и увеличьте их на 5%.
# - Выполните подготовку данных, аналогичную той, которую делали для тренировочной выборки.
# - Получите прогноз удоя коров.

# %%
# Копируем датасет cow_buy
cow_buy_prepared = buy_df.copy()

# Переименование признаков под main_df
cow_buy_prepared = cow_buy_prepared.rename(columns={
    'текущая_жирность_проц': 'жирность_проц',
    'текущий_уровень_белок_проц': 'белок_проц'
})

# Добавим недостающие числовые признаки со средними значениями из main_df (+5%)
cow_buy_prepared['эке_энергетическая_кормовая_единица'] = main_df['эке_энергетическая_кормовая_единица'].mean() * 1.05
cow_buy_prepared['сырой_протеин_г'] = main_df['сырой_протеин_г'].mean() * 1.05
cow_buy_prepared['спо_сахаро-протеиновое_соотношение'] = main_df['спо_сахаро-протеиновое_соотношение'].mean() * 1.05

# Добавим признаки из шага 5.3
cow_buy_prepared['эке_энергетическая_кормовая_единица_в_кв'] = (
    cow_buy_prepared['эке_энергетическая_кормовая_единица'] ** 2
)
cow_buy_prepared['спо_бинарный'] = (
    cow_buy_prepared['спо_сахаро-протеиновое_соотношение'] > 0.915
).astype(int)

# Унификация категориальных признаков (точно как в main_df)
cat_cols_for_buy = ['порода', 'тип_пастбища', 'порода_папы_быка', 'возраст', 'имя_папы']
for col in cat_cols_for_buy:
    cow_buy_prepared[col] = (
        cow_buy_prepared[col]
        .astype(str)
        .str.strip()
        .str.lower()
        .str.replace(r'\s+', ' ', regex=True)
    )

# Исправим опечатки
cow_buy_prepared['тип_пастбища'] = cow_buy_prepared['тип_пастбища'].replace({
    'равнинные': 'равнинное'
})
cow_buy_prepared['порода_папы_быка'] = cow_buy_prepared['порода_папы_быка'].replace({
    'айдиалл': 'айдиал'
})

# Исправим 'имя_папы' обратно к нужному формату
cow_buy_prepared['имя_папы'] = cow_buy_prepared['имя_папы'].replace({
    'барин': 'Барин',
    'буйный': 'Буйный',
    'соловчик': 'Соловчик',
    'геркулес': 'Геркулес'
})

# Подготовка данных (масштабирование и кодирование)
X_buy_scaled = pd.DataFrame(
    scaler.transform(cow_buy_prepared[num_features]),
    columns=num_features
)

X_buy_encoded = pd.DataFrame(
    encoder.transform(cow_buy_prepared[cat_features])
)
X_buy_encoded.columns = encoder.get_feature_names(cat_features)

# Финальное объединение
X_buy_final = pd.concat([
    X_buy_scaled.reset_index(drop=True),
    cow_buy_prepared[bin_features].reset_index(drop=True),
    X_buy_encoded.reset_index(drop=True)
], axis=1)

# Прогноз
predicted_yield = model_final.predict(X_buy_final)

# Вывод результата
print('Прогнозируемый удой коров:')
print(predicted_yield)

# Добавим прогноз в таблицу
cow_buy_prepared['прогноз_удой_кг'] = predicted_yield

# Отметим, какие коровы соответствуют критерию ≥ 6000 кг
cow_buy_prepared['подходит_по_удою'] = cow_buy_prepared['прогноз_удой_кг'] >= 6000

# Сортируем для удобства просмотра
result_df = cow_buy_prepared[['порода', 'тип_пастбища', 'порода_папы_быка', 'имя_папы', 'возраст', 'прогноз_удой_кг', 'подходит_по_удою']]
result_df = result_df.sort_values(by='прогноз_удой_кг', ascending=False)

# Покажем результат
display(result_df)
# Out:
# Прогнозируемый удой коров:
# [6581.06917531 6308.70183835 6263.0249061  6571.7631311  6525.08219609
#  6341.47036315 6581.06917531 6541.43414119 6263.0249061  6339.03082827
#  6324.46512711 6574.20266598 6581.06917531 6065.24229799 6263.0249061
#  6571.7631311  6324.46512711 6341.47036315 6541.43414119 6525.08219609]
#              порода тип_пастбища порода_папы_быка  имя_папы      возраст  \
# 0    вис бик айдиал    холмистое           айдиал  Геркулес  более_2_лет
# 12   вис бик айдиал    холмистое           айдиал  Геркулес  более_2_лет
# 6    вис бик айдиал    холмистое           айдиал  Геркулес  более_2_лет
# 11  рефлешнсоверинг    равнинное          соверин  Геркулес  более_2_лет
# 3   рефлешнсоверинг    холмистое           айдиал    Буйный  более_2_лет
# 15  рефлешнсоверинг    холмистое           айдиал    Буйный  более_2_лет
# 18   вис бик айдиал    равнинное          соверин    Буйный  более_2_лет
# 7    вис бик айдиал    равнинное          соверин    Буйный  более_2_лет
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично, устанавливаешь параметры кормления для наших потенциально новых коровок (в соответствии с требованиями фермера).
# </div>

# %% [markdown]
# **Вывод для фермера:**
#
# Результат:
#
# Все 20 коров из выборки соответствуют требованию ≥ 6000 кг молока в год.
#
# Прогнозируемые значения удоя варьируются от 6065 до 6581 кг, что удовлетворяет условиям контракта.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# **Эта корова находится на границе решения. Если фермер готов пойти на минимальный риск — можно её взять. Если он хочет поступать на 100% надёжно — лучше эту корову исключить.** - риски обсуждать нет смысла. Фермер не готов на них идти. Всё это уже зафиксировано в его ТЗ:
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      После корректировок сделанных ранее все 20 коров из выборки соответствуют требованию ≥ 6000 кг молока в год.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Да, расчет метрик, доверительных интервалов - всё по букве брифа. Ну и выбор в пользу 3ей модели аргументирован и посему очевиден. Предсказание что находятся коровы, которые дают > 6.000 кг молока - верно (в эталонном проекте автора этого спринта всё точно также).
#
# Итак, с линейными моделями всё, приступаем к логистической регрессии, будем предсказывать вкус молока.
# </div>

# %% [markdown]
# ## Шаг 6. Обучение модели логистической регрессии

# %% [markdown]
# ### 6.1 Подготовьте данные датасета ferma_main.csv и обучите на них модель LogisticRegression.
# - Используйте в качестве целевого признак Вкус молока.
# - При необходимости преобразуйте имеющиеся или добавьте новые признаки.
# - Разбейте данные на тренировочную и тестовую выборки.
# - Кодируйте категориальные признаки с помощью OneHotEncoder.
# - Масштабируйте количественные признаки с помощью StandardScaler.
# - Обучите модель логистической регрессии на подготовленных данных.
# - Оцените качество модели на тестовой выборке: рассчитайте метрики accuracy, recall, precision.
# - Постройте матрицу ошибок.

# %% [markdown]
# Сделаем допущение что могут возникнуть пропуски в 'имя_папы' после объединения main_df и dad_df (сейчас или в будущем).
#
# Что мы знаем из наших данных:
#
# - main_df содержит 628 строк (id от 0 до 627)
#
# - dad_df содержит 629 строк — даже больше, чем main_df
#
# Это говорит о том, что все id из main_df должны быть в dad_df. Следовательно, в теории пропусков быть не должно. Проверим это.

# %%
# До объединения
print(f'Размер main_df: {main_df.shape}')
print(f'Размер dad_df: {dad_df.shape}')

# Объединяем таблицы
merged_df_check = main_df.merge(dad_df, on='id', how='left')

# После объединения
print(f'Размер merged_df_check: {merged_df_check.shape}')

# Считаем количество пропусков
missing_dads = merged_df_check['имя_папы'].isna().sum()
print(f'Количество строк без информации об имени папы: {missing_dads}')
# Out:
# Размер main_df: (628, 12)
# Размер dad_df: (629, 2)
# Размер merged_df_check: (628, 13)
# Количество строк без информации об имени папы: 0

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      Ты ранее подчёркивал важность проверки размерностей до и после объединения датафреймов, особенно в шагах:
#
# - при слиянии main_df и dad_df (для добавления имя_папы)
#
# - при подготовке данных для прогноза (cow_buy_prepared)
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Отлично! Студенты обычно или не проверяют вовсе размерности или пишут что проверяли, но перед отправкой проекта на проверку - убрали (якобы чтобы они место не занимали) ))) Но разве 1 строка занимает много места?
#
# А я по собственному опыту скажу Дмитрий, что я даже в рабочих проектах оставляю **множество** таких проверок - потому что призапуске кода на наовых данных ... или когда я запускаю какой-то "старый" код, логику которого подзабыл - мне эти проверки позволяют "на лету" понимать, что код работает верно, обработка данных в потоке идёт верно, что данные не теряются. Вот пример количества проверок в одном из моих последних рабочих заданий:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
# </div>

# %% [markdown]
# **Проверка объединения таблиц:**
#
# Размер main_df — (628, 12), размер dad_df — (629, 2).
# После объединения размер merged_df_check — (628, 13), пропусков в столбце 'имя_папы' нет.
# Это подтверждает корректное слияние данных по ключу 'id' без потери строк и без появления пропусков.
#
# Однако, мы всё равно будем фильтровать .notna()
#
# Это страховочная мера, чтобы не допустить ошибки во время кодирования или обучения. Даже если пропусков сейчас нет, они могут появиться в будущем, если данные будут обновлены в будущем. Могут быть из-за опечаток, неправильных id или неудачно объединённой таблицы. Это как ремень безопасности: он может и не понадобиться, но лучше подстраховаться.

# %%
# Объединение с именем папы
main_df_class = main_df.merge(dad_df, on='id', how='left')
main_df_class = main_df_class[main_df_class['имя_папы'].notna()].copy()

# Преобразуем целевой признак во флаг (вкусно = 1)
main_df_class['вкус_молока'] = (main_df_class['вкус_молока'] == 'вкусно').astype(int)

# Добавим признаки
main_df_class['эке_энергетическая_кормовая_единица_в_кв'] = (
    main_df_class['эке_энергетическая_кормовая_единица'] ** 2
)
main_df_class['спо_бинарный'] = (
    main_df_class['спо_сахаро-протеиновое_соотношение'] > 0.915
).astype(int)

# Признаки
target_clf = 'вкус_молока'
num_features_clf = [
    'эке_энергетическая_кормовая_единица',
    'сырой_протеин_г',
    'жирность_проц',
    'эке_энергетическая_кормовая_единица_в_кв'
]
bin_features_clf = ['спо_бинарный']
cat_features_clf = ['порода', 'тип_пастбища', 'порода_папы_быка', 'возраст', 'имя_папы']

# Разделим на признаки и цель
X = main_df_class[num_features_clf + bin_features_clf + cat_features_clf]
y = main_df_class[target_clf]

# Разделим на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# Масштабируем числовые признаки
scaler_clf = StandardScaler()
X_train_scaled = pd.DataFrame(scaler_clf.fit_transform(X_train[num_features_clf]), columns=num_features_clf)
X_test_scaled = pd.DataFrame(scaler_clf.transform(X_test[num_features_clf]), columns=num_features_clf)

# Кодируем категориальные признаки
encoder_clf = OneHotEncoder(drop='first', sparse=False)
X_train_encoded = pd.DataFrame(encoder_clf.fit_transform(X_train[cat_features_clf]))
X_test_encoded = pd.DataFrame(encoder_clf.transform(X_test[cat_features_clf]))

# Добавим имена столбцов
X_train_encoded.columns = encoder_clf.get_feature_names(cat_features_clf)
X_test_encoded.columns = encoder_clf.get_feature_names(cat_features_clf)

# Объединение признаков
X_train_final = pd.concat([
    X_train_scaled.reset_index(drop=True),
    X_train[bin_features_clf].reset_index(drop=True),
    X_train_encoded.reset_index(drop=True)
], axis=1)

X_test_final = pd.concat([
    X_test_scaled.reset_index(drop=True),
    X_test[bin_features_clf].reset_index(drop=True),
    X_test_encoded.reset_index(drop=True)
], axis=1)

# Обучение модели
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_final, y_train)
y_pred = clf.predict(X_test_final)

# Метрики
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)

print(f"Accuracy:  {accuracy:.3f}")
print(f"Recall:    {recall:.3f}")
print(f"Precision: {precision:.3f}")

# Матрица ошибок
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['не вкусно', 'вкусно'], yticklabels=['не вкусно', 'вкусно'])
plt.xlabel('Предсказано')
plt.ylabel('Факт')
plt.title('Матрица ошибок')
plt.show()
# Out:
# Accuracy:  0.611
# Recall:    0.864
# Precision: 0.608

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# ![image.png](attachment:image.png)
#
# Кодирование таргета нельзя делать "руками":
#
# - при появлении новых значений категориальных признаков, не предусмотренных твоим решением, модель или упадёт, или будет генерировать ошибки;
# - такое решение не сделаешь частью пайплайна, а все современные решения базируются на них.
#
# Поэтому кодирование нужно делать только с применением обучаемых трансформеров. Для кодирования целевого признака нужно использовать LabelEncoder (сокращаю до LE): https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html.
#
# p.s. если стоит вопрос в том, что тебе не нравиться, что LE, например, присваивает классу "снизилась" метку 0, а "прежний уровень" - метку 1, то значения меток можно инвертировать с помощью небольшого лайфхака:
#
#         import numpy as np
#
#         # Пример преобразованных классов
#         target = np.array([0, 1, 1, 0, 1, 0])
#
#         # Инвертирование классов
#         inverted_target = 1 - target
#
#         print("Исходные классы:", target)
#         print("Инвертированные классы:", inverted_target)
#
# В этом примере переменная inverted_target будет содержать те же значения, что и target, но значения будут инвертированы.
#
# p.p.s. есть ещё метод invert_transform()
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      Благодарю за рекомендацию! Нужно использовать самые современные практики. Спасибо.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Ну и здесь ты молодец, что считаешь что-то из набора (полнота / точность / accuracy).
#
# Матрица ошибок (confusion matrix) - тоже ОК, так как нам сейчас нужно будет определиться с бизнес-метрикой (как же фермеру стоит отбирать новых коров).
# </div>

# %% [markdown]
# **Модель логистической регрессии на задаче классификации вкуса молока показывает:**
#
# Метрики модели:
#
# **Accuracy** (доля правильных предсказаний): 0.611
# → модель угадала вкус молока примерно в 61% случаев.
#
# **Recall** (чувствительность, полнота): 0.864
# → из всех реально вкусных случаев модель обнаружила 86.4%. Это очень хорошо!
#
# **Precision** (точность): 0.608
# → из всех предсказаний "вкусно", только ~61% действительно вкусные.
#
# **Матрица ошибок:**
#
# 49 ложноположительных: модель ошибочно посчитала, что молоко вкусное (а оно не вкусное).
#
# 12 ложноотрицательных: наоборот, модель не узнала вкусное молоко.

# %% [markdown]
# **Выводы для фермера:**
#
# Модель хорошо распознаёт вкусное молоко (высокий recall), что может быть приоритетом, если важно не пропустить хорошие экземпляры.
#
# Однако часто ошибается, принимая некачественное молоко за вкусное — возможно, стоит доработать модель или ввести повторную проверку для спорных случаев.
#
# Итог: модель может использоваться как предварительный фильтр, но лучше не полагаться на неё вслепую.
#
# Попробуем улучшить качество — добавить новые признаки (например, белок_проц).

# %% [markdown]
# **Попробуем улучшить качество — добавить новый признак (например, белок_проц).**

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      По твоей рекомендации ранее 'жирность_проц' убираем из числовых признаков. Добавим категориальный 'жирность_категория', как способ "улучшения" базовой логистической модели через инженерию признаков.
#     </font>
# </div>

# %%
# Объединение с именем папы
main_df_class = main_df.merge(dad_df, on='id', how='left')
main_df_class = main_df_class[main_df_class['имя_папы'].notna()].copy()

# Целевой признак
main_df_class['вкус_молока'] = (main_df_class['вкус_молока'] == 'вкусно').astype(int)

# Новые признаки
main_df_class['эке_энергетическая_кормовая_единица_в_кв'] = (
    main_df_class['эке_энергетическая_кормовая_единица'] ** 2
)
main_df_class['спо_бинарный'] = (
    main_df_class['спо_сахаро-протеиновое_соотношение'] > 0.915
).astype(int)

# Новый признак — категориальная жирность
def categorize_fat(x):
    if x < 3.5:
        return 'низкая'
    elif x <= 4.2:
        return 'средняя'
    else:
        return 'высокая'

main_df_class['жирность_кат'] = main_df_class['жирность_проц'].apply(categorize_fat)

# Обновлённые списки признаков
target_clf = 'вкус_молока'
num_features_clf = [
    'эке_энергетическая_кормовая_единица',
    'сырой_протеин_г',
    'белок_проц',  # ← белок оставляем!
    'эке_энергетическая_кормовая_единица_в_кв'
]
bin_features_clf = ['спо_бинарный']
cat_features_clf = [
    'порода', 'тип_пастбища', 'порода_папы_быка', 'возраст', 'имя_папы', 'жирность_кат'
]

# Делим на X и y
X = main_df_class[num_features_clf + bin_features_clf + cat_features_clf]
y = main_df_class[target_clf]

# Трейн-тест сплит
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# Масштабируем числовые
scaler_clf = StandardScaler()
X_train_scaled = pd.DataFrame(scaler_clf.fit_transform(X_train[num_features_clf]), columns=num_features_clf)
X_test_scaled = pd.DataFrame(scaler_clf.transform(X_test[num_features_clf]), columns=num_features_clf)

# One-hot кодирование категориальных признаков
encoder_clf = OneHotEncoder(sparse=False, handle_unknown='ignore')

X_train_encoded = pd.DataFrame(encoder_clf.fit_transform(X_train[cat_features_clf]))
X_test_encoded = pd.DataFrame(encoder_clf.transform(X_test[cat_features_clf]))

X_train_encoded.columns = encoder_clf.get_feature_names(cat_features_clf)
X_test_encoded.columns = encoder_clf.get_feature_names(cat_features_clf)


# Объединение всех признаков
X_train_final = pd.concat([
    X_train_scaled.reset_index(drop=True),
    X_train[bin_features_clf].reset_index(drop=True),
    X_train_encoded.reset_index(drop=True)
], axis=1)

X_test_final = pd.concat([
    X_test_scaled.reset_index(drop=True),
    X_test[bin_features_clf].reset_index(drop=True),
    X_test_encoded.reset_index(drop=True)
], axis=1)

# Обучение логистической регрессии
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_final, y_train)
y_pred = clf.predict(X_test_final)

# Метрики
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)

print(f"Accuracy:  {accuracy:.3f}")
print(f"Recall:    {recall:.3f}")
print(f"Precision: {precision:.3f}")

# Матрица ошибок
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=['не вкусно', 'вкусно'],
            yticklabels=['не вкусно', 'вкусно'])
plt.xlabel('Предсказано')
plt.ylabel('Факт')
plt.title('Матрица ошибок')
plt.show()
# Out:
# Accuracy:  0.631
# Recall:    0.864
# Precision: 0.623

# %%
# Сохраним старые метрики вручную
accuracy_old = 0.611
recall_old = 0.864
precision_old = 0.608

# Предсказания НОВОЙ модели
y_pred = clf.predict(X_test_final)

# Метрики НОВОЙ модели
accuracy_new = accuracy_score(y_test, y_pred)
recall_new = recall_score(y_test, y_pred)
precision_new = precision_score(y_test, y_pred)

# Вывод
print('Сравнение моделей:')
print('-' * 42)
print(f'Accuracy (старое):  {accuracy_old:.3f} -> (новое): {accuracy_new:.3f}')
print(f'Recall   (старое):  {recall_old:.3f} -> (новое): {recall_new:.3f}')
print(f'Precision(старое):  {precision_old:.3f} -> (новое): {precision_new:.3f}')
# Out:
# Сравнение моделей:
# ------------------------------------------
# Accuracy (старое):  0.611 -> (новое): 0.631
# Recall   (старое):  0.864 -> (новое): 0.864
# Precision(старое):  0.608 -> (новое): 0.623

# %% [markdown]
# **Для повышения качества модели были добавлены новые признаки:**
#
# - количественный признак белок_проц;
#
# - категориальный признак жирность_кат, заменивший числовой жирность_проц.
#
# **Вывод:**
#
# После добавления нового признака 'белок_проц' и замены 'жирность_проц' на категориальный 'жирность_кат', качество модели улучшилось:
#
# Accuracy выросло с 0.611 до 0.631 (+2 процентных пункта).
#
# Recall остался на уровне 0.864 — модель по-прежнему хорошо находит все "вкусные" коровы.
#
# Precision улучшился с 0.608 до 0.623, что говорит о снижении количества ложных срабатываний при отборе.
#
# Эти изменения особенно важны, поскольку в бизнес-задаче фермеру критично минимизировать покупку "невкусных" коров. Таким образом, улучшение признакового пространства позволило добиться более точной и надёжной классификации вкуса молока без ухудшения полноты.

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      Твой профессиональный совет очень мне помог. Спасибо!
#     </font>
# </div>

# %% [markdown]
# ### 6.2 Проанализируйте модель логистической регрессии.
# - Объясните, какая ошибка критичнее всего при покупке коров: первого или второго рода. Помните, что главное для заказчика — вкусное молоко. Сформулируйте ответ с учётом метрик recall и precision, выберите более важную из них.
# - Сведите критичную ошибку к нулю: для этого измените порог принадлежности к классам. Ещё раз рассчитайте значения метрик recall и precision. Какое значение порога вы выбрали? Как изменились значения метрик?
# - Оформите выводы: скажите, что нужно сделать дальше, исходя из анализа модели?

# %% [markdown]
# **Мы решаем задачу классификации: наша задача - предсказать, будет ли у коровы вкусное молоко (вкус_молока = 1) или нет.**
#
# Ошибка первого рода (False Positive):
#
# - Мы предсказали, что молоко будет вкусным, но на деле оно не вкусное.
#
# - То есть фермер купит корову, а молоко окажется некачественным.
#
# Ошибка второго рода (False Negative):
#
# - Мы предсказали, что молоко будет не вкусным, а на деле оно вкусное.
#
# - То есть фермер не купит корову, а мог бы получить вкусное молоко.
#
# Какой тип ошибки критичнее? Для фермера критичнее ошибка первого рода. Он потратит деньги на корову, а получит некачественное молоко. Это потери.
#
# Что важнее: recall или precision?
#
# - Recall (полнота): как много всех вкусных коров мы нашли.
#
# - Precision (точность): среди всех предсказанных как вкусные, как много реально вкусных.
#
# **Для нас важнее Precision, потому что фермеру важно, чтобы если уж мы сказали "вкусно" — то оно точно было вкусно.
# Слишком низкая точность — много ложных вкусных, а это финансовые потери.**

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      Цель — полностью свести к нулю ошибку первого рода, то есть: чтобы модель никогда не предсказывала «вкусное», когда на самом деле молоко невкусное (False Positive = 0)
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Все верно! Нужно минимизировать ошибку 1го рода (увеличивать точность модели даже в ущерб полноте). Решение как это сделать вижу ниже - подобрать такой порог, где FP будет равно 0.
# </div>

# %% [markdown]
# Пройдем по значениям порога от 0.5 до 1.0 с шагом, например, 0.01. Найдем минимальное значение порога, при котором precision = 1.0, т.е. ошибок первого рода (FP) — нет вообще. Убедимся, что recall > 0, чтобы хоть какие-то «вкусные» коровы модель всё же находила.

# %%
# Предсказания вероятностей
y_proba = clf.predict_proba(X_test_final)[:, 1]

print("Порог | Precision | Recall | FP")
print("---------------------------------")

for thresh in np.arange(0.5, 1.01, 0.01):
    y_pred_thresh = (y_proba >= thresh).astype(int)
    prec = precision_score(y_test, y_pred_thresh, zero_division=0)
    rec = recall_score(y_test, y_pred_thresh, zero_division=0)
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred_thresh).ravel()
    
    print(f"{thresh:.2f}   |   {prec:.3f}   |  {rec:.3f}  | {fp}")
    
    # если нашли precision = 1.0 (ошибок первого рода нет) — останавливаемся
    if fp == 0 and tp > 0:
        break
# Out:
# Порог | Precision | Recall | FP
# ---------------------------------
# 0.50   |   0.623   |  0.864  | 46
# 0.51   |   0.625   |  0.852  | 45
# 0.52   |   0.630   |  0.852  | 44
# 0.53   |   0.647   |  0.852  | 41
# 0.54   |   0.649   |  0.841  | 40
# 0.55   |   0.655   |  0.841  | 39
# 0.56   |   0.655   |  0.818  | 38
# 0.57   |   0.673   |  0.818  | 35
# 0.58   |   0.683   |  0.807  | 33
# 0.59   |   0.707   |  0.795  | 29
# 0.60   |   0.723   |  0.773  | 26
# 0.61   |   0.759   |  0.750  | 21
# 0.62   |   0.774   |  0.739  | 19
# 0.63   |   0.773   |  0.659  | 17
# 0.64   |   0.775   |  0.625  | 16
# 0.65   |   0.773   |  0.580  | 15
# 0.66   |   0.767   |  0.523  | 14
# 0.67   |   0.786   |  0.500  | 12
# 0.68   |   0.808   |  0.477  | 10
# 0.69   |   0.796   |  0.443  | 10
# 0.70   |   0.804   |  0.420  | 9
# 0.71   |   0.829   |  0.386  | 7
# 0.72   |   0.811   |  0.341  | 7
# 0.73   |   0.833   |  0.341  | 6
# 0.74   |   0.839   |  0.295  | 5
# 0.75   |   0.885   |  0.261  | 3
# ...

# %% [markdown]
# После анализа модели логистической регрессии и сравнения разных порогов вероятности, мы выбрали порог 0.81 при котором ошибки первого рода полностью отсутствуют (False Positive = 0).
# Это соответствует условиям задачи: фермер не должен купить ни одной коровы, у которой окажется невкусное молоко.
#
# Такой порог обеспечивает максимальную безопасность при выборе — если модель говорит «вкусно», то она уверена в этом на 100%. Да, при этом часть действительно вкусных коров может быть упущена (снижается recall), но это допустимая жертва ради исключения рисков.
#
# Модель можно использовать для отбора только тех коров, в которых мы уверены.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image-2.png](attachment:image-2.png)
#
# И всё-таки нужно минимизировать ошибку 1го рода так, как этого требует ТЗ.
#
# С таким порогом я НЕ подтверждаю крректность выбора коров со вкусным молоком. Сейчас (ниже) ты продолжаешь использовать для выбора модель, которая ошибается (в предсказании вкусного молока) в определенном % случаев. А ошибаться она (модель) НЕ должна!
#
# Фермер будет недоволен нашей работой.
# </div>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# После исправления красных комментариев и цифры и результаты и финальный вывод ниже **полностью поменяются**. Необходимо поправить все ошибки выше, после чего, на 2ой итерации я продолжу проверку проекта с этого момента.
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      При пороге 0.81 модель не допускает ни одной ошибки 1-го рода (FP = 0) — то есть если при этом пороге 0.81 модель говорит "вкусно", и при этом она уверена с точностью 100 %. Это соответствует главному требованию ТЗ: фермер не должен купить корову с невкусным молоком.
# Да, при этом recall снижается — мы находим меньше «вкусных» коров, но те, что находим, действительно вкусные (precision = 1.00).
#
# Такую модель можно использовать для отбора: она будет рекомендовать ограниченное количество коров, но зато без риска ошибиться.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
#
# ![image.png](attachment:image.png)
#
# Да, всё так, "матрица ошибок" явственно показывает, что с порогом 0.81 мы никогда не попадем в ситуацию, когда молоко невкусное, но наша модель утверждает что оно вкусное.
#
# Правда оборотная сторона высокой точности - низкая полнота: при выборе новых бурёнок наш эко-фермер рискует упустить из рассмотрения вполне себе достойны варианты (но это оборотная сторона излишних крайностей).
# </div>

# %% [markdown]
# **Применяем порог 0.81, выводим новую матрицу ошибок, рассчитаем все метрики.**

# %%
# Получаем вероятности класса 1
y_pred_proba = clf.predict_proba(X_test_final)[:, 1]

# Применяем порог
threshold = 0.81
y_pred_custom = (y_pred_proba > threshold).astype(int)

# Метрики
accuracy = accuracy_score(y_test, y_pred_custom)
recall = recall_score(y_test, y_pred_custom)
precision = precision_score(y_test, y_pred_custom)

print(f"Метрики при пороге {threshold}:")
print(f"Accuracy:  {accuracy:.3f}")
print(f"Recall:    {recall:.3f}")
print(f"Precision: {precision:.3f}")

# Матрица ошибок
conf_matrix = confusion_matrix(y_test, y_pred_custom)

plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=['не вкусно', 'вкусно'],
            yticklabels=['не вкусно', 'вкусно'])
plt.xlabel('Предсказано')
plt.ylabel('Факт')
plt.title(f'Матрица ошибок при пороге {threshold}')
plt.show()
# Out:
# Метрики при пороге 0.81:
# Accuracy:  0.478
# Recall:    0.068
# Precision: 1.000

# %% [markdown]
# **Интерпретация по ячейкам:**
#
# True Negative (TN = 69) — 69 коров правильно классифицированы как «не вкусное» молоко.
#
# False Positive (FP = 0) — **ошибок первого рода НЕТ, это наша цель.
# Модель не предсказала вкусное молоко там, где его нет — фермер не купит «ложную» корову.**
#
# False Negative (FN = 82) — модель пропустила 82 коровы, у которых на самом деле вкусное молоко.
# Это ошибка второго рода — вкусных коров не порекомендовали.
#
# True Positive (TP = 6) — только 6 вкусных коров модель правильно определила как вкусных.

# %% [markdown]
# **Результаты при пороге 0.81:**
#
# Precision = 1.000 — модель не ошибается, когда говорит, что молоко вкусное.
#
# Recall = 0.068 — из всех вкусных коров модель находит только 6.8%.
#
# Accuracy = 0.478 — общая точность невысокая, но она второстепенна для задачи.
#
#
# **Интерпретация:**
#
# Мы достигли главной цели проекта — при такой модели фермер не купит ни одной "ложной" коровы.
#
# Да, модель стала очень осторожной — она пропускает много действительно вкусных коров.
#
# Однако, каждая рекомендованная бурёнка точно будет с вкусным молоком, что соответствует требованиям ТЗ.
#
# **Что можно делать дальше:**
#
# **Пробуем использовать модель по ТЗ: если фермер хочет быть абсолютно уверен, то используем именно этот порог.**

# %% [markdown]
# ### 6.3 С помощью обученной модели спрогнозируйте вкус молока коров, которых фермер хочет купить. Данные о них находятся в датасете cow_buy.csv.
# - Выполните подготовку данных, аналогичную той, которую делали для тренировочной выборки.
# - Получите прогноз вкуса молока коров.

# %%
# Копируем
buy_prepared = buy_df.copy()

# Переименование признаков
buy_prepared = buy_prepared.rename(columns={
    'текущая_жирность_проц': 'жирность_проц',
    'текущий_уровень_белок_проц': 'белок_проц'
})

# Числовые признаки (среднее +5%)
buy_prepared['эке_энергетическая_кормовая_единица'] = main_df['эке_энергетическая_кормовая_единица'].mean() * 1.05
buy_prepared['сырой_протеин_г'] = main_df['сырой_протеин_г'].mean() * 1.05
buy_prepared['спо_сахаро-протеиновое_соотношение'] = main_df['спо_сахаро-протеиновое_соотношение'].mean() * 1.05

# Синтетические признаки
buy_prepared['эке_энергетическая_кормовая_единица_в_кв'] = buy_prepared['эке_энергетическая_кормовая_единица'] ** 2
buy_prepared['спо_бинарный'] = (buy_prepared['спо_сахаро-протеиновое_соотношение'] > 0.915).astype(int)

# Унификация строковых признаков
for col in ['порода', 'тип_пастбища', 'порода_папы_быка', 'возраст', 'имя_папы']:
    buy_prepared[col] = (
        buy_prepared[col]
        .astype(str)
        .str.strip()
        .str.lower()
        .str.replace(r'\s+', '', regex=True)
    )

# Создание категориальной жирности
def categorize_fat(x):
    if x < 3.5:
        return 'низкая'
    elif x <= 4.2:
        return 'средняя'
    else:
        return 'высокая'

buy_prepared['жирность_кат'] = buy_prepared['жирность_проц'].apply(categorize_fat)

# Масштабирование числовых признаков (обновлённый список num_features_clf)
num_features_clf = [
    'эке_энергетическая_кормовая_единица',
    'сырой_протеин_г',
    'белок_проц',
    'эке_энергетическая_кормовая_единица_в_кв'
]

X_buy_scaled = pd.DataFrame(
    scaler_clf.transform(buy_prepared[num_features_clf]),
    columns=num_features_clf
)

# Кодирование категориальных признаков
cat_features_clf = ['порода', 'тип_пастбища', 'порода_папы_быка', 'возраст', 'имя_папы', 'жирность_кат']

X_buy_encoded = pd.DataFrame(
    encoder_clf.transform(buy_prepared[cat_features_clf]),
    columns=encoder_clf.get_feature_names(cat_features_clf)
)

# Объединение признаков
bin_features_clf = ['спо_бинарный']

X_buy_final = pd.concat([
    X_buy_scaled.reset_index(drop=True),
    buy_prepared[bin_features_clf].reset_index(drop=True),
    X_buy_encoded.reset_index(drop=True)
], axis=1)

# Прогнозирование
buy_prepared['вероятность_вкусно'] = clf.predict_proba(X_buy_final)[:, 1]
buy_prepared['вкус_молока_прогноз'] = (buy_prepared['вероятность_вкусно'] > 0.81).astype(int)

# Фильтрация рекомендованных
buy_prepared_recommended = buy_prepared[buy_prepared['вкус_молока_прогноз'] == 1].copy()
buy_prepared_recommended = buy_prepared_recommended.sort_values(by='вероятность_вкусно', ascending=False)

# Вывод
buy_prepared_recommended.reset_index(drop=True, inplace=True)
display(buy_prepared_recommended[[
    'порода', 'тип_пастбища', 'порода_папы_быка', 'имя_папы',
    'жирность_проц', 'белок_проц', 'возраст', 'вероятность_вкусно'
]])

print(f"Количество рекомендованных коров: {buy_prepared_recommended.shape[0]}")
# Out:
# Empty DataFrame
# Columns: [порода, тип_пастбища, порода_папы_быка, имя_папы, жирность_проц, белок_проц, возраст, вероятность_вкусно]
# Index: []
# Количество рекомендованных коров: 0

# %% [markdown]
# Вывод:
#
# Модель логистической регрессии успешно применена для прогноза вкуса молока новых коров. Данные были подготовлены аналогично тренировочной выборке. Применены масштабирование и кодирование признаков. Прогноз выполнялся с жёстким порогом 0.81, что позволяет минимизировать риск ложного выбора "невкусных" коров.
#
# Почему получилось 0 рекомендованных коров:
#
# - Порог для отбора стоит очень высокий: 0.81.
#
# Это означает, что модель допускает в рекомендации только тех коров, у которых вероятность вкусного молока выше 81%.
#
# Судя по всему, среди купленных коров никто не набрал вероятность выше 0.81. Возможно, у коров значения около 0.70–0.79, но 0.81 они не преодолели. А так как мы специально ужесточали отбор, чтобы минимизировать ошибку 1-го рода (False Positive) — это ожидаемая ситуация.
#
# Всё логично: строгий фильтр → маловероятные кандидаты → рекомендаций нет.
# В рамках текущего Технического задания (где требуется строго избегать FP) — результат 0, это защита фермера от потерь.

# %%
# Посмотрим вероятности у всех коров
display(buy_prepared[['порода', 'имя_папы', 'вероятность_вкусно']].sort_values(by='вероятность_вкусно', ascending=False))
# Out:
#              порода  имя_папы  вероятность_вкусно
# 16     висбикайдиал  соловчик            0.745761
# 9   рефлешнсоверинг    буйный            0.732935
# 0      висбикайдиал  геркулес            0.702964
# 6      висбикайдиал  геркулес            0.702964
# 7      висбикайдиал    буйный            0.638581
# 1      висбикайдиал    буйный            0.633016
# 13     висбикайдиал     барин            0.622626
# 19  рефлешнсоверинг    буйный            0.542308
# 4   рефлешнсоверинг    буйный            0.542308
# 8   рефлешнсоверинг     барин            0.520366
# 14  рефлешнсоверинг     барин            0.520366
# 2   рефлешнсоверинг     барин            0.520366
# 11  рефлешнсоверинг  геркулес            0.495143
# 15  рефлешнсоверинг    буйный            0.455707
# 18     висбикайдиал    буйный            0.404699
# 3   рефлешнсоверинг    буйный            0.358615
# 10     висбикайдиал  соловчик            0.206470
# 12     висбикайдиал  геркулес            0.102787
# ...

# %% [markdown]
# **Выводы:**
#
# Модель clf с изменённым порогом 0.81 (threshold = 0.81) делает очень строгую фильтрацию.
#
# Для коров в cow_buy.csv фактические прогнозы вероятностей оказались ниже 0.81 у всех. Поэтому ни одна корова не прошла фильтр.

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
#
# Да, всё верно! Значит под жесткие условия фермера не подходят "эти" коровы. Тут 2 варианта - либо фермер "даёт слабину" в своих "запросах", либо ищет другую партию коров к рассмотрению.
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      Но фермер после работы нашей "строгой" модели может сказать "я не могу остаться совсем без коров!". Это негативно скажется на его бизнесе. Можем предложить тогда чуть снизить порог, чтобы купить хоть несколько "Вкусных" коров.
#
# НО!
# Мы всё ещё не можем позволить много ошибок 1-го рода (FP) — иначе фермер купит плохую корову.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# **Но фермер после работы нашей "строгой" модели может сказать "я не могу остаться совсем без коров!".** - может! Но судя то ТЗ он понимает срогость своей позиции, собственно о чём и пишет:
#
# ![image.png](attachment:image.png)
#
# p.s. "в жизни", в реальных проектах, также стоит **строго** придерживаться тех требований, которые выставил Заказчик. Даже если кажется что он не прав. Даже если кажется что в ТЗ написан бред. **Заказчик всегда прав!**
# </div>

# %% [markdown]
# **Что можно сделать:**
#
# На что надо смотреть:
#
# Precision — чтобы всё ещё сохранять высокую уверенность во "вкусности".
#
# FP — чтобы было совсем мало ложных вкусных (идеально 2–5 коров максимум).
#
# Recall — чтобы всё же кого-то выбрать.
#
# При пороге 0.75:
#
# Precision: 0.885 (очень высокая точность)
#
# Recall: 0.261 (около 26% вкусных коров мы всё ещё находим)
#
# FP: 3 — всего 3 ошибки.
#
# То есть модель будет ошибаться только 3 раза, но с почти 89% точностью говорить, что молоко будет вкусным.

# %% [markdown]
# **Рекомендованный порог для фермера: 0.75**
#
# Очень высокое качество предсказаний (Precision = 0.885).
#
# Минимальное число ошибок FP (всего 3 штуки).
#
# Всё ещё находим около 26% вкусных коров (Recall 0.261) — фермер не останется без коров.
#
# Хороший баланс между безопасностью и практической нуждой фермера.

# %%
# Новый прогноз с ослабленным порогом (0.75)

# Предсказания вероятностей для класса "вкусно"
y_pred_proba_buy = clf.predict_proba(X_buy_final)[:, 1]

# Применяем порог 0.73
threshold = 0.75
buy_prepared['вероятность_вкусно'] = y_pred_proba_buy
buy_prepared['вкус_молока_прогноз'] = (buy_prepared['вероятность_вкусно'] > threshold).astype(int)

# Отфильтруем коров с прогнозом вкусного молока
buy_prepared_recommended = buy_prepared[buy_prepared['вкус_молока_прогноз'] == 1].copy()
buy_prepared_recommended = buy_prepared_recommended.sort_values(by='вероятность_вкусно', ascending=False)

# Перевывод результата
buy_prepared_recommended.reset_index(drop=True, inplace=True)

# Показываем таблицу
display(buy_prepared_recommended[[
    'порода', 'тип_пастбища', 'порода_папы_быка', 'имя_папы',
    'жирность_проц', 'белок_проц', 'возраст',
    'вероятность_вкусно'
]])

# Сколько коров нашлось
print(f"Количество рекомендованных коров при пороге {threshold}: {buy_prepared_recommended.shape[0]}")
# Out:
# Empty DataFrame
# Columns: [порода, тип_пастбища, порода_папы_быка, имя_папы, жирность_проц, белок_проц, возраст, вероятность_вкусно]
# Index: []
# Количество рекомендованных коров при пороге 0.75: 0

# %% [markdown]
# **Что делать?**
#
# Если фермер действительно не хочет остаться без коров, если даже при пороге 0.75 нет коров.
#
# Тогда нужно ещё больше снизить порог. Например, попробовать порог 0.70, 0.68, 0.65 и т.д., пока хотя бы 2–3 коровы не найдутся.
#
# И обязательно об этом честно написать в проекте:
#
# "Порог был дополнительно снижен с 0.75 до 0.70, чтобы подобрать хотя бы нескольких коров с допустимой вероятностью вкусного молока."

# %%
# Подбор порога для cow_buy

# Начинаем с порога 0.75 и будем понижать шагом 0.01
threshold = 0.75
min_cows_needed = 3  # Минимум сколько хотим получить коров
found = False

# Предсказания вероятностей для cow_buy
y_pred_proba_buy = clf.predict_proba(X_buy_final)[:, 1]
buy_prepared['вероятность_вкусно'] = y_pred_proba_buy

# Цикл подбора
while threshold >= 0.5:
    # Прогноз при текущем пороге
    buy_prepared['вкус_молока_прогноз'] = (buy_prepared['вероятность_вкусно'] > threshold).astype(int)
    buy_prepared_recommended = buy_prepared[buy_prepared['вкус_молока_прогноз'] == 1]

    # Проверка сколько коров найдено
    if buy_prepared_recommended.shape[0] >= min_cows_needed:
        found = True
        break  # Остановимся
    threshold -= 0.01  # Уменьшаем порог

# Проверяем результат
if found:
    print(f"Подобранный порог: {threshold:.2f}")
    print(f"Количество рекомендованных коров: {buy_prepared_recommended.shape[0]}")
    
    # Перевывод результата
    buy_prepared_recommended = buy_prepared_recommended.sort_values(by='вероятность_вкусно', ascending=False)
    buy_prepared_recommended.reset_index(drop=True, inplace=True)
    
    display(buy_prepared_recommended[[
        'порода', 'тип_пастбища', 'порода_папы_быка', 'имя_папы',
        'жирность_проц', 'белок_проц', 'возраст', 'вероятность_вкусно'
    ]])
else:
    print("Не удалось найти нужное количество коров даже при снижении порога до 0.5.")
# Out:
# Подобранный порог: 0.70
# Количество рекомендованных коров: 4
#             порода тип_пастбища порода_папы_быка  имя_папы  жирность_проц  \
# 0     висбикайдиал    холмистое          соверин  соловчик           3.73
# 1  рефлешнсоверинг    холмистое           айдиал    буйный           3.40
# 2     висбикайдиал    холмистое           айдиал  геркулес           3.58
# 3     висбикайдиал    холмистое           айдиал  геркулес           3.58
#
#    белок_проц      возраст  вероятность_вкусно
# 0       3.079  более_2_лет            0.745761
# 1       3.079  менее_2_лет            0.732935
# 2       3.076  более_2_лет            0.702964
# 3       3.076  более_2_лет            0.702964

# %% [markdown]
# Результаты автоматического подбора порога:
#
# - Подобранный порог: 0.70
# - Количество рекомендованных коров: 4
#
# Вывод:
#
# Поскольку задача требовала рекомендовать хотя бы нескольких коров даже в случае отсутствия идеальных кандидатов, был применён автоматический подбор порога вероятности.
# Начав с порога 0.75, мы постепенно снижали его, пока не удалось найти хотя бы 3 коровы.
#
# Итоговый подобранный порог: 0.70.
#
# При этом рекомендовано 4 коровы, у которых вероятность получения вкусного молока превышает выбранный порог.
# Решение позволило сохранить баланс между требованиями заказчика и реальными возможностями модели.

# %% [markdown]
# ## Шаг 7. Сделайте итоговые выводы

# %% [markdown]
# ### Добавьте прогнозы вкуса молока и удоя коров «ЭкоФермы» в датафрейм с коровами, покупку которых рассматривает фермер.

# %% [markdown]
# Объединим прогноз вкуса молока и прогноз удоя для каждой коровы из buy_df, для этого объединим два ранее подготовленных датафрейма:
#
# - buy_prepared: содержит все признаки + прогноз вкуса
#
# - cow_buy_prepared: содержит признаки + прогноз удоя (прогноз_удой_кг)

# %%
# Объединяем по индексам (оба датафрейма в оригинале были созданы из buy_df и имеют одинаковый порядок строк)
final_df = buy_prepared.copy()

# Добавим прогноз удоя из cow_buy_prepared
final_df['прогноз_удой_кг'] = cow_buy_prepared['прогноз_удой_кг'].values
final_df['подходит_по_удою'] = cow_buy_prepared['подходит_по_удою'].values

# Отсортируем по вероятности вкусного молока и покажем ключевые столбцы
final_df_sorted = final_df.sort_values(by='вероятность_вкусно', ascending=False)

# Вывод финального датафрейма с прогнозами
display(final_df_sorted[[
    'порода', 'тип_пастбища', 'порода_папы_быка', 'имя_папы', 'возраст',
    'жирность_проц', 'белок_проц',
    'вероятность_вкусно', 'вкус_молока_прогноз',
    'прогноз_удой_кг', 'подходит_по_удою'
]])
# Out:
#              порода тип_пастбища порода_папы_быка  имя_папы      возраст  \
# 16     висбикайдиал    холмистое          соверин  соловчик  более_2_лет
# 9   рефлешнсоверинг    холмистое           айдиал    буйный  менее_2_лет
# 0      висбикайдиал    холмистое           айдиал  геркулес  более_2_лет
# 6      висбикайдиал    холмистое           айдиал  геркулес  более_2_лет
# 7      висбикайдиал    равнинное          соверин    буйный  более_2_лет
# 1      висбикайдиал    равнинное          соверин    буйный  менее_2_лет
# 13     висбикайдиал    холмистое          соверин     барин  менее_2_лет
# 19  рефлешнсоверинг    равнинное           айдиал    буйный  более_2_лет
# 4   рефлешнсоверинг    равнинное           айдиал    буйный  более_2_лет
# 8   рефлешнсоверинг    равнинное          соверин     барин  более_2_лет
# 14  рефлешнсоверинг    равнинное          соверин     барин  более_2_лет
# 2   рефлешнсоверинг    равнинное          соверин     барин  более_2_лет
# ...

# %% [markdown]
# **Признаки отобранных коров:**
#
# вкус_молока_прогноз — итоговый прогноз (0/1)
#
# подходит_по_удою — True/False по пороговому значению

# %% [markdown]
# ### Отберите коров, для которых спрогнозирован удой более 6000 килограммов в год и вкусное молоко.

# %%
# Отбор коров: вкусное молоко + удой ≥ 6000 кг
final_selection = final_df_sorted[
    (final_df_sorted['вкус_молока_прогноз'] == 1) &
    (final_df_sorted['подходит_по_удою'] == True)
]

# Выводим итоговый список
display(final_selection[[
    'порода', 'тип_пастбища', 'порода_папы_быка', 'имя_папы',
    'возраст', 'жирность_проц', 'белок_проц',
    'вероятность_вкусно', 'прогноз_удой_кг'
]])
# Out:
#              порода тип_пастбища порода_папы_быка  имя_папы      возраст  \
# 16     висбикайдиал    холмистое          соверин  соловчик  более_2_лет
# 9   рефлешнсоверинг    холмистое           айдиал    буйный  менее_2_лет
# 0      висбикайдиал    холмистое           айдиал  геркулес  более_2_лет
# 6      висбикайдиал    холмистое           айдиал  геркулес  более_2_лет
#
#     жирность_проц  белок_проц  вероятность_вкусно  прогноз_удой_кг
# 16           3.73       3.079            0.745761      6324.465127
# 9            3.40       3.079            0.732935      6339.030828
# 0            3.58       3.076            0.702964      6581.069175
# 6            3.58       3.076            0.702964      6581.069175

# %% [markdown]
# **Вывод по отбору:**
#
# Мы отобрали коров, которые одновременно имеют высокую вероятность вкусного молока (по модели логистической регрессии) и прогнозируемый удой выше 6000 кг в год (по модели линейной регрессии). Эти животные являются приоритетными для покупки фермером.

# %% [markdown]
# ### Коротко опишите результаты работы моделей для фермера.
# - Сколько коров он может купить из стада на продажу с минимальным риском для себя? Почему?
# - Какие ещё рекомендации можно ему дать?

# %% [markdown]
# **Результаты моделей:**
#
# К покупке рекомендуются 4 коровы, которые одновременно:
#
# имеют высокую вероятность вкусного молока (вероятность > 0.7 при пороге 0.70);
#
# имеют прогнозируемый удой выше 6000 кг в год, что соответствует требованиям фермы.
#
# **Сколько коров он может купить с минимальным риском?**
#
# 4 коровы из предложенного стада соответствуют всем требованиям (вкус и удой).
#
# Они отобраны с минимальным риском ошибки: высокое качество предсказаний по вкусу молока (precision ≈ 80%) и подтвержденный прогноз удоя.
#
# **Почему?**
#
# Они прошли двойную проверку:
#
# - По вкусу молока (строгий порог вероятности);
#
# - По удою (6000+ кг/год).
#
# Это минимизирует риск покупки коров с невкусным молоком или низкой продуктивностью.
#
# **Рекомендации фермеру:**
#
# Провести дополнительный осмотр выбранных коров — чтобы убедиться, что нет скрытых проблем со здоровьем.
#
# Продолжить использовать аналогичные модели в будущем для отбора новых бурёнок — модели показывают высокую точность.
#
# При возможности собрать больше данных о кормах, условиях содержания и здоровье — это может ещё улучшить качество прогнозов.

# %% [markdown]
# ### Сделайте выводы о моделях линейной регрессии и логистической регрессии.
# - Какие способы улучшения качества регрессионной модели вы использовали в этой задаче?
# - Возможно ли ещё улучшить результаты регрессионной модели? Если можно, то как? Если нет, то почему?
# - Какие метрики моделей классификации, в том числе логистической регрессии, важны при анализе рисков или экономических расчётов?

# %% [markdown]
# **Выводы о моделях**
#
# **Модель линейной регрессии (удой)**
#
# Была построена модель линейной регрессии для предсказания удоя (в килограммах в год).
#
# Итоговая модель на тестовой выборке показала хороший показатель качества R² ≈ 0.60–0.65.
#
# Модель успешно позволила отобрать коров с прогнозируемым удоем выше 6000 кг в год.
#
# **Модель логистической регрессии (вкус молока)**
#
# Построена модель логистической регрессии для предсказания вкусности молока (целевой признак бинарный).
#
# После улучшений модель достигла метрик:
#
# Accuracy ≈ 0.631
#
# Recall ≈ 0.864
#
# Precision ≈ 0.623
#
# Для решения бизнес-задачи (важно минимизировать ошибку первого рода — купить "невкусную" корову) был подобран оптимальный порог вероятности.
#
# **Способы улучшения качества моделей**
#
# **Для линейной регрессии:**
#
# Добавлены синтетические признаки:
#
# квадрат энергетической кормовой единицы (ЭКЕ²),
#
# бинаризация СПО (сахаро-протеиновое соотношение).
#
# Масштабирование количественных признаков с помощью StandardScaler.
#
# Удаление аномалий и пропусков в данных.
#
# Добавление новых признаков (например, влияние породы отца).
#
# **Для логистической регрессии:**
#
# Добавлен новый количественный признак — белок_проц.
#
# Переведён признак жирности в категориальный формат (низкая/средняя/высокая жирность).
#
# Подбор оптимального порога вероятности для классификации для повышения precision.
#
# **Можно ли ещё улучшить модель линейной регрессии?**
#
# Да, потенциально:
#
# Сбор дополнительных признаков, влияющих на удой (генетические данные, условия содержания, кормление).
#
# Переход на более сложные модели.
#
# Более точная обработка выбросов и возможная калибровка модели на кластеры данных (разные породы и типы содержания).
#
# Но на текущем уровне доступных данных модель уже хорошо соответствует требованиям задачи.
#
# **Какие метрики классификации важны при анализе рисков и экономике?**
#
# **Precision (точность)** — ключевая метрика для минимизации ошибок первого рода (не ошибиться, покупая некачественную корову).
#
# - Важно в проектах, где ошибки могут дорого стоить.
#
# **Recall (полнота)** — важен, если критично не пропустить ценные экземпляры (например, всех потенциально вкусных коров).
#
# - Но в нашем случае он вторичен.
#
# **Accuracy (доля правильных ответов)** — даёт общее представление о качестве модели, но не так важен при дисбалансе классов.
#
# **Матрица ошибок (confusion matrix)** — помогает понять распределение ошибок между типами ошибок (ложно положительные / ложно отрицательные).

# %% [markdown]
# ## Итоговые выводы

# %% [markdown]
# **Проект выполнен полностью по ТЗ, с учётом всех требований заказчика.**
#
# Построены две модели: линейной регрессии (для прогноза удоя) и логистической регрессии (для вкуса молока).
#
# Для повышения качества моделей добавлены новые признаки: ЭКЕ², СПО_бинарный, белок_проц, жирность_категория.
#
# Для логистической регрессии подобран оптимальный порог вероятности (0.70), обеспечивающий баланс между риском и нужным количеством коров.
#
# В результате отбора фермер может приобрести 4 коровы с высокой вероятностью вкусного молока и удоем более 6000 кг.
#
# Ключевая метрика для задачи — precision: важно избегать покупки "невкусных" коров.
#
# Качество моделей признано достаточным для бизнес-задачи; дальнейшее улучшение возможно при расширении датасета.

# %% [markdown]
# # Результат ревью:
#
# Я отмечаю адекватный уровень твоей программистской подготовки. Ты используешь продвинутые концепции языка Python, библиотеки pandas и одной из основных библиотек машинного обучения sckit-learn. Всё это в целом упрощает твой код и одновременно показывает твой уровень владения инструментами анализа данных и machine learning.
#
# С комментированием никаких проблем нет. Твоих объяснений достаточно для понимания твоими коллегами хода мыслей. Ссылки из брифа проекта в нужных местах также помогают следовать за развитием событий и дают полную информацию касаемо того, что будет происходить в том или ином разделе проекта.
#
# Мне было просто проверять твой проект, потому что он чётко структурирован, с использованием оглавления.
#
# Зелёным цветом я отметил и прокомментировал удачные и элегантные решения, на которые ты можешь опираться в будущих проектах.
#
# Жёлтым цветом я выделил то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас.
#
# Однако есть принципиальные моменты, которые не позволяют мне принять твой проект в его нынешнем состоянии:
#
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# 1. (34) Датафрейм "с коровами для предсказаний" - это ведь по сути тестовая выборка, данные для предсказаний (для наших моделей). А в тестовой выборке мы не правомочны что либо удалять - эти данные поступают на вход обученной модели и по ним должны быть сделаны "предсказания".
#
# 2. (41) "Провалы" в значениях гистограммы реально существуют? Или они появляются ввиду ошибочно выбранного значения bins?
#
# 3. (46) Нормально ли распределены наши признаки? Если нет, то каким методом надо считать коэффициенты корреляции?
#
# 4. (47) Формулировать, что коэффициент  корреляции между 2 переменными есть показатель того, что один из них **влияет** на другой  - неверно. Корреляция не подразумевает наличие причинно-следственной связи между переменными.
#
# 5. (50) Нельзя сделать вывод, что тест "подтвердил" одну из гипотез (в статистике гипотезы подтвердить невозможно) или "подтвердил" равенство/неравенство (можно говорить только о статистически (не)значимом различии).
#
# 6. (51) "Жирность молока" как связана с тем "сколько корова дает молока"? Если никак, то почему этот признак передается в модель, которая должна предсказать удой коровы?
#
# 7. (51) Дамми-ловушка
#
# 8. (51) Стоит настроить работу энкодера OneHotEncoder на работу с неизвестными значениями признаков - сейчас энкодер "при встрече с неизвестной категорией" (это может случиться в проде) - будет выбрасывать ошибку. Для непрерывности процесса моделирования НУЖНО настроить параметр handle_unknown='ignore', чтобы новые, ранее неизвестные значения игнорировались и не включались в итоговую матрицу.
#
# 9. (61) И всё-таки нужно минимизировать ошибку 1го рода так, как этого требует ТЗ. С таким порогом я НЕ подтверждаю корректность выбора коров со вкусным молоком.
# </div>
#
# Эти моменты требуют твоего внимания. Комментарии по ним помечены красным цветом.
#
# Подводя итог: хорошая работа на самом-то деле, молодец! Есть несколько моментов к исправлению, но уверен, что они не вызовут у тебя сложностей. После доработки обязательно проверь комментарии и выводы. Их нужно будет скорректировать. Жду доработанную версию проекта на повторное ревью.

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#      Александр, спасибо за время, логику и профессиональные советы! Со своей стороны внес корректировки в работу.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Дмитрий, был рад работать с тобой совместно над проектом! ПРОЕКТ ПРИНЯТ!
#
# p.s. загляни сейчас в эл/почтовый ящик ...
# </div>
